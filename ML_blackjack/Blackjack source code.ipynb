# %% [markdown]
# # BlackJack : Monte-Carlo with Exploring Start
# ----
#
# ## 설명
# 블랙잭 게임에서의 최적 Policy를 찾는 프로그램입니다. 본 프로그램에서 정의된 블랙잭 룰은 다음과 같습니다.
#  - 하나의 카드 덱(조커를 제외한 52장의 카드)을 사용
#  - 카드의 합을 계산할 시 A = 1 or 11, J,Q,K = 10으로 계산
#  - 플레이어는 Hit 또는 Stick만을 할 수 있음
#  - 카드의 합이 21 이하일 경우, 딜러와 플레이어 중 숫자가 더 높은 쪽이 승리.
#  - 카드의 합이 21 초과한 딜러/플레이어는 패배
#  - 카드의 합이 같을 경우 무승부
#
# 본 프로그램에서는 최적 Policy를 찾기 위해 Monte-Carlo Control with Exploring Start[1] 알고리즘을 사용합니다. 최적 Policy를 찾기 위해, 본 프로그램은 다음과 같은 변수로 구성된 State로부터 탐색을 수행합니다.
#  - 플레이어 카드의 합 : 12 ~ 21 사이의 정수
#  - 딜러가 보여주는 카드의 숫자 : 1 ~ 10 사이의 정수
#  - 플레이어가 현재 사용 가능한 Ace의 유무 : True / False
#
# 위와 같이 구성된 State S에서 Action A를 선택했을 때의 기대 리턴(게임이 끝났을 때 얻을 것으로 기대되는 보상의 합)은 Q(S,A)입니다. 많은 에피소드를 경험할수혹 Agent는 Optimal Q(S,A)에 가까운 값을 학습하게 되며, 이로부터 최적 Policy를 찾을 수 있습니다.
#
# ----
#
# ## 0. Package
# 먼저 본 프로그램에서 사용할 Package를 Import합니다.

# %%
# %matplotlib inline
import random
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib import colors

# %% [markdown]
# ## 1. Class : Deck
# 카드 덱 한 벌에 해당하는 클래스를 선언합니다. 조커를 제외한 52장의 카드로 이루어져 있으며, 각 카드는 정수로 표기됩니다. <br>
# A = 11, J, Q, K = 10으로 표현되며, 나머지 카드는 해당 카드에 적힌 숫자만큼의 값을 갖습니다.
#
# ### 클래스 구성
# * Attributes
#    * card_deck : List, 52개의 정수로 이루어짐
# * Methods
#    * shuffle() : 카드 덱을 랜덤하게 섞음
#    * draw() : 카드 덱에서 한 장을 뽑아 리턴
#    * reset() : 카드 덱을 초기화함

# %%
class Deck(object):
    
    def __init__(self):
        deck = [2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10, 11]
        self.card_deck = deck * 4
        self.shuffle()
        self.cc = 0

    def shuffle(self):
        random.shuffle(self.card_deck)

    def draw(self):
        return self.card_deck.pop()

    def reset(self):
        deck = [2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10, 11]
        self.card_deck = deck * 4
        self.shuffle()
        cc = 0
        
    def len(self):
        return len(self.card_deck)
    
    def card_count(self):
        return self.cc
    def card_plus(self):
        self.cc += 1
    def card_minus(self):
        self.cc -= 1

# %% [markdown]
# ## 2. Class : Dealer
# 다음으로 Dealer 클래스를 선언합니다.<br>
# Dealer 클래스는 강화학습에서의 Environment에 해당합니다. 플레이어의 Action을 받고, 그에 따른 다음 State와 Reward를 반환합니다.<br>
# 딜러는 시작할 때 두 장의 카드를 받습니다. 플레이어의 차례가 끝난 후, 플레이어의 카드 합이 21을 넘지 않는다면 딜러는 다음과 같이 행동합니다.
#  - 딜러 카드의 합이 17 미만일 때 : 카드 한 장을 추가로 뽑음 (Hit)
#  - 딜러 카드의 합이 17 이상일 때 : 플레이어의 카드 합과 비교하여 승패 결정 (Stick)
#
# ### 클래스 구성
# 딜러 클래스는 다음과 같이 구성됩니다
#  - Attributes
#      - hands : List, 딜러가 가지고 있는 카드들
#      - usable_ace : List, 딜러가 가지고 있는 A의 인덱스
#  - Methods
#      - hit(deck) : 카드 덱에서 카드 한 장을 뽑아 hands에 추가
#      - show() : 딜러가 가진 카드 중 랜덤한 한 장의 값을 리턴
#      - calculate_sum() : 딜러가 가진 카드의 합을 리턴. 카드 합이 21 이상일 때 사용 가능한 Ace가 있다면 사용함.
#      - action() : 딜러의 Action - 합이 17 미만이면 hit, 이상이면 stick
#      - observation(action, agent, deck) : 플레이어의 action을 받아 종료 여부와 reward 리턴
#      - calculate_rewards(agent, deck) : 플레이어와 딜러의 승패 계산 및 reward 리턴
#      - reset() : 딜러 클래스의 모든 attribute 초기화

# %%
class Dealer(object):
    """
    Dealer : 딜러 클래스
    딜러는 두 장의 카드를 받고, 카드의 합이 16 이하이면 Hit, 17이상이면 Stick 함.
    처음 두 장을 받았을 때 한 장의 카드를 랜덤하게 오픈함.
    """

    def __init__(self):
        """
        hand : 딜러가 가진 카드
        usable_ace : 딜러가 가진 카드 리스트 중 ace의 인덱스
        natural : 두 장의 카드로 21이 되면 True, 아니면 False
        """
        self.hands = list()
        self.usable_ace = list()

    def hit(self, deck: Deck):
        """
        딜러의 Hit. 새로운 카드가 Ace라면 사용 가능한 Ace 리스트에 추가함
        :param deck: Deck Object
        :return:
        """
        new_card = deck.draw()
        if new_card == 11:
            self.usable_ace.append(len(self.hands))
        self.hands.append(new_card)

    def show(self):
        """
        딜러가 가진 카드 중 하나를 랜덤하게 보여줌
        :return: 딜러의 카드 중 랜덤한 카드 숫자
        """
        card = random.choice(self.hands)
        if card == 11:
            card = 1
        return card

    def calculate_sum(self):
        """
        딜러가 가진 카드의 합을 구함
        21을 넘을 때 사용 가능한 Ace가 있으면 사용함
        :return: 딜러 카드의 합
        """
        sums = sum(self.hands)
        if sums > 21 and len(self.usable_ace) > 0:
            self.hands[self.usable_ace.pop()] = 1
            sums = sum(self.hands)
        return sums

    def action(self, deck: Deck):
        """
        딜러의 순서 때 딜러의 행동.
        숫자의 합이 16 이하일 때는 Hit, 17 이상이면 Stick
        :param deck:
        :return:
        """
        while True:
            sums = self.calculate_sum()
            if sums < 17:
                self.hit(deck)
            else:
                return sums

    def observation(self, action, agent, deck):
        """
        플레이어의 Action을 받아, 그에 맞는 Observation과 Reward를 반환
        :param action: agent 의 Action
        :param agent: agent 클래스
        :param deck: deck 클래스
        :return: 에피소드 종료 여부, reward
        """
        done = False
        reward = 0
        if action == True:  # Hit
            agent.hit(deck)
            if agent.calculate_sum() > 21:  #플레이어의 Hit으로 인해 카드 합이 21이 넘으면 즉시 종료
                done = True
                reward = -1
        else:  # Stick
            done = True
            reward = self.calcuate_reward(agent, deck)

        return done, reward

    def calcuate_reward(self, agent, deck):
        """
        플레이어가 Stick했을 때 딜러와의 카드 비교 수행
        :param agent:
        :param deck:
        :return: Reward
        """
        agent_sum = agent.calculate_sum()           # 플레이어의 카드 합 계산
        if agent_sum > 21:                          # 플레이어의 Bust (패)
            return -1

        dealer_sum = self.action(deck)              # 딜러의 카드 합 계산
        if dealer_sum > 21:                         # 딜러가 Bust (승)
            return 1
        if dealer_sum > agent_sum:                  # 딜러의 카드 합 > 플레이어 합 (패)
            return -1
        if dealer_sum < agent_sum:                  # 딜러의 카드 합 < 플레이어 합 (승)
            return 1
        return 0                                   # 딜러의 카드 합 == 플레이어의 합 (무)

    def reset(self):
        """
        딜러 초기화 (새로운 에피소드 시작을 위해)
        """
        self.hands = list()
        self.usable_ace = list()

# %% [markdown]
# ## 3. Class : Agent
# Agent 클래스는 플레이어에 해당하며, 최적 Policy를 학습하는 주체가 됩니다. Agent는 여러 에피소드들로부터 Q값(기대 Return)을 계산하고, 다음 에피소드 수행 시 해당 State에서 Q값이 높은 Action을 선택하는 Greedy Policy를 따릅니다.
#
# ### 클래스 구성
#
# Agent의 구성은 다음과 같습니다.
#
#  - Attributes
#      - hands : List, Agent가 가지고 있는 카드들
#      - usable_ace : List, Agent가 가지고 있는 A의 인덱스
#      - Q_table : Dictionary, 기대 Return값과 방문 횟수를 저장
#  - Methods
#      - hit(deck) : 카드 덱에서 카드 한 장을 뽑아 hands에 추가
#      - calculate_sum() : Agent가 가진 카드의 합을 리턴. 카드 합이 21 이상일 때 사용 가능한 Ace가 있다면 사용함.
#      - random_action() : 현재 State에 상관없이 랜덤하게 Action을 리턴
#      - policy(state) : 현재 State에서 가능한 Action 중, Q_table의 값이 큰 Action을 리턴
#      - update_qval(episode) : 에피소드로부터 평균 리턴을 계산하여 Q_table을 업데이트
#      - reset() : Agent 클래스의 모든 attribute 초기화

# %%
class Agent(object):
    def __init__(self):
        """
        hand : 플레이어의 카드
        usable_ace : 사용 가능한 ace 리스트
        Q_table : q(s,a) 값을 저장할 딕셔너리
        """
        self.hands = list()
        self.usable_ace = list()
        self.Q_table = dict()

    def hit(self, deck: Deck):
        """
        덱에서 새로운 카드를 뽑음
        :param deck: Deck for draw a card
        :return: None
        """
        new_card = deck.draw()
        if new_card == 11:
            self.usable_ace.append(len(self.hands))
        self.hands.append(new_card)

    def calculate_sum(self):
        """
        플레이어가 가진 카드의 합을 구함.
        21을 넘을 때 사용 가능한 ace가 있으면 사용함
        :return:
        """
        sums = sum(self.hands)
        if sums > 21 and len(self.usable_ace) > 0:
            self.hands[self.usable_ace.pop()] = 1
            sums = sum(self.hands)
        return sums

    def random_action(self):
        """
        랜덤하게 행동
        True = hit, False = stick
        :return:
        """
        return random.choice([True, False])

    def policy(self, state):
        """
        Agent의 policy 함수.
        e의 확률로 랜덤 행동을 하며, 그 외에는 현재 state에서 큰 q(s,a)값을 갖는 action을 선택함
        :param state: Agent에게 주어진 state
        :return: agent의 action을 반환 , True = hit and False = stick
        """
        # Q_table에서 현재 state-action에 대해 값이 존재하는지 검사함
        for action in (True, False):
            if (state, action) not in self.Q_table.keys():  # Q_table에 값이 없으면 0으로 초기화
                self.Q_table[(state, action)] = [0, 0]      # (mean return, visit count)
            else:
                continue

        # q값이 큰 action 선택
        if self.Q_table[(state, True)] > self.Q_table[(state, False)]:
            return True     # Hit
        elif self.Q_table[(state, True)] == self.Q_table[(state, False)]:   # q값이 같으면 무작위추출
            return self.random_action()
        else:
            return False    # Stick


    def reset(self):
        """
        Agent를 리셋함
        :return: None
        """
        self.hands = list()
        self.usable_ace = list()

    def update_qval(self, episode):
        """
        에피소드(한 번의 게임)으로부터 Q_table 을 업데이트함
        Q 테이블에 없는 state-action 쌍이 나오면 새로 생성
        Q 테이블에 state-action 쌍이 존재한다면 Incremental mean 적용하여 업데이트
        :param episode: Episode generated from environment
        :return: None
        """
        total_return = 0
        for state, action, reward in episode[::-1]:     # 에피소드의 뒤에서부터 (역순)
            total_return += reward                       # return Gt 계산
            if (state, action) not in self.Q_table.keys():  # state-action 쌍이 없다면
                self.Q_table[(state, action)] = [total_return, 1]   # 새롭게 엔트리 생성 (Gt, count)

            else:  #이미 존재하는 state-action 쌍이면 Incremental mean 적용
                prev_val = self.Q_table[(state, action)][0]         # 이전의 평균 return
                count = self.Q_table[(state, action)][1] + 1        # count 증가
                mean = prev_val + (total_return - prev_val) / count # 평균 계산 : Incremental Mean 적용
                self.Q_table[(state, action)] = [mean, count]  # 업데이트

# %% [markdown]
# ## 4. Class : MonteCarlo
# Monte-Carlo control with Exploring Start를 구현한 클래스입니다. 에피소드를 생성할 수 있고, 생성된 에피소드로부터 에이전트를 학습시킵니다.
# 에피소드 생성 시 Exploring Start를 위해 에피소드의 첫 번째 State에서는 무작위로 Action을 선택하며, 이후에는 에이전트의 Policy를 따라 Action을 선택합니다.
#
# ### 클래스 구성
# MonteCarlo 클래스는 다음과 같이 구성됩니다.
#  - Attribute
#      - 없음
#  - Methods
#      - generate_episode(dealer, agent, deck) : 딜러, 플레이어, 카드 덱을 이용해 한 번의 블랙잭 게임을 진행하고 에피소드를 반환합니다.
#      - train(dealer, agent, deck, it, verbose) : 지정된 이터레이션 수만큼의 에피소드로부터 플레이어를 학습시킵니다.

# %%
class MonteCarlo(object):
    def generate_episode(self, dealer: Dealer, agent: Agent, deck: Deck):
        """
        하나의 에피소드(게임)를 생성함
        :param dealer:
        :param agent:
        :param deck:
        :return:
        """
        
        # 카드 덱, 딜러, Agent를 초기화
        deck.reset()
        dealer.reset()
        agent.reset()
        agent.hit(deck)
        agent.hit(deck)
        dealer.hit(deck)
        dealer.hit(deck)

        done = False    # 에피소드의 종료 여부

        episode = list()    # 에피소드

        while not done:
            # 에피소드가 끝날 때까지 State, Action, Reward를 생성
            sums = agent.calculate_sum()
            if sums < 12:
                agent.hit(deck)
                continue

            state = (sums, bool(agent.usable_ace), dealer.show())

            ########   Exploring Start ~!!!!!!!!! : 
            if len(episode) == 0:       # 첫번째 State 일 때는 무작위 Action 선택
                action =agent.random_action()
            else:                       # 그 외에는 Q 테이블에서 큰 값을 갖는 Action 선택
                action = agent.policy(state)
            
            done, reward = dealer.observation(action, agent, deck)  # 에피소드 종료 여부, Reward 계산
            
            # 생성된 State, Action, Reward를 에피소드에 추가
            episode.append([state, action, reward])

        return episode

    def train(self, dealer: Dealer, agent: Agent, deck: Deck, it=10000, verbose=True):
        count = 0
        win = 0
        loss = 0
        draw = 0
        total_win = 0
        total_loss = 0
        total_draw = 0
        result = str()
        for i in range(it):
            count += 1
            episode = self.generate_episode(dealer, agent, deck)
            agent.update_qval(episode)

            if episode[-1][-1] == 1:
                win += 1
            elif episode[-1][-1] == 0:
                draw += 1
            else:
                loss += 1

            if count % 1000 == 0 and verbose == True:
                total_win += win
                total_loss += loss
                total_draw += draw

                print("========== Training : Episode ", count, " ===========")
                print("Recent 1000 games win rate :{:.3f}%".format(win / (win + loss) * 100))
                print(" -- 1000 Games WIN :", win, "DRAW :", draw, "LOSS :", loss)
                print("Total win rate : {:.3f}%".format(total_win / (total_win + total_loss) * 100))
                print(" -- TOTAL Games WIN :", total_win, "DRAW :", total_draw, "LOSS :", total_loss)

                win = 0
                loss = 0
                draw = 0

# %% [markdown]
# ## 5. Function : plot_q_val(agent, usable_ace)
# Q값을 시각화하기 위한 함수입니다.

# %%
def plot_q_val(agent: Agent, usable_ace=True):
    fig = plt.figure()
    ax = Axes3D(fig)

    hands = set()
    dealer_show = set()

    for state, action in sorted(agent.Q_table.keys()):
        hands.add(state[0])
        dealer_show.add(state[2])

    Z_list = list()

    l = list()

    for d in dealer_show:
        l = []
        for hand in hands:
            if ((hand, usable_ace, d), True) not in agent.Q_table.keys():
                agent.Q_table[((hand, usable_ace, d), True)] = [0, 0]
            if ((hand, usable_ace, d), False) not in agent.Q_table.keys():
                agent.Q_table[((hand, usable_ace, d), False)] = [0, 0]
            v_val = max([agent.Q_table[((hand, usable_ace, d), True)][0], agent.Q_table[((hand, usable_ace, d), False)][0]])
            l.append(v_val)
        Z_list.append(l)

    Y = np.array(list(hands))
    X = np.array(list(dealer_show))
    if usable_ace:
        X, Y = np.meshgrid(X, Y)
    else:
        X, Y = np.meshgrid(X, Y)

    Z = np.array(Z_list).T

    ax.plot_wireframe(X, Y, Z)
    plt.show()

# %% [markdown]
# ## 6. Function : plot_q_val(agent, usable_ace)
# 최적 Policy를 시각화하기 위한 함수입니다.

# %%
def plot_action(agent: Agent, usable_ace=True):
    hands = set()
    dealer_show = set()

    for state, action in sorted(agent.Q_table.keys()):
        hands.add(state[0])
        dealer_show.add(state[2])

    Z_list = list()

    l = list()

    action = False

    for d in dealer_show:
        l = []
        for hand in hands:
            if ((hand, usable_ace, d), True) not in agent.Q_table.keys():
                agent.Q_table[((hand, usable_ace, d), True)] = [0, 0]
            if ((hand, usable_ace, d), False) not in agent.Q_table.keys():
                agent.Q_table[((hand, usable_ace, d), False)] = [0, 0]
            l.append(0 if agent.Q_table[((hand, usable_ace, d), True)][0] > agent.Q_table[((hand, usable_ace, d), False)][0] else 1)
        Z_list.append(l)

    Y = np.array(list(hands))
    X = np.array(list(dealer_show))
    if usable_ace:
        X, Y = np.meshgrid(X, Y)
    else:
        X, Y = np.meshgrid(X, Y)
    Z = np.array(Z_list).T

    data = Z[::-1,:]
    data = np.append(data, [0 for _ in range(Z[0].shape[0])]).reshape(-1,Z[0].shape[0])
    
    cmap=cm.coolwarm
    plt.imshow(data, cmap=cmap, extent=[1,11,11,21])

    plt.show()
    return X, Y, Z

# %% [markdown]
# ## 7. 최적 Policy 학습

# %%
deck = Deck()
dealer = Dealer()
agent = Agent()
mc_es = MonteCarlo()

mc_es.train(dealer, agent, deck, it=1000000)
# Out:
# ========== Training : Episode  1000  ===========
# Recent 1000 games win rate :32.461%
#  -- 1000 Games WIN : 310 DRAW : 45 LOSS : 645
# Total win rate : 32.461%
#  -- TOTAL Games WIN : 310 DRAW : 45 LOSS : 645
# ========== Training : Episode  2000  ===========
# Recent 1000 games win rate :35.474%
#  -- 1000 Games WIN : 337 DRAW : 50 LOSS : 613
# Total win rate : 33.963%
#  -- TOTAL Games WIN : 647 DRAW : 95 LOSS : 1258
# ========== Training : Episode  3000  ===========
# Recent 1000 games win rate :34.249%
#  -- 1000 Games WIN : 324 DRAW : 54 LOSS : 622
# Total win rate : 34.058%
#  -- TOTAL Games WIN : 971 DRAW : 149 LOSS : 1880
# ========== Training : Episode  4000  ===========
# Recent 1000 games win rate :33.895%
#  -- 1000 Games WIN : 322 DRAW : 50 LOSS : 628
# Total win rate : 34.017%
#  -- TOTAL Games WIN : 1293 DRAW : 199 LOSS : 2508
# ========== Training : Episode  5000  ===========
# Recent 1000 games win rate :36.887%
#  -- 1000 Games WIN : 346 DRAW : 62 LOSS : 592
# Total win rate : 34.585%
#  -- TOTAL Games WIN : 1639 DRAW : 261 LOSS : 3100
# ========== Training : Episode  6000  ===========
# Recent 1000 games win rate :34.319%
#  -- 1000 Games WIN : 325 DRAW : 53 LOSS : 622
# Total win rate : 34.541%
#  -- TOTAL Games WIN : 1964 DRAW : 314 LOSS : 3722
# ========== Training : Episode  7000  ===========
# Recent 1000 games win rate :33.689%
#  -- 1000 Games WIN : 316 DRAW : 62 LOSS : 622
# Total win rate : 34.420%
#  -- TOTAL Games WIN : 2280 DRAW : 376 LOSS : 4344
# ========== Training : Episode  8000  ===========
# Recent 1000 games win rate :35.653%
#  -- 1000 Games WIN : 333 DRAW : 66 LOSS : 601
# Total win rate : 34.573%
#  -- TOTAL Games WIN : 2613 DRAW : 442 LOSS : 4945
# ========== Training : Episode  9000  ===========
# Recent 1000 games win rate :35.889%
#  -- 1000 Games WIN : 337 DRAW : 61 LOSS : 602
# Total win rate : 34.718%
#  -- TOTAL Games WIN : 2950 DRAW : 503 LOSS : 5547
# ========== Training : Episode  10000  ===========
# Recent 1000 games win rate :33.757%
#  -- 1000 Games WIN : 319 DRAW : 55 LOSS : 626
# Total win rate : 34.622%
#  -- TOTAL Games WIN : 3269 DRAW : 558 LOSS : 6173
# ========== Training : Episode  11000  ===========
# Recent 1000 games win rate :36.364%
#  -- 1000 Games WIN : 344 DRAW : 54 LOSS : 602
# Total win rate : 34.781%
#  -- TOTAL Games WIN : 3613 DRAW : 612 LOSS : 6775
# ========== Training : Episode  12000  ===========
# Recent 1000 games win rate :35.813%
#  -- 1000 Games WIN : 337 DRAW : 59 LOSS : 604
# Total win rate : 34.866%
#  -- TOTAL Games WIN : 3950 DRAW : 671 LOSS : 7379
# ========== Training : Episode  13000  ===========
# Recent 1000 games win rate :34.538%
#  -- 1000 Games WIN : 325 DRAW : 59 LOSS : 616
# Total win rate : 34.841%
#  -- TOTAL Games WIN : 4275 DRAW : 730 LOSS : 7995
# ========== Training : Episode  14000  ===========
# Recent 1000 games win rate :35.326%
#  -- 1000 Games WIN : 331 DRAW : 63 LOSS : 606
# Total win rate : 34.875%
#  -- TOTAL Games WIN : 4606 DRAW : 793 LOSS : 8601
# ========== Training : Episode  15000  ===========
# Recent 1000 games win rate :36.383%
#  -- 1000 Games WIN : 342 DRAW : 60 LOSS : 598
# Total win rate : 34.976%
#  -- TOTAL Games WIN : 4948 DRAW : 853 LOSS : 9199
# ========== Training : Episode  16000  ===========
# Recent 1000 games win rate :36.575%
#  -- 1000 Games WIN : 346 DRAW : 54 LOSS : 600
# Total win rate : 35.076%
#  -- TOTAL Games WIN : 5294 DRAW : 907 LOSS : 9799
# ========== Training : Episode  17000  ===========
# Recent 1000 games win rate :32.025%
#  -- 1000 Games WIN : 302 DRAW : 57 LOSS : 641
# Total win rate : 34.896%
#  -- TOTAL Games WIN : 5596 DRAW : 964 LOSS : 10440
# ========== Training : Episode  18000  ===========
# Recent 1000 games win rate :36.188%
#  -- 1000 Games WIN : 338 DRAW : 66 LOSS : 596
# Total win rate : 34.968%
#  -- TOTAL Games WIN : 5934 DRAW : 1030 LOSS : 11036
# ========== Training : Episode  19000  ===========
# Recent 1000 games win rate :33.795%
#  -- 1000 Games WIN : 317 DRAW : 62 LOSS : 621
# Total win rate : 34.906%
#  -- TOTAL Games WIN : 6251 DRAW : 1092 LOSS : 11657
# ========== Training : Episode  20000  ===========
# Recent 1000 games win rate :36.132%
#  -- 1000 Games WIN : 340 DRAW : 59 LOSS : 601
# Total win rate : 34.967%
#  -- TOTAL Games WIN : 6591 DRAW : 1151 LOSS : 12258
# ========== Training : Episode  21000  ===========
# Recent 1000 games win rate :36.825%
#  -- 1000 Games WIN : 348 DRAW : 55 LOSS : 597
# Total win rate : 35.056%
#  -- TOTAL Games WIN : 6939 DRAW : 1206 LOSS : 12855
# ========== Training : Episode  22000  ===========
# Recent 1000 games win rate :36.152%
#  -- 1000 Games WIN : 342 DRAW : 54 LOSS : 604
# Total win rate : 35.106%
#  -- TOTAL Games WIN : 7281 DRAW : 1260 LOSS : 13459
# ========== Training : Episode  23000  ===========
# Recent 1000 games win rate :36.192%
#  -- 1000 Games WIN : 346 DRAW : 44 LOSS : 610
# Total win rate : 35.154%
#  -- TOTAL Games WIN : 7627 DRAW : 1304 LOSS : 14069
# ========== Training : Episode  24000  ===========
# Recent 1000 games win rate :32.803%
#  -- 1000 Games WIN : 309 DRAW : 58 LOSS : 633
# Total win rate : 35.056%
#  -- TOTAL Games WIN : 7936 DRAW : 1362 LOSS : 14702
# ========== Training : Episode  25000  ===========
# Recent 1000 games win rate :33.013%
#  -- 1000 Games WIN : 309 DRAW : 64 LOSS : 627
# Total win rate : 34.975%
#  -- TOTAL Games WIN : 8245 DRAW : 1426 LOSS : 15329
# ========== Training : Episode  26000  ===========
# Recent 1000 games win rate :32.910%
#  -- 1000 Games WIN : 311 DRAW : 55 LOSS : 634
# Total win rate : 34.895%
#  -- TOTAL Games WIN : 8556 DRAW : 1481 LOSS : 15963
# ========== Training : Episode  27000  ===========
# Recent 1000 games win rate :34.428%
#  -- 1000 Games WIN : 325 DRAW : 56 LOSS : 619
# Total win rate : 34.878%
#  -- TOTAL Games WIN : 8881 DRAW : 1537 LOSS : 16582
# ========== Training : Episode  28000  ===========
# Recent 1000 games win rate :34.906%
#  -- 1000 Games WIN : 333 DRAW : 46 LOSS : 621
# Total win rate : 34.879%
#  -- TOTAL Games WIN : 9214 DRAW : 1583 LOSS : 17203
# ========== Training : Episode  29000  ===========
# Recent 1000 games win rate :34.979%
#  -- 1000 Games WIN : 333 DRAW : 48 LOSS : 619
# Total win rate : 34.883%
#  -- TOTAL Games WIN : 9547 DRAW : 1631 LOSS : 17822
# ========== Training : Episode  30000  ===========
# Recent 1000 games win rate :34.607%
#  -- 1000 Games WIN : 326 DRAW : 58 LOSS : 616
# Total win rate : 34.873%
#  -- TOTAL Games WIN : 9873 DRAW : 1689 LOSS : 18438
# ========== Training : Episode  31000  ===========
# Recent 1000 games win rate :35.412%
#  -- 1000 Games WIN : 335 DRAW : 54 LOSS : 611
# Total win rate : 34.891%
#  -- TOTAL Games WIN : 10208 DRAW : 1743 LOSS : 19049
# ========== Training : Episode  32000  ===========
# Recent 1000 games win rate :36.268%
#  -- 1000 Games WIN : 346 DRAW : 46 LOSS : 608
# Total win rate : 34.934%
#  -- TOTAL Games WIN : 10554 DRAW : 1789 LOSS : 19657
# ========== Training : Episode  33000  ===========
# Recent 1000 games win rate :36.105%
#  -- 1000 Games WIN : 343 DRAW : 50 LOSS : 607
# Total win rate : 34.970%
#  -- TOTAL Games WIN : 10897 DRAW : 1839 LOSS : 20264
# ========== Training : Episode  34000  ===========
# Recent 1000 games win rate :37.155%
#  -- 1000 Games WIN : 350 DRAW : 58 LOSS : 592
# Total win rate : 35.034%
#  -- TOTAL Games WIN : 11247 DRAW : 1897 LOSS : 20856
# ========== Training : Episode  35000  ===========
# Recent 1000 games win rate :33.192%
#  -- 1000 Games WIN : 314 DRAW : 54 LOSS : 632
# Total win rate : 34.981%
#  -- TOTAL Games WIN : 11561 DRAW : 1951 LOSS : 21488
# ========== Training : Episode  36000  ===========
# Recent 1000 games win rate :34.532%
#  -- 1000 Games WIN : 317 DRAW : 82 LOSS : 601
# Total win rate : 34.969%
#  -- TOTAL Games WIN : 11878 DRAW : 2033 LOSS : 22089
# ========== Training : Episode  37000  ===========
# Recent 1000 games win rate :36.681%
#  -- 1000 Games WIN : 347 DRAW : 54 LOSS : 599
# Total win rate : 35.016%
#  -- TOTAL Games WIN : 12225 DRAW : 2087 LOSS : 22688
# ========== Training : Episode  38000  ===========
# Recent 1000 games win rate :33.298%
#  -- 1000 Games WIN : 314 DRAW : 57 LOSS : 629
# Total win rate : 34.970%
#  -- TOTAL Games WIN : 12539 DRAW : 2144 LOSS : 23317
# ========== Training : Episode  39000  ===========
# Recent 1000 games win rate :34.989%
#  -- 1000 Games WIN : 324 DRAW : 74 LOSS : 602
# Total win rate : 34.971%
#  -- TOTAL Games WIN : 12863 DRAW : 2218 LOSS : 23919
# ========== Training : Episode  40000  ===========
# Recent 1000 games win rate :34.824%
#  -- 1000 Games WIN : 327 DRAW : 61 LOSS : 612
# Total win rate : 34.967%
#  -- TOTAL Games WIN : 13190 DRAW : 2279 LOSS : 24531
# ========== Training : Episode  41000  ===========
# Recent 1000 games win rate :35.518%
#  -- 1000 Games WIN : 336 DRAW : 54 LOSS : 610
# Total win rate : 34.981%
#  -- TOTAL Games WIN : 13526 DRAW : 2333 LOSS : 25141
# ========== Training : Episode  42000  ===========
# Recent 1000 games win rate :34.947%
#  -- 1000 Games WIN : 332 DRAW : 50 LOSS : 618
# Total win rate : 34.980%
#  -- TOTAL Games WIN : 13858 DRAW : 2383 LOSS : 25759
# ========== Training : Episode  43000  ===========
# Recent 1000 games win rate :37.274%
#  -- 1000 Games WIN : 350 DRAW : 61 LOSS : 589
# Total win rate : 35.033%
#  -- TOTAL Games WIN : 14208 DRAW : 2444 LOSS : 26348
# ========== Training : Episode  44000  ===========
# Recent 1000 games win rate :35.069%
#  -- 1000 Games WIN : 330 DRAW : 59 LOSS : 611
# Total win rate : 35.034%
#  -- TOTAL Games WIN : 14538 DRAW : 2503 LOSS : 26959
# ========== Training : Episode  45000  ===========
# Recent 1000 games win rate :35.776%
#  -- 1000 Games WIN : 332 DRAW : 72 LOSS : 596
# Total win rate : 35.050%
#  -- TOTAL Games WIN : 14870 DRAW : 2575 LOSS : 27555
# ========== Training : Episode  46000  ===========
# Recent 1000 games win rate :31.356%
#  -- 1000 Games WIN : 296 DRAW : 56 LOSS : 648
# Total win rate : 34.970%
#  -- TOTAL Games WIN : 15166 DRAW : 2631 LOSS : 28203
# ========== Training : Episode  47000  ===========
# Recent 1000 games win rate :34.820%
#  -- 1000 Games WIN : 328 DRAW : 58 LOSS : 614
# Total win rate : 34.966%
#  -- TOTAL Games WIN : 15494 DRAW : 2689 LOSS : 28817
# ========== Training : Episode  48000  ===========
# Recent 1000 games win rate :35.106%
#  -- 1000 Games WIN : 330 DRAW : 60 LOSS : 610
# Total win rate : 34.969%
#  -- TOTAL Games WIN : 15824 DRAW : 2749 LOSS : 29427
# ========== Training : Episode  49000  ===========
# Recent 1000 games win rate :34.219%
#  -- 1000 Games WIN : 322 DRAW : 59 LOSS : 619
# Total win rate : 34.954%
#  -- TOTAL Games WIN : 16146 DRAW : 2808 LOSS : 30046
# ========== Training : Episode  50000  ===========
# Recent 1000 games win rate :34.402%
#  -- 1000 Games WIN : 322 DRAW : 64 LOSS : 614
# Total win rate : 34.943%
#  -- TOTAL Games WIN : 16468 DRAW : 2872 LOSS : 30660
# ========== Training : Episode  51000  ===========
# Recent 1000 games win rate :35.269%
#  -- 1000 Games WIN : 334 DRAW : 53 LOSS : 613
# Total win rate : 34.950%
#  -- TOTAL Games WIN : 16802 DRAW : 2925 LOSS : 31273
# ========== Training : Episode  52000  ===========
# Recent 1000 games win rate :35.661%
#  -- 1000 Games WIN : 337 DRAW : 55 LOSS : 608
# Total win rate : 34.963%
#  -- TOTAL Games WIN : 17139 DRAW : 2980 LOSS : 31881
# ========== Training : Episode  53000  ===========
# Recent 1000 games win rate :36.043%
#  -- 1000 Games WIN : 337 DRAW : 65 LOSS : 598
# Total win rate : 34.983%
#  -- TOTAL Games WIN : 17476 DRAW : 3045 LOSS : 32479
# ========== Training : Episode  54000  ===========
# Recent 1000 games win rate :34.421%
#  -- 1000 Games WIN : 327 DRAW : 50 LOSS : 623
# Total win rate : 34.973%
#  -- TOTAL Games WIN : 17803 DRAW : 3095 LOSS : 33102
# ========== Training : Episode  55000  ===========
# Recent 1000 games win rate :35.546%
#  -- 1000 Games WIN : 332 DRAW : 66 LOSS : 602
# Total win rate : 34.983%
#  -- TOTAL Games WIN : 18135 DRAW : 3161 LOSS : 33704
# ========== Training : Episode  56000  ===========
# Recent 1000 games win rate :38.871%
#  -- 1000 Games WIN : 365 DRAW : 61 LOSS : 574
# Total win rate : 35.052%
#  -- TOTAL Games WIN : 18500 DRAW : 3222 LOSS : 34278
# ========== Training : Episode  57000  ===========
# Recent 1000 games win rate :34.721%
#  -- 1000 Games WIN : 317 DRAW : 87 LOSS : 596
# Total win rate : 35.047%
#  -- TOTAL Games WIN : 18817 DRAW : 3309 LOSS : 34874
# ========== Training : Episode  58000  ===========
# Recent 1000 games win rate :35.570%
#  -- 1000 Games WIN : 334 DRAW : 61 LOSS : 605
# Total win rate : 35.056%
#  -- TOTAL Games WIN : 19151 DRAW : 3370 LOSS : 35479
# ========== Training : Episode  59000  ===========
# Recent 1000 games win rate :34.152%
#  -- 1000 Games WIN : 320 DRAW : 63 LOSS : 617
# Total win rate : 35.041%
#  -- TOTAL Games WIN : 19471 DRAW : 3433 LOSS : 36096
# ========== Training : Episode  60000  ===========
# Recent 1000 games win rate :31.958%
#  -- 1000 Games WIN : 302 DRAW : 55 LOSS : 643
# Total win rate : 34.989%
#  -- TOTAL Games WIN : 19773 DRAW : 3488 LOSS : 36739
# ========== Training : Episode  61000  ===========
# Recent 1000 games win rate :33.298%
#  -- 1000 Games WIN : 314 DRAW : 57 LOSS : 629
# Total win rate : 34.961%
#  -- TOTAL Games WIN : 20087 DRAW : 3545 LOSS : 37368
# ========== Training : Episode  62000  ===========
# Recent 1000 games win rate :34.188%
#  -- 1000 Games WIN : 320 DRAW : 64 LOSS : 616
# Total win rate : 34.949%
#  -- TOTAL Games WIN : 20407 DRAW : 3609 LOSS : 37984
# ========== Training : Episode  63000  ===========
# Recent 1000 games win rate :32.196%
#  -- 1000 Games WIN : 302 DRAW : 62 LOSS : 636
# Total win rate : 34.905%
#  -- TOTAL Games WIN : 20709 DRAW : 3671 LOSS : 38620
# ========== Training : Episode  64000  ===========
# Recent 1000 games win rate :36.188%
#  -- 1000 Games WIN : 338 DRAW : 66 LOSS : 596
# Total win rate : 34.925%
#  -- TOTAL Games WIN : 21047 DRAW : 3737 LOSS : 39216
# ========== Training : Episode  65000  ===========
# Recent 1000 games win rate :37.764%
#  -- 1000 Games WIN : 358 DRAW : 52 LOSS : 590
# Total win rate : 34.969%
#  -- TOTAL Games WIN : 21405 DRAW : 3789 LOSS : 39806
# ========== Training : Episode  66000  ===========
# Recent 1000 games win rate :35.213%
#  -- 1000 Games WIN : 331 DRAW : 60 LOSS : 609
# Total win rate : 34.973%
#  -- TOTAL Games WIN : 21736 DRAW : 3849 LOSS : 40415
# ========== Training : Episode  67000  ===========
# Recent 1000 games win rate :35.737%
#  -- 1000 Games WIN : 337 DRAW : 57 LOSS : 606
# Total win rate : 34.984%
#  -- TOTAL Games WIN : 22073 DRAW : 3906 LOSS : 41021
# ========== Training : Episode  68000  ===========
# Recent 1000 games win rate :36.373%
#  -- 1000 Games WIN : 339 DRAW : 68 LOSS : 593
# Total win rate : 35.005%
#  -- TOTAL Games WIN : 22412 DRAW : 3974 LOSS : 41614
# ========== Training : Episode  69000  ===========
# Recent 1000 games win rate :35.542%
#  -- 1000 Games WIN : 338 DRAW : 49 LOSS : 613
# Total win rate : 35.012%
#  -- TOTAL Games WIN : 22750 DRAW : 4023 LOSS : 42227
# ========== Training : Episode  70000  ===========
# Recent 1000 games win rate :39.358%
#  -- 1000 Games WIN : 368 DRAW : 65 LOSS : 567
# Total win rate : 35.074%
#  -- TOTAL Games WIN : 23118 DRAW : 4088 LOSS : 42794
# ========== Training : Episode  71000  ===========
# Recent 1000 games win rate :34.146%
#  -- 1000 Games WIN : 322 DRAW : 57 LOSS : 621
# Total win rate : 35.061%
#  -- TOTAL Games WIN : 23440 DRAW : 4145 LOSS : 43415
# ========== Training : Episode  72000  ===========
# Recent 1000 games win rate :35.676%
#  -- 1000 Games WIN : 335 DRAW : 61 LOSS : 604
# Total win rate : 35.069%
#  -- TOTAL Games WIN : 23775 DRAW : 4206 LOSS : 44019
# ========== Training : Episode  73000  ===========
# Recent 1000 games win rate :35.887%
#  -- 1000 Games WIN : 342 DRAW : 47 LOSS : 611
# Total win rate : 35.081%
#  -- TOTAL Games WIN : 24117 DRAW : 4253 LOSS : 44630
# ========== Training : Episode  74000  ===========
# Recent 1000 games win rate :39.346%
#  -- 1000 Games WIN : 373 DRAW : 52 LOSS : 575
# Total win rate : 35.139%
#  -- TOTAL Games WIN : 24490 DRAW : 4305 LOSS : 45205
# ========== Training : Episode  75000  ===========
# Recent 1000 games win rate :35.699%
#  -- 1000 Games WIN : 337 DRAW : 56 LOSS : 607
# Total win rate : 35.146%
#  -- TOTAL Games WIN : 24827 DRAW : 4361 LOSS : 45812
# ========== Training : Episode  76000  ===========
# Recent 1000 games win rate :35.624%
#  -- 1000 Games WIN : 337 DRAW : 54 LOSS : 609
# Total win rate : 35.153%
#  -- TOTAL Games WIN : 25164 DRAW : 4415 LOSS : 46421
# ========== Training : Episode  77000  ===========
# Recent 1000 games win rate :35.887%
#  -- 1000 Games WIN : 342 DRAW : 47 LOSS : 611
# Total win rate : 35.162%
#  -- TOTAL Games WIN : 25506 DRAW : 4462 LOSS : 47032
# ========== Training : Episode  78000  ===========
# Recent 1000 games win rate :36.220%
#  -- 1000 Games WIN : 343 DRAW : 53 LOSS : 604
# Total win rate : 35.176%
#  -- TOTAL Games WIN : 25849 DRAW : 4515 LOSS : 47636
# ========== Training : Episode  79000  ===========
# Recent 1000 games win rate :37.155%
#  -- 1000 Games WIN : 350 DRAW : 58 LOSS : 592
# Total win rate : 35.201%
#  -- TOTAL Games WIN : 26199 DRAW : 4573 LOSS : 48228
# ========== Training : Episode  80000  ===========
# Recent 1000 games win rate :37.567%
#  -- 1000 Games WIN : 349 DRAW : 71 LOSS : 580
# Total win rate : 35.230%
#  -- TOTAL Games WIN : 26548 DRAW : 4644 LOSS : 48808
# ========== Training : Episode  81000  ===========
# Recent 1000 games win rate :34.258%
#  -- 1000 Games WIN : 321 DRAW : 63 LOSS : 616
# Total win rate : 35.218%
#  -- TOTAL Games WIN : 26869 DRAW : 4707 LOSS : 49424
# ========== Training : Episode  82000  ===========
# Recent 1000 games win rate :33.085%
#  -- 1000 Games WIN : 311 DRAW : 60 LOSS : 629
# Total win rate : 35.192%
#  -- TOTAL Games WIN : 27180 DRAW : 4767 LOSS : 50053
# ========== Training : Episode  83000  ===========
# Recent 1000 games win rate :38.502%
#  -- 1000 Games WIN : 365 DRAW : 52 LOSS : 583
# Total win rate : 35.232%
#  -- TOTAL Games WIN : 27545 DRAW : 4819 LOSS : 50636
# ========== Training : Episode  84000  ===========
# Recent 1000 games win rate :35.042%
#  -- 1000 Games WIN : 335 DRAW : 44 LOSS : 621
# Total win rate : 35.230%
#  -- TOTAL Games WIN : 27880 DRAW : 4863 LOSS : 51257
# ========== Training : Episode  85000  ===========
# Recent 1000 games win rate :37.383%
#  -- 1000 Games WIN : 360 DRAW : 37 LOSS : 603
# Total win rate : 35.256%
#  -- TOTAL Games WIN : 28240 DRAW : 4900 LOSS : 51860
# ========== Training : Episode  86000  ===========
# Recent 1000 games win rate :34.989%
#  -- 1000 Games WIN : 331 DRAW : 54 LOSS : 615
# Total win rate : 35.253%
#  -- TOTAL Games WIN : 28571 DRAW : 4954 LOSS : 52475
# ========== Training : Episode  87000  ===========
# Recent 1000 games win rate :35.600%
#  -- 1000 Games WIN : 335 DRAW : 59 LOSS : 606
# Total win rate : 35.257%
#  -- TOTAL Games WIN : 28906 DRAW : 5013 LOSS : 53081
# ========== Training : Episode  88000  ===========
# Recent 1000 games win rate :34.494%
#  -- 1000 Games WIN : 327 DRAW : 52 LOSS : 621
# Total win rate : 35.248%
#  -- TOTAL Games WIN : 29233 DRAW : 5065 LOSS : 53702
# ========== Training : Episode  89000  ===========
# Recent 1000 games win rate :31.450%
#  -- 1000 Games WIN : 295 DRAW : 62 LOSS : 643
# Total win rate : 35.206%
#  -- TOTAL Games WIN : 29528 DRAW : 5127 LOSS : 54345
# ========== Training : Episode  90000  ===========
# Recent 1000 games win rate :36.780%
#  -- 1000 Games WIN : 345 DRAW : 62 LOSS : 593
# Total win rate : 35.223%
#  -- TOTAL Games WIN : 29873 DRAW : 5189 LOSS : 54938
# ========== Training : Episode  91000  ===========
# Recent 1000 games win rate :38.040%
#  -- 1000 Games WIN : 361 DRAW : 51 LOSS : 588
# Total win rate : 35.254%
#  -- TOTAL Games WIN : 30234 DRAW : 5240 LOSS : 55526
# ========== Training : Episode  92000  ===========
# Recent 1000 games win rate :34.009%
#  -- 1000 Games WIN : 319 DRAW : 62 LOSS : 619
# Total win rate : 35.241%
#  -- TOTAL Games WIN : 30553 DRAW : 5302 LOSS : 56145
# ========== Training : Episode  93000  ===========
# Recent 1000 games win rate :35.408%
#  -- 1000 Games WIN : 330 DRAW : 68 LOSS : 602
# Total win rate : 35.242%
#  -- TOTAL Games WIN : 30883 DRAW : 5370 LOSS : 56747
# ========== Training : Episode  94000  ===========
# Recent 1000 games win rate :35.480%
#  -- 1000 Games WIN : 336 DRAW : 53 LOSS : 611
# Total win rate : 35.245%
#  -- TOTAL Games WIN : 31219 DRAW : 5423 LOSS : 57358
# ========== Training : Episode  95000  ===========
# Recent 1000 games win rate :35.979%
#  -- 1000 Games WIN : 340 DRAW : 55 LOSS : 605
# Total win rate : 35.253%
#  -- TOTAL Games WIN : 31559 DRAW : 5478 LOSS : 57963
# ========== Training : Episode  96000  ===========
# Recent 1000 games win rate :33.121%
#  -- 1000 Games WIN : 312 DRAW : 58 LOSS : 630
# Total win rate : 35.231%
#  -- TOTAL Games WIN : 31871 DRAW : 5536 LOSS : 58593
# ========== Training : Episode  97000  ===========
# Recent 1000 games win rate :34.694%
#  -- 1000 Games WIN : 323 DRAW : 69 LOSS : 608
# Total win rate : 35.225%
#  -- TOTAL Games WIN : 32194 DRAW : 5605 LOSS : 59201
# ========== Training : Episode  98000  ===========
# Recent 1000 games win rate :35.586%
#  -- 1000 Games WIN : 337 DRAW : 53 LOSS : 610
# Total win rate : 35.229%
#  -- TOTAL Games WIN : 32531 DRAW : 5658 LOSS : 59811
# ========== Training : Episode  99000  ===========
# Recent 1000 games win rate :35.439%
#  -- 1000 Games WIN : 331 DRAW : 66 LOSS : 603
# Total win rate : 35.231%
#  -- TOTAL Games WIN : 32862 DRAW : 5724 LOSS : 60414
# ========== Training : Episode  100000  ===========
# Recent 1000 games win rate :35.250%
#  -- 1000 Games WIN : 331 DRAW : 61 LOSS : 608
# Total win rate : 35.231%
#  -- TOTAL Games WIN : 33193 DRAW : 5785 LOSS : 61022
# ========== Training : Episode  101000  ===========
# Recent 1000 games win rate :36.138%
#  -- 1000 Games WIN : 335 DRAW : 73 LOSS : 592
# Total win rate : 35.240%
#  -- TOTAL Games WIN : 33528 DRAW : 5858 LOSS : 61614
# ========== Training : Episode  102000  ===========
# Recent 1000 games win rate :35.414%
#  -- 1000 Games WIN : 329 DRAW : 71 LOSS : 600
# Total win rate : 35.242%
#  -- TOTAL Games WIN : 33857 DRAW : 5929 LOSS : 62214
# ========== Training : Episode  103000  ===========
# Recent 1000 games win rate :36.161%
#  -- 1000 Games WIN : 341 DRAW : 57 LOSS : 602
# Total win rate : 35.251%
#  -- TOTAL Games WIN : 34198 DRAW : 5986 LOSS : 62816
# ========== Training : Episode  104000  ===========
# Recent 1000 games win rate :35.745%
#  -- 1000 Games WIN : 336 DRAW : 60 LOSS : 604
# Total win rate : 35.255%
#  -- TOTAL Games WIN : 34534 DRAW : 6046 LOSS : 63420
# ========== Training : Episode  105000  ===========
# Recent 1000 games win rate :36.067%
#  -- 1000 Games WIN : 343 DRAW : 49 LOSS : 608
# Total win rate : 35.263%
#  -- TOTAL Games WIN : 34877 DRAW : 6095 LOSS : 64028
# ========== Training : Episode  106000  ===========
# Recent 1000 games win rate :34.509%
#  -- 1000 Games WIN : 323 DRAW : 64 LOSS : 613
# Total win rate : 35.256%
#  -- TOTAL Games WIN : 35200 DRAW : 6159 LOSS : 64641
# ========== Training : Episode  107000  ===========
# Recent 1000 games win rate :38.678%
#  -- 1000 Games WIN : 357 DRAW : 77 LOSS : 566
# Total win rate : 35.287%
#  -- TOTAL Games WIN : 35557 DRAW : 6236 LOSS : 65207
# ========== Training : Episode  108000  ===========
# Recent 1000 games win rate :36.287%
#  -- 1000 Games WIN : 344 DRAW : 52 LOSS : 604
# Total win rate : 35.297%
#  -- TOTAL Games WIN : 35901 DRAW : 6288 LOSS : 65811
# ========== Training : Episode  109000  ===========
# Recent 1000 games win rate :37.579%
#  -- 1000 Games WIN : 357 DRAW : 50 LOSS : 593
# Total win rate : 35.318%
#  -- TOTAL Games WIN : 36258 DRAW : 6338 LOSS : 66404
# ========== Training : Episode  110000  ===========
# Recent 1000 games win rate :36.170%
#  -- 1000 Games WIN : 340 DRAW : 60 LOSS : 600
# Total win rate : 35.326%
#  -- TOTAL Games WIN : 36598 DRAW : 6398 LOSS : 67004
# ========== Training : Episode  111000  ===========
# Recent 1000 games win rate :35.622%
#  -- 1000 Games WIN : 332 DRAW : 68 LOSS : 600
# Total win rate : 35.328%
#  -- TOTAL Games WIN : 36930 DRAW : 6466 LOSS : 67604
# ========== Training : Episode  112000  ===========
# Recent 1000 games win rate :34.989%
#  -- 1000 Games WIN : 331 DRAW : 54 LOSS : 615
# Total win rate : 35.325%
#  -- TOTAL Games WIN : 37261 DRAW : 6520 LOSS : 68219
# ========== Training : Episode  113000  ===========
# Recent 1000 games win rate :35.110%
#  -- 1000 Games WIN : 336 DRAW : 43 LOSS : 621
# Total win rate : 35.323%
#  -- TOTAL Games WIN : 37597 DRAW : 6563 LOSS : 68840
# ========== Training : Episode  114000  ===========
# Recent 1000 games win rate :36.102%
#  -- 1000 Games WIN : 339 DRAW : 61 LOSS : 600
# Total win rate : 35.330%
#  -- TOTAL Games WIN : 37936 DRAW : 6624 LOSS : 69440
# ========== Training : Episode  115000  ===========
# Recent 1000 games win rate :36.247%
#  -- 1000 Games WIN : 340 DRAW : 62 LOSS : 598
# Total win rate : 35.338%
#  -- TOTAL Games WIN : 38276 DRAW : 6686 LOSS : 70038
# ========== Training : Episode  116000  ===========
# Recent 1000 games win rate :37.234%
#  -- 1000 Games WIN : 350 DRAW : 60 LOSS : 590
# Total win rate : 35.354%
#  -- TOTAL Games WIN : 38626 DRAW : 6746 LOSS : 70628
# ========== Training : Episode  117000  ===========
# Recent 1000 games win rate :35.319%
#  -- 1000 Games WIN : 332 DRAW : 60 LOSS : 608
# Total win rate : 35.354%
#  -- TOTAL Games WIN : 38958 DRAW : 6806 LOSS : 71236
# ========== Training : Episode  118000  ===========
# Recent 1000 games win rate :35.250%
#  -- 1000 Games WIN : 331 DRAW : 61 LOSS : 608
# Total win rate : 35.353%
#  -- TOTAL Games WIN : 39289 DRAW : 6867 LOSS : 71844
# ========== Training : Episode  119000  ===========
# Recent 1000 games win rate :35.966%
#  -- 1000 Games WIN : 337 DRAW : 63 LOSS : 600
# Total win rate : 35.358%
#  -- TOTAL Games WIN : 39626 DRAW : 6930 LOSS : 72444
# ========== Training : Episode  120000  ===========
# Recent 1000 games win rate :37.924%
#  -- 1000 Games WIN : 358 DRAW : 56 LOSS : 586
# Total win rate : 35.380%
#  -- TOTAL Games WIN : 39984 DRAW : 6986 LOSS : 73030
# ========== Training : Episode  121000  ===========
# Recent 1000 games win rate :36.876%
#  -- 1000 Games WIN : 347 DRAW : 59 LOSS : 594
# Total win rate : 35.392%
#  -- TOTAL Games WIN : 40331 DRAW : 7045 LOSS : 73624
# ========== Training : Episode  122000  ===========
# Recent 1000 games win rate :33.369%
#  -- 1000 Games WIN : 312 DRAW : 65 LOSS : 623
# Total win rate : 35.376%
#  -- TOTAL Games WIN : 40643 DRAW : 7110 LOSS : 74247
# ========== Training : Episode  123000  ===========
# Recent 1000 games win rate :34.599%
#  -- 1000 Games WIN : 328 DRAW : 52 LOSS : 620
# Total win rate : 35.369%
#  -- TOTAL Games WIN : 40971 DRAW : 7162 LOSS : 74867
# ========== Training : Episode  124000  ===========
# Recent 1000 games win rate :38.854%
#  -- 1000 Games WIN : 366 DRAW : 58 LOSS : 576
# Total win rate : 35.397%
#  -- TOTAL Games WIN : 41337 DRAW : 7220 LOSS : 75443
# ========== Training : Episode  125000  ===========
# Recent 1000 games win rate :33.474%
#  -- 1000 Games WIN : 317 DRAW : 53 LOSS : 630
# Total win rate : 35.382%
#  -- TOTAL Games WIN : 41654 DRAW : 7273 LOSS : 76073
# ========== Training : Episode  126000  ===========
# Recent 1000 games win rate :36.085%
#  -- 1000 Games WIN : 341 DRAW : 55 LOSS : 604
# Total win rate : 35.387%
#  -- TOTAL Games WIN : 41995 DRAW : 7328 LOSS : 76677
# ========== Training : Episode  127000  ===========
# Recent 1000 games win rate :35.730%
#  -- 1000 Games WIN : 333 DRAW : 68 LOSS : 599
# Total win rate : 35.390%
#  -- TOTAL Games WIN : 42328 DRAW : 7396 LOSS : 77276
# ========== Training : Episode  128000  ===========
# Recent 1000 games win rate :35.829%
#  -- 1000 Games WIN : 335 DRAW : 65 LOSS : 600
# Total win rate : 35.394%
#  -- TOTAL Games WIN : 42663 DRAW : 7461 LOSS : 77876
# ========== Training : Episode  129000  ===========
# Recent 1000 games win rate :35.300%
#  -- 1000 Games WIN : 335 DRAW : 51 LOSS : 614
# Total win rate : 35.393%
#  -- TOTAL Games WIN : 42998 DRAW : 7512 LOSS : 78490
# ========== Training : Episode  130000  ===========
# Recent 1000 games win rate :37.152%
#  -- 1000 Games WIN : 347 DRAW : 66 LOSS : 587
# Total win rate : 35.406%
#  -- TOTAL Games WIN : 43345 DRAW : 7578 LOSS : 79077
# ========== Training : Episode  131000  ===========
# Recent 1000 games win rate :38.036%
#  -- 1000 Games WIN : 364 DRAW : 43 LOSS : 593
# Total win rate : 35.427%
#  -- TOTAL Games WIN : 43709 DRAW : 7621 LOSS : 79670
# ========== Training : Episode  132000  ===========
# Recent 1000 games win rate :33.477%
#  -- 1000 Games WIN : 310 DRAW : 74 LOSS : 616
# Total win rate : 35.412%
#  -- TOTAL Games WIN : 44019 DRAW : 7695 LOSS : 80286
# ========== Training : Episode  133000  ===========
# Recent 1000 games win rate :34.352%
#  -- 1000 Games WIN : 326 DRAW : 51 LOSS : 623
# Total win rate : 35.404%
#  -- TOTAL Games WIN : 44345 DRAW : 7746 LOSS : 80909
# ========== Training : Episode  134000  ===========
# Recent 1000 games win rate :36.230%
#  -- 1000 Games WIN : 346 DRAW : 45 LOSS : 609
# Total win rate : 35.410%
#  -- TOTAL Games WIN : 44691 DRAW : 7791 LOSS : 81518
# ========== Training : Episode  135000  ===========
# Recent 1000 games win rate :36.797%
#  -- 1000 Games WIN : 347 DRAW : 57 LOSS : 596
# Total win rate : 35.421%
#  -- TOTAL Games WIN : 45038 DRAW : 7848 LOSS : 82114
# ========== Training : Episode  136000  ===========
# Recent 1000 games win rate :33.800%
#  -- 1000 Games WIN : 314 DRAW : 71 LOSS : 615
# Total win rate : 35.409%
#  -- TOTAL Games WIN : 45352 DRAW : 7919 LOSS : 82729
# ========== Training : Episode  137000  ===========
# Recent 1000 games win rate :35.631%
#  -- 1000 Games WIN : 336 DRAW : 57 LOSS : 607
# Total win rate : 35.410%
#  -- TOTAL Games WIN : 45688 DRAW : 7976 LOSS : 83336
# ========== Training : Episode  138000  ===========
# Recent 1000 games win rate :35.843%
#  -- 1000 Games WIN : 338 DRAW : 57 LOSS : 605
# Total win rate : 35.414%
#  -- TOTAL Games WIN : 46026 DRAW : 8033 LOSS : 83941
# ========== Training : Episode  139000  ===========
# Recent 1000 games win rate :34.049%
#  -- 1000 Games WIN : 317 DRAW : 69 LOSS : 614
# Total win rate : 35.404%
#  -- TOTAL Games WIN : 46343 DRAW : 8102 LOSS : 84555
# ========== Training : Episode  140000  ===========
# Recent 1000 games win rate :31.230%
#  -- 1000 Games WIN : 292 DRAW : 65 LOSS : 643
# Total win rate : 35.374%
#  -- TOTAL Games WIN : 46635 DRAW : 8167 LOSS : 85198
# ========== Training : Episode  141000  ===========
# Recent 1000 games win rate :35.941%
#  -- 1000 Games WIN : 340 DRAW : 54 LOSS : 606
# Total win rate : 35.378%
#  -- TOTAL Games WIN : 46975 DRAW : 8221 LOSS : 85804
# ========== Training : Episode  142000  ===========
# Recent 1000 games win rate :35.936%
#  -- 1000 Games WIN : 336 DRAW : 65 LOSS : 599
# Total win rate : 35.382%
#  -- TOTAL Games WIN : 47311 DRAW : 8286 LOSS : 86403
# ========== Training : Episode  143000  ===========
# Recent 1000 games win rate :37.474%
#  -- 1000 Games WIN : 356 DRAW : 50 LOSS : 594
# Total win rate : 35.397%
#  -- TOTAL Games WIN : 47667 DRAW : 8336 LOSS : 86997
# ========== Training : Episode  144000  ===========
# Recent 1000 games win rate :34.783%
#  -- 1000 Games WIN : 328 DRAW : 57 LOSS : 615
# Total win rate : 35.393%
#  -- TOTAL Games WIN : 47995 DRAW : 8393 LOSS : 87612
# ========== Training : Episode  145000  ===========
# Recent 1000 games win rate :34.372%
#  -- 1000 Games WIN : 320 DRAW : 69 LOSS : 611
# Total win rate : 35.386%
#  -- TOTAL Games WIN : 48315 DRAW : 8462 LOSS : 88223
# ========== Training : Episode  146000  ===========
# Recent 1000 games win rate :34.973%
#  -- 1000 Games WIN : 327 DRAW : 65 LOSS : 608
# Total win rate : 35.383%
#  -- TOTAL Games WIN : 48642 DRAW : 8527 LOSS : 88831
# ========== Training : Episode  147000  ===========
# Recent 1000 games win rate :35.532%
#  -- 1000 Games WIN : 334 DRAW : 60 LOSS : 606
# Total win rate : 35.384%
#  -- TOTAL Games WIN : 48976 DRAW : 8587 LOSS : 89437
# ========== Training : Episode  148000  ===========
# Recent 1000 games win rate :36.354%
#  -- 1000 Games WIN : 341 DRAW : 62 LOSS : 597
# Total win rate : 35.390%
#  -- TOTAL Games WIN : 49317 DRAW : 8649 LOSS : 90034
# ========== Training : Episode  149000  ===========
# Recent 1000 games win rate :35.388%
#  -- 1000 Games WIN : 333 DRAW : 59 LOSS : 608
# Total win rate : 35.390%
#  -- TOTAL Games WIN : 49650 DRAW : 8708 LOSS : 90642
# ========== Training : Episode  150000  ===========
# Recent 1000 games win rate :36.220%
#  -- 1000 Games WIN : 343 DRAW : 53 LOSS : 604
# Total win rate : 35.396%
#  -- TOTAL Games WIN : 49993 DRAW : 8761 LOSS : 91246
# ========== Training : Episode  151000  ===========
# Recent 1000 games win rate :32.869%
#  -- 1000 Games WIN : 307 DRAW : 66 LOSS : 627
# Total win rate : 35.379%
#  -- TOTAL Games WIN : 50300 DRAW : 8827 LOSS : 91873
# ========== Training : Episode  152000  ===========
# Recent 1000 games win rate :35.730%
#  -- 1000 Games WIN : 333 DRAW : 68 LOSS : 599
# Total win rate : 35.382%
#  -- TOTAL Games WIN : 50633 DRAW : 8895 LOSS : 92472
# ========== Training : Episode  153000  ===========
# Recent 1000 games win rate :34.952%
#  -- 1000 Games WIN : 331 DRAW : 53 LOSS : 616
# Total win rate : 35.379%
#  -- TOTAL Games WIN : 50964 DRAW : 8948 LOSS : 93088
# ========== Training : Episode  154000  ===========
# Recent 1000 games win rate :36.161%
#  -- 1000 Games WIN : 341 DRAW : 57 LOSS : 602
# Total win rate : 35.384%
#  -- TOTAL Games WIN : 51305 DRAW : 9005 LOSS : 93690
# ========== Training : Episode  155000  ===========
# Recent 1000 games win rate :36.786%
#  -- 1000 Games WIN : 348 DRAW : 54 LOSS : 598
# Total win rate : 35.393%
#  -- TOTAL Games WIN : 51653 DRAW : 9059 LOSS : 94288
# ========== Training : Episode  156000  ===========
# Recent 1000 games win rate :34.468%
#  -- 1000 Games WIN : 324 DRAW : 60 LOSS : 616
# Total win rate : 35.387%
#  -- TOTAL Games WIN : 51977 DRAW : 9119 LOSS : 94904
# ========== Training : Episode  157000  ===========
# Recent 1000 games win rate :36.791%
#  -- 1000 Games WIN : 344 DRAW : 65 LOSS : 591
# Total win rate : 35.396%
#  -- TOTAL Games WIN : 52321 DRAW : 9184 LOSS : 95495
# ========== Training : Episode  158000  ===========
# Recent 1000 games win rate :34.746%
#  -- 1000 Games WIN : 328 DRAW : 56 LOSS : 616
# Total win rate : 35.392%
#  -- TOTAL Games WIN : 52649 DRAW : 9240 LOSS : 96111
# ========== Training : Episode  159000  ===========
# Recent 1000 games win rate :35.480%
#  -- 1000 Games WIN : 336 DRAW : 53 LOSS : 611
# Total win rate : 35.392%
#  -- TOTAL Games WIN : 52985 DRAW : 9293 LOSS : 96722
# ========== Training : Episode  160000  ===========
# Recent 1000 games win rate :34.876%
#  -- 1000 Games WIN : 324 DRAW : 71 LOSS : 605
# Total win rate : 35.389%
#  -- TOTAL Games WIN : 53309 DRAW : 9364 LOSS : 97327
# ========== Training : Episode  161000  ===========
# Recent 1000 games win rate :37.261%
#  -- 1000 Games WIN : 351 DRAW : 58 LOSS : 591
# Total win rate : 35.401%
#  -- TOTAL Games WIN : 53660 DRAW : 9422 LOSS : 97918
# ========== Training : Episode  162000  ===========
# Recent 1000 games win rate :34.457%
#  -- 1000 Games WIN : 327 DRAW : 51 LOSS : 622
# Total win rate : 35.395%
#  -- TOTAL Games WIN : 53987 DRAW : 9473 LOSS : 98540
# ========== Training : Episode  163000  ===========
# Recent 1000 games win rate :39.293%
#  -- 1000 Games WIN : 367 DRAW : 66 LOSS : 567
# Total win rate : 35.419%
#  -- TOTAL Games WIN : 54354 DRAW : 9539 LOSS : 99107
# ========== Training : Episode  164000  ===========
# Recent 1000 games win rate :37.632%
#  -- 1000 Games WIN : 356 DRAW : 54 LOSS : 590
# Total win rate : 35.432%
#  -- TOTAL Games WIN : 54710 DRAW : 9593 LOSS : 99697
# ========== Training : Episode  165000  ===========
# Recent 1000 games win rate :37.738%
#  -- 1000 Games WIN : 357 DRAW : 54 LOSS : 589
# Total win rate : 35.446%
#  -- TOTAL Games WIN : 55067 DRAW : 9647 LOSS : 100286
# ========== Training : Episode  166000  ===========
# Recent 1000 games win rate :37.092%
#  -- 1000 Games WIN : 352 DRAW : 51 LOSS : 597
# Total win rate : 35.456%
#  -- TOTAL Games WIN : 55419 DRAW : 9698 LOSS : 100883
# ========== Training : Episode  167000  ===========
# Recent 1000 games win rate :35.875%
#  -- 1000 Games WIN : 334 DRAW : 69 LOSS : 597
# Total win rate : 35.459%
#  -- TOTAL Games WIN : 55753 DRAW : 9767 LOSS : 101480
# ========== Training : Episode  168000  ===========
# Recent 1000 games win rate :36.881%
#  -- 1000 Games WIN : 350 DRAW : 51 LOSS : 599
# Total win rate : 35.467%
#  -- TOTAL Games WIN : 56103 DRAW : 9818 LOSS : 102079
# ========== Training : Episode  169000  ===========
# Recent 1000 games win rate :33.617%
#  -- 1000 Games WIN : 316 DRAW : 60 LOSS : 624
# Total win rate : 35.456%
#  -- TOTAL Games WIN : 56419 DRAW : 9878 LOSS : 102703
# ========== Training : Episode  170000  ===========
# Recent 1000 games win rate :38.486%
#  -- 1000 Games WIN : 361 DRAW : 62 LOSS : 577
# Total win rate : 35.474%
#  -- TOTAL Games WIN : 56780 DRAW : 9940 LOSS : 103280
# ========== Training : Episode  171000  ===========
# Recent 1000 games win rate :34.358%
#  -- 1000 Games WIN : 324 DRAW : 57 LOSS : 619
# Total win rate : 35.468%
#  -- TOTAL Games WIN : 57104 DRAW : 9997 LOSS : 103899
# ========== Training : Episode  172000  ===========
# Recent 1000 games win rate :34.185%
#  -- 1000 Games WIN : 321 DRAW : 61 LOSS : 618
# Total win rate : 35.460%
#  -- TOTAL Games WIN : 57425 DRAW : 10058 LOSS : 104517
# ========== Training : Episode  173000  ===========
# Recent 1000 games win rate :34.017%
#  -- 1000 Games WIN : 315 DRAW : 74 LOSS : 611
# Total win rate : 35.452%
#  -- TOTAL Games WIN : 57740 DRAW : 10132 LOSS : 105128
# ========== Training : Episode  174000  ===========
# Recent 1000 games win rate :34.431%
#  -- 1000 Games WIN : 324 DRAW : 59 LOSS : 617
# Total win rate : 35.446%
#  -- TOTAL Games WIN : 58064 DRAW : 10191 LOSS : 105745
# ========== Training : Episode  175000  ===========
# Recent 1000 games win rate :34.677%
#  -- 1000 Games WIN : 327 DRAW : 57 LOSS : 616
# Total win rate : 35.442%
#  -- TOTAL Games WIN : 58391 DRAW : 10248 LOSS : 106361
# ========== Training : Episode  176000  ===========
# Recent 1000 games win rate :37.712%
#  -- 1000 Games WIN : 356 DRAW : 56 LOSS : 588
# Total win rate : 35.455%
#  -- TOTAL Games WIN : 58747 DRAW : 10304 LOSS : 106949
# ========== Training : Episode  177000  ===========
# Recent 1000 games win rate :38.015%
#  -- 1000 Games WIN : 360 DRAW : 53 LOSS : 587
# Total win rate : 35.469%
#  -- TOTAL Games WIN : 59107 DRAW : 10357 LOSS : 107536
# ========== Training : Episode  178000  ===========
# Recent 1000 games win rate :33.404%
#  -- 1000 Games WIN : 314 DRAW : 60 LOSS : 626
# Total win rate : 35.458%
#  -- TOTAL Games WIN : 59421 DRAW : 10417 LOSS : 108162
# ========== Training : Episode  179000  ===========
# Recent 1000 games win rate :34.183%
#  -- 1000 Games WIN : 322 DRAW : 58 LOSS : 620
# Total win rate : 35.451%
#  -- TOTAL Games WIN : 59743 DRAW : 10475 LOSS : 108782
# ========== Training : Episode  180000  ===========
# Recent 1000 games win rate :35.903%
#  -- 1000 Games WIN : 340 DRAW : 53 LOSS : 607
# Total win rate : 35.453%
#  -- TOTAL Games WIN : 60083 DRAW : 10528 LOSS : 109389
# ========== Training : Episode  181000  ===========
# Recent 1000 games win rate :36.720%
#  -- 1000 Games WIN : 347 DRAW : 55 LOSS : 598
# Total win rate : 35.460%
#  -- TOTAL Games WIN : 60430 DRAW : 10583 LOSS : 109987
# ========== Training : Episode  182000  ===========
# Recent 1000 games win rate :34.571%
#  -- 1000 Games WIN : 326 DRAW : 57 LOSS : 617
# Total win rate : 35.455%
#  -- TOTAL Games WIN : 60756 DRAW : 10640 LOSS : 110604
# ========== Training : Episode  183000  ===========
# Recent 1000 games win rate :35.069%
#  -- 1000 Games WIN : 330 DRAW : 59 LOSS : 611
# Total win rate : 35.453%
#  -- TOTAL Games WIN : 61086 DRAW : 10699 LOSS : 111215
# ========== Training : Episode  184000  ===========
# Recent 1000 games win rate :36.383%
#  -- 1000 Games WIN : 342 DRAW : 60 LOSS : 598
# Total win rate : 35.458%
#  -- TOTAL Games WIN : 61428 DRAW : 10759 LOSS : 111813
# ========== Training : Episode  185000  ===========
# Recent 1000 games win rate :34.362%
#  -- 1000 Games WIN : 323 DRAW : 60 LOSS : 617
# Total win rate : 35.452%
#  -- TOTAL Games WIN : 61751 DRAW : 10819 LOSS : 112430
# ========== Training : Episode  186000  ===========
# Recent 1000 games win rate :35.357%
#  -- 1000 Games WIN : 332 DRAW : 61 LOSS : 607
# Total win rate : 35.452%
#  -- TOTAL Games WIN : 62083 DRAW : 10880 LOSS : 113037
# ========== Training : Episode  187000  ===========
# Recent 1000 games win rate :35.232%
#  -- 1000 Games WIN : 334 DRAW : 52 LOSS : 614
# Total win rate : 35.451%
#  -- TOTAL Games WIN : 62417 DRAW : 10932 LOSS : 113651
# ========== Training : Episode  188000  ===========
# Recent 1000 games win rate :35.865%
#  -- 1000 Games WIN : 340 DRAW : 52 LOSS : 608
# Total win rate : 35.453%
#  -- TOTAL Games WIN : 62757 DRAW : 10984 LOSS : 114259
# ========== Training : Episode  189000  ===========
# Recent 1000 games win rate :35.630%
#  -- 1000 Games WIN : 331 DRAW : 71 LOSS : 598
# Total win rate : 35.454%
#  -- TOTAL Games WIN : 63088 DRAW : 11055 LOSS : 114857
# ========== Training : Episode  190000  ===========
# Recent 1000 games win rate :34.736%
#  -- 1000 Games WIN : 322 DRAW : 73 LOSS : 605
# Total win rate : 35.450%
#  -- TOTAL Games WIN : 63410 DRAW : 11128 LOSS : 115462
# ========== Training : Episode  191000  ===========
# Recent 1000 games win rate :34.607%
#  -- 1000 Games WIN : 326 DRAW : 58 LOSS : 616
# Total win rate : 35.446%
#  -- TOTAL Games WIN : 63736 DRAW : 11186 LOSS : 116078
# ========== Training : Episode  192000  ===========
# Recent 1000 games win rate :36.344%
#  -- 1000 Games WIN : 338 DRAW : 70 LOSS : 592
# Total win rate : 35.450%
#  -- TOTAL Games WIN : 64074 DRAW : 11256 LOSS : 116670
# ========== Training : Episode  193000  ===========
# Recent 1000 games win rate :32.907%
#  -- 1000 Games WIN : 309 DRAW : 61 LOSS : 630
# Total win rate : 35.437%
#  -- TOTAL Games WIN : 64383 DRAW : 11317 LOSS : 117300
# ========== Training : Episode  194000  ===========
# Recent 1000 games win rate :37.660%
#  -- 1000 Games WIN : 354 DRAW : 60 LOSS : 586
# Total win rate : 35.448%
#  -- TOTAL Games WIN : 64737 DRAW : 11377 LOSS : 117886
# ========== Training : Episode  195000  ===========
# Recent 1000 games win rate :35.528%
#  -- 1000 Games WIN : 340 DRAW : 43 LOSS : 617
# Total win rate : 35.449%
#  -- TOTAL Games WIN : 65077 DRAW : 11420 LOSS : 118503
# ========== Training : Episode  196000  ===========
# Recent 1000 games win rate :35.138%
#  -- 1000 Games WIN : 331 DRAW : 58 LOSS : 611
# Total win rate : 35.447%
#  -- TOTAL Games WIN : 65408 DRAW : 11478 LOSS : 119114
# ========== Training : Episode  197000  ===========
# Recent 1000 games win rate :36.190%
#  -- 1000 Games WIN : 342 DRAW : 55 LOSS : 603
# Total win rate : 35.451%
#  -- TOTAL Games WIN : 65750 DRAW : 11533 LOSS : 119717
# ========== Training : Episode  198000  ===========
# Recent 1000 games win rate :35.155%
#  -- 1000 Games WIN : 328 DRAW : 67 LOSS : 605
# Total win rate : 35.450%
#  -- TOTAL Games WIN : 66078 DRAW : 11600 LOSS : 120322
# ========== Training : Episode  199000  ===========
# Recent 1000 games win rate :35.213%
#  -- 1000 Games WIN : 331 DRAW : 60 LOSS : 609
# Total win rate : 35.448%
#  -- TOTAL Games WIN : 66409 DRAW : 11660 LOSS : 120931
# ========== Training : Episode  200000  ===========
# Recent 1000 games win rate :36.090%
#  -- 1000 Games WIN : 336 DRAW : 69 LOSS : 595
# Total win rate : 35.452%
#  -- TOTAL Games WIN : 66745 DRAW : 11729 LOSS : 121526
# ========== Training : Episode  201000  ===========
# Recent 1000 games win rate :34.316%
#  -- 1000 Games WIN : 326 DRAW : 50 LOSS : 624
# Total win rate : 35.446%
#  -- TOTAL Games WIN : 67071 DRAW : 11779 LOSS : 122150
# ========== Training : Episode  202000  ===========
# Recent 1000 games win rate :34.595%
#  -- 1000 Games WIN : 320 DRAW : 75 LOSS : 605
# Total win rate : 35.442%
#  -- TOTAL Games WIN : 67391 DRAW : 11854 LOSS : 122755
# ========== Training : Episode  203000  ===========
# Recent 1000 games win rate :34.289%
#  -- 1000 Games WIN : 323 DRAW : 58 LOSS : 619
# Total win rate : 35.436%
#  -- TOTAL Games WIN : 67714 DRAW : 11912 LOSS : 123374
# ========== Training : Episode  204000  ===========
# Recent 1000 games win rate :34.183%
#  -- 1000 Games WIN : 322 DRAW : 58 LOSS : 620
# Total win rate : 35.430%
#  -- TOTAL Games WIN : 68036 DRAW : 11970 LOSS : 123994
# ========== Training : Episode  205000  ===========
# Recent 1000 games win rate :35.730%
#  -- 1000 Games WIN : 333 DRAW : 68 LOSS : 599
# Total win rate : 35.431%
#  -- TOTAL Games WIN : 68369 DRAW : 12038 LOSS : 124593
# ========== Training : Episode  206000  ===========
# Recent 1000 games win rate :34.402%
#  -- 1000 Games WIN : 322 DRAW : 64 LOSS : 614
# Total win rate : 35.426%
#  -- TOTAL Games WIN : 68691 DRAW : 12102 LOSS : 125207
# ========== Training : Episode  207000  ===========
# Recent 1000 games win rate :33.897%
#  -- 1000 Games WIN : 321 DRAW : 53 LOSS : 626
# Total win rate : 35.419%
#  -- TOTAL Games WIN : 69012 DRAW : 12155 LOSS : 125833
# ========== Training : Episode  208000  ===========
# Recent 1000 games win rate :35.263%
#  -- 1000 Games WIN : 335 DRAW : 50 LOSS : 615
# Total win rate : 35.418%
#  -- TOTAL Games WIN : 69347 DRAW : 12205 LOSS : 126448
# ========== Training : Episode  209000  ===========
# Recent 1000 games win rate :37.780%
#  -- 1000 Games WIN : 354 DRAW : 63 LOSS : 583
# Total win rate : 35.429%
#  -- TOTAL Games WIN : 69701 DRAW : 12268 LOSS : 127031
# ========== Training : Episode  210000  ===========
# Recent 1000 games win rate :37.299%
#  -- 1000 Games WIN : 348 DRAW : 67 LOSS : 585
# Total win rate : 35.438%
#  -- TOTAL Games WIN : 70049 DRAW : 12335 LOSS : 127616
# ========== Training : Episode  211000  ===========
# Recent 1000 games win rate :34.388%
#  -- 1000 Games WIN : 326 DRAW : 52 LOSS : 622
# Total win rate : 35.433%
#  -- TOTAL Games WIN : 70375 DRAW : 12387 LOSS : 128238
# ========== Training : Episode  212000  ===========
# Recent 1000 games win rate :37.001%
#  -- 1000 Games WIN : 343 DRAW : 73 LOSS : 584
# Total win rate : 35.441%
#  -- TOTAL Games WIN : 70718 DRAW : 12460 LOSS : 128822
# ========== Training : Episode  213000  ===========
# Recent 1000 games win rate :38.445%
#  -- 1000 Games WIN : 361 DRAW : 61 LOSS : 578
# Total win rate : 35.455%
#  -- TOTAL Games WIN : 71079 DRAW : 12521 LOSS : 129400
# ========== Training : Episode  214000  ===========
# Recent 1000 games win rate :34.141%
#  -- 1000 Games WIN : 324 DRAW : 51 LOSS : 625
# Total win rate : 35.448%
#  -- TOTAL Games WIN : 71403 DRAW : 12572 LOSS : 130025
# ========== Training : Episode  215000  ===========
# Recent 1000 games win rate :34.801%
#  -- 1000 Games WIN : 332 DRAW : 46 LOSS : 622
# Total win rate : 35.445%
#  -- TOTAL Games WIN : 71735 DRAW : 12618 LOSS : 130647
# ========== Training : Episode  216000  ===========
# Recent 1000 games win rate :38.289%
#  -- 1000 Games WIN : 358 DRAW : 65 LOSS : 577
# Total win rate : 35.458%
#  -- TOTAL Games WIN : 72093 DRAW : 12683 LOSS : 131224
# ========== Training : Episode  217000  ===========
# Recent 1000 games win rate :33.650%
#  -- 1000 Games WIN : 319 DRAW : 52 LOSS : 629
# Total win rate : 35.450%
#  -- TOTAL Games WIN : 72412 DRAW : 12735 LOSS : 131853
# ========== Training : Episode  218000  ===========
# Recent 1000 games win rate :36.026%
#  -- 1000 Games WIN : 339 DRAW : 59 LOSS : 602
# Total win rate : 35.453%
#  -- TOTAL Games WIN : 72751 DRAW : 12794 LOSS : 132455
# ========== Training : Episode  219000  ===========
# Recent 1000 games win rate :34.899%
#  -- 1000 Games WIN : 327 DRAW : 63 LOSS : 610
# Total win rate : 35.450%
#  -- TOTAL Games WIN : 73078 DRAW : 12857 LOSS : 133065
# ========== Training : Episode  220000  ===========
# Recent 1000 games win rate :33.940%
#  -- 1000 Games WIN : 317 DRAW : 66 LOSS : 617
# Total win rate : 35.443%
#  -- TOTAL Games WIN : 73395 DRAW : 12923 LOSS : 133682
# ========== Training : Episode  221000  ===========
# Recent 1000 games win rate :34.072%
#  -- 1000 Games WIN : 323 DRAW : 52 LOSS : 625
# Total win rate : 35.437%
#  -- TOTAL Games WIN : 73718 DRAW : 12975 LOSS : 134307
# ========== Training : Episode  222000  ===========
# Recent 1000 games win rate :36.674%
#  -- 1000 Games WIN : 344 DRAW : 62 LOSS : 594
# Total win rate : 35.443%
#  -- TOTAL Games WIN : 74062 DRAW : 13037 LOSS : 134901
# ========== Training : Episode  223000  ===========
# Recent 1000 games win rate :35.037%
#  -- 1000 Games WIN : 329 DRAW : 61 LOSS : 610
# Total win rate : 35.441%
#  -- TOTAL Games WIN : 74391 DRAW : 13098 LOSS : 135511
# ========== Training : Episode  224000  ===========
# Recent 1000 games win rate :36.903%
#  -- 1000 Games WIN : 348 DRAW : 57 LOSS : 595
# Total win rate : 35.447%
#  -- TOTAL Games WIN : 74739 DRAW : 13155 LOSS : 136106
# ========== Training : Episode  225000  ===========
# Recent 1000 games win rate :36.354%
#  -- 1000 Games WIN : 341 DRAW : 62 LOSS : 597
# Total win rate : 35.451%
#  -- TOTAL Games WIN : 75080 DRAW : 13217 LOSS : 136703
# ========== Training : Episode  226000  ===========
# Recent 1000 games win rate :35.556%
#  -- 1000 Games WIN : 336 DRAW : 55 LOSS : 609
# Total win rate : 35.452%
#  -- TOTAL Games WIN : 75416 DRAW : 13272 LOSS : 137312
# ========== Training : Episode  227000  ===========
# Recent 1000 games win rate :35.021%
#  -- 1000 Games WIN : 332 DRAW : 52 LOSS : 616
# Total win rate : 35.450%
#  -- TOTAL Games WIN : 75748 DRAW : 13324 LOSS : 137928
# ========== Training : Episode  228000  ===========
# Recent 1000 games win rate :34.728%
#  -- 1000 Games WIN : 332 DRAW : 44 LOSS : 624
# Total win rate : 35.447%
# ...
# Recent 1000 games win rate :35.026%
#  -- 1000 Games WIN : 331 DRAW : 55 LOSS : 614
# Total win rate : 35.493%
#  -- TOTAL Games WIN : 309110 DRAW : 55087 LOSS : 561803
# ========== Training : Episode  927000  ===========
# Recent 1000 games win rate :35.805%
#  -- 1000 Games WIN : 338 DRAW : 56 LOSS : 606
# Total win rate : 35.493%
#  -- TOTAL Games WIN : 309448 DRAW : 55143 LOSS : 562409
# ========== Training : Episode  928000  ===========
# Recent 1000 games win rate :33.333%
#  -- 1000 Games WIN : 314 DRAW : 58 LOSS : 628
# Total win rate : 35.491%
#  -- TOTAL Games WIN : 309762 DRAW : 55201 LOSS : 563037
# ========== Training : Episode  929000  ===========
# Recent 1000 games win rate :37.381%
#  -- 1000 Games WIN : 354 DRAW : 53 LOSS : 593
# Total win rate : 35.493%
#  -- TOTAL Games WIN : 310116 DRAW : 55254 LOSS : 563630
# ========== Training : Episode  930000  ===========
# Recent 1000 games win rate :34.984%
#  -- 1000 Games WIN : 332 DRAW : 51 LOSS : 617
# Total win rate : 35.492%
#  -- TOTAL Games WIN : 310448 DRAW : 55305 LOSS : 564247
# ========== Training : Episode  931000  ===========
# Recent 1000 games win rate :35.439%
#  -- 1000 Games WIN : 331 DRAW : 66 LOSS : 603
# Total win rate : 35.492%
#  -- TOTAL Games WIN : 310779 DRAW : 55371 LOSS : 564850
# ========== Training : Episode  932000  ===========
# Recent 1000 games win rate :34.783%
#  -- 1000 Games WIN : 328 DRAW : 57 LOSS : 615
# Total win rate : 35.491%
#  -- TOTAL Games WIN : 311107 DRAW : 55428 LOSS : 565465
# ========== Training : Episode  933000  ===========
# Recent 1000 games win rate :34.727%
#  -- 1000 Games WIN : 324 DRAW : 67 LOSS : 609
# Total win rate : 35.491%
#  -- TOTAL Games WIN : 311431 DRAW : 55495 LOSS : 566074
# ========== Training : Episode  934000  ===========
# Recent 1000 games win rate :32.875%
#  -- 1000 Games WIN : 311 DRAW : 54 LOSS : 635
# Total win rate : 35.488%
#  -- TOTAL Games WIN : 311742 DRAW : 55549 LOSS : 566709
# ========== Training : Episode  935000  ===========
# Recent 1000 games win rate :36.614%
#  -- 1000 Games WIN : 346 DRAW : 55 LOSS : 599
# Total win rate : 35.489%
#  -- TOTAL Games WIN : 312088 DRAW : 55604 LOSS : 567308
# ========== Training : Episode  936000  ===========
# Recent 1000 games win rate :35.961%
#  -- 1000 Games WIN : 333 DRAW : 74 LOSS : 593
# Total win rate : 35.489%
#  -- TOTAL Games WIN : 312421 DRAW : 55678 LOSS : 567901
# ========== Training : Episode  937000  ===========
# Recent 1000 games win rate :36.383%
#  -- 1000 Games WIN : 338 DRAW : 71 LOSS : 591
# Total win rate : 35.490%
#  -- TOTAL Games WIN : 312759 DRAW : 55749 LOSS : 568492
# ========== Training : Episode  938000  ===========
# Recent 1000 games win rate :35.231%
#  -- 1000 Games WIN : 328 DRAW : 69 LOSS : 603
# Total win rate : 35.490%
#  -- TOTAL Games WIN : 313087 DRAW : 55818 LOSS : 569095
# ========== Training : Episode  939000  ===========
# Recent 1000 games win rate :35.376%
#  -- 1000 Games WIN : 329 DRAW : 70 LOSS : 601
# Total win rate : 35.490%
#  -- TOTAL Games WIN : 313416 DRAW : 55888 LOSS : 569696
# ========== Training : Episode  940000  ===========
# Recent 1000 games win rate :35.729%
#  -- 1000 Games WIN : 338 DRAW : 54 LOSS : 608
# Total win rate : 35.490%
#  -- TOTAL Games WIN : 313754 DRAW : 55942 LOSS : 570304
# ========== Training : Episode  941000  ===========
# Recent 1000 games win rate :37.381%
#  -- 1000 Games WIN : 354 DRAW : 53 LOSS : 593
# Total win rate : 35.492%
#  -- TOTAL Games WIN : 314108 DRAW : 55995 LOSS : 570897
# ========== Training : Episode  942000  ===========
# Recent 1000 games win rate :36.887%
#  -- 1000 Games WIN : 346 DRAW : 62 LOSS : 592
# Total win rate : 35.494%
#  -- TOTAL Games WIN : 314454 DRAW : 56057 LOSS : 571489
# ========== Training : Episode  943000  ===========
# Recent 1000 games win rate :32.694%
#  -- 1000 Games WIN : 307 DRAW : 61 LOSS : 632
# Total win rate : 35.491%
#  -- TOTAL Games WIN : 314761 DRAW : 56118 LOSS : 572121
# ========== Training : Episode  944000  ===========
# Recent 1000 games win rate :36.688%
#  -- 1000 Games WIN : 339 DRAW : 76 LOSS : 585
# Total win rate : 35.492%
#  -- TOTAL Games WIN : 315100 DRAW : 56194 LOSS : 572706
# ========== Training : Episode  945000  ===========
# Recent 1000 games win rate :36.757%
#  -- 1000 Games WIN : 340 DRAW : 75 LOSS : 585
# Total win rate : 35.493%
#  -- TOTAL Games WIN : 315440 DRAW : 56269 LOSS : 573291
# ========== Training : Episode  946000  ===========
# Recent 1000 games win rate :37.073%
#  -- 1000 Games WIN : 347 DRAW : 64 LOSS : 589
# Total win rate : 35.495%
#  -- TOTAL Games WIN : 315787 DRAW : 56333 LOSS : 573880
# ========== Training : Episode  947000  ===========
# Recent 1000 games win rate :36.393%
#  -- 1000 Games WIN : 341 DRAW : 63 LOSS : 596
# Total win rate : 35.496%
#  -- TOTAL Games WIN : 316128 DRAW : 56396 LOSS : 574476
# ========== Training : Episode  948000  ===========
# Recent 1000 games win rate :35.158%
#  -- 1000 Games WIN : 334 DRAW : 50 LOSS : 616
# Total win rate : 35.496%
#  -- TOTAL Games WIN : 316462 DRAW : 56446 LOSS : 575092
# ========== Training : Episode  949000  ===========
# Recent 1000 games win rate :34.755%
#  -- 1000 Games WIN : 326 DRAW : 62 LOSS : 612
# Total win rate : 35.495%
#  -- TOTAL Games WIN : 316788 DRAW : 56508 LOSS : 575704
# ========== Training : Episode  950000  ===========
# Recent 1000 games win rate :33.087%
#  -- 1000 Games WIN : 314 DRAW : 51 LOSS : 635
# Total win rate : 35.492%
#  -- TOTAL Games WIN : 317102 DRAW : 56559 LOSS : 576339
# ========== Training : Episode  951000  ===========
# Recent 1000 games win rate :36.179%
#  -- 1000 Games WIN : 339 DRAW : 63 LOSS : 598
# Total win rate : 35.493%
#  -- TOTAL Games WIN : 317441 DRAW : 56622 LOSS : 576937
# ========== Training : Episode  952000  ===========
# Recent 1000 games win rate :33.053%
#  -- 1000 Games WIN : 314 DRAW : 50 LOSS : 636
# Total win rate : 35.490%
#  -- TOTAL Games WIN : 317755 DRAW : 56672 LOSS : 577573
# ========== Training : Episode  953000  ===========
# Recent 1000 games win rate :35.069%
#  -- 1000 Games WIN : 330 DRAW : 59 LOSS : 611
# Total win rate : 35.490%
#  -- TOTAL Games WIN : 318085 DRAW : 56731 LOSS : 578184
# ========== Training : Episode  954000  ===========
# Recent 1000 games win rate :34.648%
#  -- 1000 Games WIN : 325 DRAW : 62 LOSS : 613
# Total win rate : 35.489%
#  -- TOTAL Games WIN : 318410 DRAW : 56793 LOSS : 578797
# ========== Training : Episode  955000  ===========
# Recent 1000 games win rate :32.412%
#  -- 1000 Games WIN : 305 DRAW : 59 LOSS : 636
# Total win rate : 35.486%
#  -- TOTAL Games WIN : 318715 DRAW : 56852 LOSS : 579433
# ========== Training : Episode  956000  ===========
# Recent 1000 games win rate :34.916%
#  -- 1000 Games WIN : 331 DRAW : 52 LOSS : 617
# Total win rate : 35.485%
#  -- TOTAL Games WIN : 319046 DRAW : 56904 LOSS : 580050
# ========== Training : Episode  957000  ===========
# Recent 1000 games win rate :37.301%
#  -- 1000 Games WIN : 351 DRAW : 59 LOSS : 590
# Total win rate : 35.487%
#  -- TOTAL Games WIN : 319397 DRAW : 56963 LOSS : 580640
# ========== Training : Episode  958000  ===========
# Recent 1000 games win rate :38.812%
#  -- 1000 Games WIN : 366 DRAW : 57 LOSS : 577
# Total win rate : 35.491%
#  -- TOTAL Games WIN : 319763 DRAW : 57020 LOSS : 581217
# ========== Training : Episode  959000  ===========
# Recent 1000 games win rate :35.983%
#  -- 1000 Games WIN : 344 DRAW : 44 LOSS : 612
# Total win rate : 35.491%
#  -- TOTAL Games WIN : 320107 DRAW : 57064 LOSS : 581829
# ========== Training : Episode  960000  ===========
# Recent 1000 games win rate :34.921%
#  -- 1000 Games WIN : 330 DRAW : 55 LOSS : 615
# Total win rate : 35.491%
#  -- TOTAL Games WIN : 320437 DRAW : 57119 LOSS : 582444
# ========== Training : Episode  961000  ===========
# Recent 1000 games win rate :36.943%
#  -- 1000 Games WIN : 348 DRAW : 58 LOSS : 594
# Total win rate : 35.492%
#  -- TOTAL Games WIN : 320785 DRAW : 57177 LOSS : 583038
# ========== Training : Episode  962000  ===========
# Recent 1000 games win rate :39.158%
#  -- 1000 Games WIN : 372 DRAW : 50 LOSS : 578
# Total win rate : 35.496%
#  -- TOTAL Games WIN : 321157 DRAW : 57227 LOSS : 583616
# ========== Training : Episode  963000  ===========
# Recent 1000 games win rate :36.998%
#  -- 1000 Games WIN : 350 DRAW : 54 LOSS : 596
# Total win rate : 35.497%
#  -- TOTAL Games WIN : 321507 DRAW : 57281 LOSS : 584212
# ========== Training : Episode  964000  ===========
# Recent 1000 games win rate :33.976%
#  -- 1000 Games WIN : 317 DRAW : 67 LOSS : 616
# Total win rate : 35.496%
#  -- TOTAL Games WIN : 321824 DRAW : 57348 LOSS : 584828
# ========== Training : Episode  965000  ===========
# Recent 1000 games win rate :37.581%
#  -- 1000 Games WIN : 348 DRAW : 74 LOSS : 578
# Total win rate : 35.498%
#  -- TOTAL Games WIN : 322172 DRAW : 57422 LOSS : 585406
# ========== Training : Episode  966000  ===========
# Recent 1000 games win rate :35.401%
#  -- 1000 Games WIN : 331 DRAW : 65 LOSS : 604
# Total win rate : 35.498%
#  -- TOTAL Games WIN : 322503 DRAW : 57487 LOSS : 586010
# ========== Training : Episode  967000  ===========
# Recent 1000 games win rate :32.869%
#  -- 1000 Games WIN : 307 DRAW : 66 LOSS : 627
# Total win rate : 35.495%
#  -- TOTAL Games WIN : 322810 DRAW : 57553 LOSS : 586637
# ========== Training : Episode  968000  ===========
# Recent 1000 games win rate :37.815%
#  -- 1000 Games WIN : 360 DRAW : 48 LOSS : 592
# Total win rate : 35.498%
#  -- TOTAL Games WIN : 323170 DRAW : 57601 LOSS : 587229
# ========== Training : Episode  969000  ===========
# Recent 1000 games win rate :34.283%
#  -- 1000 Games WIN : 325 DRAW : 52 LOSS : 623
# Total win rate : 35.496%
#  -- TOTAL Games WIN : 323495 DRAW : 57653 LOSS : 587852
# ========== Training : Episode  970000  ===========
# Recent 1000 games win rate :37.301%
#  -- 1000 Games WIN : 351 DRAW : 59 LOSS : 590
# Total win rate : 35.498%
#  -- TOTAL Games WIN : 323846 DRAW : 57712 LOSS : 588442
# ========== Training : Episode  971000  ===========
# Recent 1000 games win rate :35.256%
#  -- 1000 Games WIN : 330 DRAW : 64 LOSS : 606
# Total win rate : 35.498%
#  -- TOTAL Games WIN : 324176 DRAW : 57776 LOSS : 589048
# ========== Training : Episode  972000  ===========
# Recent 1000 games win rate :35.615%
#  -- 1000 Games WIN : 333 DRAW : 65 LOSS : 602
# Total win rate : 35.498%
#  -- TOTAL Games WIN : 324509 DRAW : 57841 LOSS : 589650
# ========== Training : Episode  973000  ===========
# Recent 1000 games win rate :36.557%
#  -- 1000 Games WIN : 344 DRAW : 59 LOSS : 597
# Total win rate : 35.499%
#  -- TOTAL Games WIN : 324853 DRAW : 57900 LOSS : 590247
# ========== Training : Episode  974000  ===========
# Recent 1000 games win rate :37.222%
#  -- 1000 Games WIN : 351 DRAW : 57 LOSS : 592
# Total win rate : 35.501%
#  -- TOTAL Games WIN : 325204 DRAW : 57957 LOSS : 590839
# ========== Training : Episode  975000  ===========
# Recent 1000 games win rate :33.761%
#  -- 1000 Games WIN : 316 DRAW : 64 LOSS : 620
# Total win rate : 35.499%
#  -- TOTAL Games WIN : 325520 DRAW : 58021 LOSS : 591459
# ========== Training : Episode  976000  ===========
# Recent 1000 games win rate :33.052%
#  -- 1000 Games WIN : 313 DRAW : 53 LOSS : 634
# Total win rate : 35.497%
#  -- TOTAL Games WIN : 325833 DRAW : 58074 LOSS : 592093
# ========== Training : Episode  977000  ===========
# Recent 1000 games win rate :32.906%
#  -- 1000 Games WIN : 308 DRAW : 64 LOSS : 628
# Total win rate : 35.494%
#  -- TOTAL Games WIN : 326141 DRAW : 58138 LOSS : 592721
# ========== Training : Episode  978000  ===========
# Recent 1000 games win rate :32.447%
#  -- 1000 Games WIN : 305 DRAW : 60 LOSS : 635
# Total win rate : 35.491%
#  -- TOTAL Games WIN : 326446 DRAW : 58198 LOSS : 593356
# ========== Training : Episode  979000  ===========
# Recent 1000 games win rate :33.508%
#  -- 1000 Games WIN : 319 DRAW : 48 LOSS : 633
# Total win rate : 35.489%
#  -- TOTAL Games WIN : 326765 DRAW : 58246 LOSS : 593989
# ========== Training : Episode  980000  ===========
# Recent 1000 games win rate :36.334%
#  -- 1000 Games WIN : 335 DRAW : 78 LOSS : 587
# Total win rate : 35.490%
#  -- TOTAL Games WIN : 327100 DRAW : 58324 LOSS : 594576
# ========== Training : Episode  981000  ===========
# Recent 1000 games win rate :36.950%
#  -- 1000 Games WIN : 344 DRAW : 69 LOSS : 587
# Total win rate : 35.491%
#  -- TOTAL Games WIN : 327444 DRAW : 58393 LOSS : 595163
# ========== Training : Episode  982000  ===========
# Recent 1000 games win rate :35.797%
#  -- 1000 Games WIN : 339 DRAW : 53 LOSS : 608
# Total win rate : 35.491%
#  -- TOTAL Games WIN : 327783 DRAW : 58446 LOSS : 595771
# ========== Training : Episode  983000  ===========
# Recent 1000 games win rate :37.288%
#  -- 1000 Games WIN : 352 DRAW : 56 LOSS : 592
# Total win rate : 35.493%
#  -- TOTAL Games WIN : 328135 DRAW : 58502 LOSS : 596363
# ========== Training : Episode  984000  ===========
# Recent 1000 games win rate :36.603%
#  -- 1000 Games WIN : 347 DRAW : 52 LOSS : 601
# Total win rate : 35.494%
#  -- TOTAL Games WIN : 328482 DRAW : 58554 LOSS : 596964
# ========== Training : Episode  985000  ===========
# Recent 1000 games win rate :37.829%
#  -- 1000 Games WIN : 359 DRAW : 51 LOSS : 590
# Total win rate : 35.497%
#  -- TOTAL Games WIN : 328841 DRAW : 58605 LOSS : 597554
# ========== Training : Episode  986000  ===========
# Recent 1000 games win rate :35.692%
#  -- 1000 Games WIN : 338 DRAW : 53 LOSS : 609
# Total win rate : 35.497%
#  -- TOTAL Games WIN : 329179 DRAW : 58658 LOSS : 598163
# ========== Training : Episode  987000  ===========
# Recent 1000 games win rate :33.651%
#  -- 1000 Games WIN : 318 DRAW : 55 LOSS : 627
# Total win rate : 35.495%
#  -- TOTAL Games WIN : 329497 DRAW : 58713 LOSS : 598790
# ========== Training : Episode  988000  ===========
# Recent 1000 games win rate :37.010%
#  -- 1000 Games WIN : 349 DRAW : 57 LOSS : 594
# Total win rate : 35.497%
#  -- TOTAL Games WIN : 329846 DRAW : 58770 LOSS : 599384
# ========== Training : Episode  989000  ===========
# Recent 1000 games win rate :36.129%
#  -- 1000 Games WIN : 336 DRAW : 70 LOSS : 594
# Total win rate : 35.497%
#  -- TOTAL Games WIN : 330182 DRAW : 58840 LOSS : 599978
# ========== Training : Episode  990000  ===========
# Recent 1000 games win rate :37.155%
#  -- 1000 Games WIN : 350 DRAW : 58 LOSS : 592
# Total win rate : 35.499%
#  -- TOTAL Games WIN : 330532 DRAW : 58898 LOSS : 600570
# ========== Training : Episode  991000  ===========
# Recent 1000 games win rate :37.095%
#  -- 1000 Games WIN : 355 DRAW : 43 LOSS : 602
# Total win rate : 35.501%
#  -- TOTAL Games WIN : 330887 DRAW : 58941 LOSS : 601172
# ========== Training : Episode  992000  ===========
# Recent 1000 games win rate :35.752%
#  -- 1000 Games WIN : 335 DRAW : 63 LOSS : 602
# Total win rate : 35.501%
#  -- TOTAL Games WIN : 331222 DRAW : 59004 LOSS : 601774
# ========== Training : Episode  993000  ===========
# Recent 1000 games win rate :34.968%
#  -- 1000 Games WIN : 328 DRAW : 62 LOSS : 610
# Total win rate : 35.500%
#  -- TOTAL Games WIN : 331550 DRAW : 59066 LOSS : 602384
# ========== Training : Episode  994000  ===========
# Recent 1000 games win rate :35.714%
#  -- 1000 Games WIN : 335 DRAW : 62 LOSS : 603
# Total win rate : 35.501%
#  -- TOTAL Games WIN : 331885 DRAW : 59128 LOSS : 602987
# ========== Training : Episode  995000  ===========
# Recent 1000 games win rate :34.587%
#  -- 1000 Games WIN : 331 DRAW : 43 LOSS : 626
# Total win rate : 35.500%
#  -- TOTAL Games WIN : 332216 DRAW : 59171 LOSS : 603613
# ========== Training : Episode  996000  ===========
# Recent 1000 games win rate :34.472%
#  -- 1000 Games WIN : 323 DRAW : 63 LOSS : 614
# Total win rate : 35.499%
#  -- TOTAL Games WIN : 332539 DRAW : 59234 LOSS : 604227
# ========== Training : Episode  997000  ===========
# Recent 1000 games win rate :36.258%
#  -- 1000 Games WIN : 343 DRAW : 54 LOSS : 603
# Total win rate : 35.499%
#  -- TOTAL Games WIN : 332882 DRAW : 59288 LOSS : 604830
# ========== Training : Episode  998000  ===========
# Recent 1000 games win rate :33.688%
#  -- 1000 Games WIN : 317 DRAW : 59 LOSS : 624
# Total win rate : 35.498%
#  -- TOTAL Games WIN : 333199 DRAW : 59347 LOSS : 605454
# ========== Training : Episode  999000  ===========
# Recent 1000 games win rate :36.277%
#  -- 1000 Games WIN : 341 DRAW : 60 LOSS : 599
# Total win rate : 35.498%
#  -- TOTAL Games WIN : 333540 DRAW : 59407 LOSS : 606053
# ========== Training : Episode  1000000  ===========
# Recent 1000 games win rate :34.222%
#  -- 1000 Games WIN : 321 DRAW : 62 LOSS : 617
# Total win rate : 35.497%
#  -- TOTAL Games WIN : 333861 DRAW : 59469 LOSS : 606670

# %% [markdown]
# ## 8. 학습 결과 시각화

# %%
print("Q-value with Usable Ace")
plot_q_val(agent, usable_ace=True)
print("Q-value without Usable Ace")
plot_q_val(agent, usable_ace=False)
print("Optimal policy with Usable Ace : (RED : STICK, BLUE : HIT)")
usable_result = plot_action(agent, usable_ace=True)
print("Optimal policy without Usable Ace : (RED : STICK, BLUE : HIT)")
no_usable_result = plot_action(agent, usable_ace=False)
# Out:
# Q-value with Usable Ace
# Q-value without Usable Ace
# Optimal policy with Usable Ace : (RED : STICK, BLUE : HIT)
# Optimal policy without Usable Ace : (RED : STICK, BLUE : HIT)

# %% [markdown]
# ----
# ## 9. 과제
#
# ### 목표
# 위 코드로부터 최적 Policy를 학습시킨 Agent를 사용하여, 블랙잭 게임을 시뮬레이션한 뒤 승률을 계산.
#
# ### 초기 설정
#  - 플레이어는 1,000,000번의 에피소드로부터 최적 Policy를 학습
#  - 플레이어의 초기 자금 : 10,000 달러
#  - 플레이어는 게임 참가 시 10 달러를 지불, 결과에 따라 금액을 획득
#      - 승리 시 : 20 달러 획득
#      - 무승부 시 : 10 달러 획득
#      - 패배 시 : 0 달러 획득
#
# ### 요구사항
#  - 플레이어와 딜러가 1,000번의 게임을 진행
#  - 1,000번의 게임 후 플레이어의 승률을 계산
#  - 매 게임 별 플레이어의 소지금 변화를 그래프로 시각화
#
# #### * HINT : MonteCarlo 클래스의 generate_episode(), train() 메소드를 참고할 것
# ----
# ### (과제 1) 1,000번의 게임 진행

# %%
current_money = 10000
win_count = 0
lose_count = 0

money_list = []

#episode = list()    # 에피소드

for i in range (1000):
            current_money -= 10
          #  episode = mc_es.generate_episode(dealer, agent, deck)
         # agent.update_qval(episode)
            
            deck.reset()
            dealer.reset()
            agent.reset()

            # 딜러와 에이전트가 카드를 두장씩 뽑음
            dealer.hit(deck)
            dealer.hit(deck)
            agent.hit(deck)
            agent.hit(deck)
            
            dealer_one = dealer.show()
            
            done = False 
            money = 0
            
            while not done:
            # 에피소드가 끝날 때까지 State, Action, Reward를 생성
                sums = agent.calculate_sum()
                if sums < 12:
                    agent.hit(deck)
                    continue

                state = (sums, bool(agent.usable_ace), dealer.show())

                       
                action = agent.policy(state)
                done, reward = dealer.observation(action, agent, deck)  
                
            dealer.action(deck)
            
            done, reward = dealer.observation(action, agent, deck)# 에피소드 종료 여부, Reward 계산
            
            if (reward == 1):
                current_money += 20
                win_count += 1
            elif (reward == 0):
                current_money += 10
            elif (reward == -1):
                current_money  += 0
                lose_count += 1

   
            money_list.insert(i,current_money)
            
           # print("========== Training : Episode ", i, " ===========")



########################################################

# %% [markdown]
# ### (과제 2) 플레이어의 승률을 계산

# %%
############### 코드 작성 ##############################

 

winRate = win_count/(win_count+lose_count)

winRate

########################################################
# Out:
# 0.41039236479321317

# %% [markdown]
# ### (과제 3) 플레이어의 소지금 변화를 그래프로 시각화

# %%
############### 코드 작성 ##############################


plt.plot(money_list)
plt.show()



########################################################

# %% [markdown]
# ## 추가 과제 : 플레이어의 승률 높이기
# State를 수정하여 승률이 더 높은 policy를 찾기
#
# 기존 코드의 수정 필요
#  - 딜러는 게임이 끝났을 때, 남은 카드의 수를 확인
#  - 15장 이상이라면 해당 덱을 다음 게임에서 그대로 사용
#  - 15장 미만이라면 52장의 셔플된 새로운 카드를 기존 덱에 추가

# %%
class Dealer_2(object):
    """
    Dealer : 딜러 클래스
    딜러는 두 장의 카드를 받고, 카드의 합이 16 이하이면 Hit, 17이상이면 Stick 함.
    처음 두 장을 받았을 때 한 장의 카드를 랜덤하게 오픈함.
    """

    def __init__(self):
        """
        hand : 딜러가 가진 카드
        usable_ace : 딜러가 가진 카드 리스트 중 ace의 인덱스
        natural : 두 장의 카드로 21이 되면 True, 아니면 False
        """
        self.hands = list()
        self.usable_ace = list()

    def hit(self, deck: Deck):
        """
        딜러의 Hit. 새로운 카드가 Ace라면 사용 가능한 Ace 리스트에 추가함
        :param deck: Deck Object
        :return:
        """
        new_card = deck.draw()
        if new_card == 11:
            self.usable_ace.append(len(self.hands))
        self.hands.append(new_card)
        
        if new_card == 10 or 11 :
            deck.card_minus()
        elif new_card == 7 or 8 or 9 :
            pass
        else :
            deck.card_plus()
            

    def show(self):
        """
        딜러가 가진 카드 중 하나를 랜덤하게 보여줌
        :return: 딜러의 카드 중 랜덤한 카드 숫자
        """
        card = random.choice(self.hands)
        if card == 11:
            card = 1
        return card

    def calculate_sum(self):
        """
        딜러가 가진 카드의 합을 구함
        21을 넘을 때 사용 가능한 Ace가 있으면 사용함
        :return: 딜러 카드의 합
        """
        sums = sum(self.hands)
        if sums > 21 and len(self.usable_ace) > 0:
            self.hands[self.usable_ace.pop()] = 1
            sums = sum(self.hands)
        return sums

    def action(self, deck: Deck):
        """
        딜러의 순서 때 딜러의 행동.
        숫자의 합이 16 이하일 때는 Hit, 17 이상이면 Stick
        :param deck:
        :return:
        """
        while True:
            sums = self.calculate_sum()
            if sums < 17:
                self.hit(deck)
            else:
                return sums
            
            

    def observation(self, action, agent, deck):
        """
        플레이어의 Action을 받아, 그에 맞는 Observation과 Reward를 반환
        :param action: agent 의 Action
        :param agent: agent 클래스
        :param deck: deck 클래스
        :return: 에피소드 종료 여부, reward
        """
        done = False
        reward = 0
        if action == True:  # Hit
            agent.hit(deck)
            if agent.calculate_sum() > 21:  #플레이어의 Hit으로 인해 카드 합이 21이 넘으면 즉시 종료
                done = True
                reward = -1
        else:  # Stick
            done = True
            reward = self.calcuate_reward(agent, deck)

        return done, reward

    def calcuate_reward(self, agent, deck):
        """
        플레이어가 Stick했을 때 딜러와의 카드 비교 수행
        :param agent:
        :param deck:
        :return: Reward
        """
        agent_sum = agent.calculate_sum()           # 플레이어의 카드 합 계산
        if agent_sum > 21:                          # 플레이어의 Bust (패)
            return -1

        dealer_sum = self.action(deck)              # 딜러의 카드 합 계산
        if dealer_sum > 21:                         # 딜러가 Bust (승)
            return 1
        if dealer_sum > agent_sum:                  # 딜러의 카드 합 > 플레이어 합 (패)
            return -1
        if dealer_sum < agent_sum:                  # 딜러의 카드 합 < 플레이어 합 (승)
            return 1
        return 0                                   # 딜러의 카드 합 == 플레이어의 합 (무)

    def reset(self):
        """
        딜러 초기화 (새로운 에피소드 시작을 위해)
        """
        self.hands = list()
        self.usable_ace = list()

# %%
############### 코드 작성 ##############################


class Agent_2(object):
    def __init__(self):
        """
        hand : 플레이어의 카드
        usable_ace : 사용 가능한 ace 리스트
        Q_table : q(s,a) 값을 저장할 딕셔너리
        """
        self.hands = list()
        self.usable_ace = list()
        self.Q_table = dict()

    def hit(self, deck: Deck):
        """
        덱에서 새로운 카드를 뽑음
        :param deck: Deck for draw a card
        :return: None
        """
        new_card = deck.draw()
        if new_card == 11:
            self.usable_ace.append(len(self.hands))
        self.hands.append(new_card)
        
        if new_card == 10 or 11 :
            deck.card_minus()
        elif new_card == 7 or 8 or 9 :
            pass
        else :
            deck.card_plus()
            

    def calculate_sum(self):
        """
        플레이어가 가진 카드의 합을 구함.
        21을 넘을 때 사용 가능한 ace가 있으면 사용함
        :return:
        """
        sums = sum(self.hands)
        if sums > 21 and len(self.usable_ace) > 0:
            self.hands[self.usable_ace.pop()] = 1
            sums = sum(self.hands)
        return sums

    def random_action(self):
        """
        랜덤하게 행동 -> q값이 같으면!!!
        True = hit, False = stick
        :return:
        """
        return random.choice([True, False])

    def policy(self, state):
        """
        Agent의 policy 함수.
        e의 확률로 랜덤 행동을 하며, 그 외에는 현재 state에서 큰 q(s,a)값을 갖는 action을 선택함
        :param state: Agent에게 주어진 state
        :return: agent의 action을 반환 , True = hit and False = stick
    
        # Q_table에서 현재 state-action에 대해 값이 존재하는지 검사함
        for action in (True, False):
            if (state, action) not in self.Q_table.keys():  # Q_table에 값이 없으면 0으로 초기화
                self.Q_table[(state, action)] = [0, 0]      # (mean return, visit count)
            else:
                continue

        # q값이 큰 action 선택
        if self.Q_table[(state, True)] > self.Q_table[(state, False)]:
            return True     # Hit
        elif self.Q_table[(state, True)] == self.Q_table[(state, False)]:   # q값이 같으면 무작위추출
            return self.random_action()
        else:
            return False    # Stick
        """
        
        if deck.card_count() >= 0 :
            return True
        else :
            return False


    def reset(self):
        """
        Agent를 리셋함
        :return: None
        """
        self.hands = list()
        self.usable_ace = list()

    def update_qval(self, episode):
        """
        에피소드(한 번의 게임)으로부터 Q_table 을 업데이트함
        Q 테이블에 없는 state-action 쌍이 나오면 새로 생성
        Q 테이블에 state-action 쌍이 존재한다면 Incremental mean 적용하여 업데이트
        :param episode: Episode generated from environment
        :return: None
        """
        total_return = 0
        for state, action, reward in episode[::-1]:     # 에피소드의 뒤에서부터 (역순)
            total_return += reward                       # return Gt 계산
            if (state, action) not in self.Q_table.keys():  # state-action 쌍이 없다면
                self.Q_table[(state, action)] = [total_return, 1]   # 새롭게 엔트리 생성 (Gt, count)

            else:  #이미 존재하는 state-action 쌍이면 Incremental mean 적용
                prev_val = self.Q_table[(state, action)][0]         # 이전의 평균 return
                count = self.Q_table[(state, action)][1] + 1        # count 증가
                mean = prev_val + (total_return - prev_val) / count # 평균 계산 : Incremental Mean 적용
                self.Q_table[(state, action)] = [mean, count]  # 업데이트

########################################################

# %%
class MonteCarlo_2(object):
    def generate_episode(self, dealer: Dealer, agent: Agent, deck: Deck):
        """
        하나의 에피소드(게임)를 생성함
        :param dealer:
        :param agent:
        :param deck:
        :return:
        """
       # 15장 이상이라면 해당 덱을 다음 게임에서 그대로 사용
        #15장 미만이라면 52장의 셔플된 새로운 카드를 기존 덱에 추가
        
        # 카드 덱, 딜러, Agent를 초기화
        if deck.len() < 15 :
            deck.reset()

        dealer.reset()
        agent.reset()
        agent.hit(deck)
        agent.hit(deck)
        dealer.hit(deck)
        dealer.hit(deck)

        done = False    # 에피소드의 종료 여부

        episode = list()    # 에피소드

        while not done:
            # 에피소드가 끝날 때까지 State, Action, Reward를 생성
            sums = agent.calculate_sum()
            if sums < 12:
                agent.hit(deck)
                continue

            state = (sums, bool(agent.usable_ace), dealer.show())

            ########   Exploring Start ~!!!!!!!!! : 
            if len(episode) == 0:       # 첫번째 State 일 때는 무작위 Action 선택
                action =agent.random_action()
            else:                       # 그 외에는 Q 테이블에서 큰 값을 갖는 Action 선택
                action = agent.policy(state)
            
            done, reward = dealer.observation(action, agent, deck)  # 에피소드 종료 여부, Reward 계산
            
            # 생성된 State, Action, Reward를 에피소드에 추가
            episode.append([state, action, reward])

        return episode

    def train(self, dealer: Dealer, agent: Agent, deck: Deck, it=10000, verbose=True):
        count = 0
        win = 0
        loss = 0
        draw = 0
        total_win = 0
        total_loss = 0
        total_draw = 0
        result = str()
        for i in range(it):
            count += 1
            episode = self.generate_episode(dealer, agent, deck)
            agent.update_qval(episode)

            if episode[-1][-1] == 1:
                win += 1
            elif episode[-1][-1] == 0:
                draw += 1
            else:
                loss += 1

            if count % 1000 == 0 and verbose == True:
                total_win += win
                total_loss += loss
                total_draw += draw

                print("========== Training : Episode ", count, " ===========")
                print("Recent 1000 games win rate :{:.3f}%".format(win / (win + loss) * 100))
                print(" -- 1000 Games WIN :", win, "DRAW :", draw, "LOSS :", loss)
                print("Total win rate : {:.3f}%".format(total_win / (total_win + total_loss) * 100))
                print(" -- TOTAL Games WIN :", total_win, "DRAW :", total_draw, "LOSS :", total_loss)

                win = 0
                loss = 0
                draw = 0

# %%
deck = Deck()
dealer = Dealer_2()
agent = Agent_2()
mc_es2 = MonteCarlo_2()

mc_es2.train(dealer, agent, deck, it=1000000)
# Out:
# ========== Training : Episode  1000  ===========
# Recent 1000 games win rate :33.263%
#  -- 1000 Games WIN : 314 DRAW : 56 LOSS : 630
# Total win rate : 33.263%
#  -- TOTAL Games WIN : 314 DRAW : 56 LOSS : 630
# ========== Training : Episode  2000  ===========
# Recent 1000 games win rate :35.032%
#  -- 1000 Games WIN : 330 DRAW : 58 LOSS : 612
# Total win rate : 34.146%
#  -- TOTAL Games WIN : 644 DRAW : 114 LOSS : 1242
# ========== Training : Episode  3000  ===========
# Recent 1000 games win rate :32.585%
#  -- 1000 Games WIN : 305 DRAW : 64 LOSS : 631
# Total win rate : 33.629%
#  -- TOTAL Games WIN : 949 DRAW : 178 LOSS : 1873
# ========== Training : Episode  4000  ===========
# Recent 1000 games win rate :35.376%
#  -- 1000 Games WIN : 329 DRAW : 70 LOSS : 601
# Total win rate : 34.062%
#  -- TOTAL Games WIN : 1278 DRAW : 248 LOSS : 2474
# ========== Training : Episode  5000  ===========
# Recent 1000 games win rate :36.688%
#  -- 1000 Games WIN : 350 DRAW : 46 LOSS : 604
# Total win rate : 34.594%
#  -- TOTAL Games WIN : 1628 DRAW : 294 LOSS : 3078
# ========== Training : Episode  6000  ===========
# Recent 1000 games win rate :34.857%
#  -- 1000 Games WIN : 328 DRAW : 59 LOSS : 613
# Total win rate : 34.638%
#  -- TOTAL Games WIN : 1956 DRAW : 353 LOSS : 3691
# ========== Training : Episode  7000  ===========
# Recent 1000 games win rate :35.363%
#  -- 1000 Games WIN : 331 DRAW : 64 LOSS : 605
# Total win rate : 34.741%
#  -- TOTAL Games WIN : 2287 DRAW : 417 LOSS : 4296
# ========== Training : Episode  8000  ===========
# Recent 1000 games win rate :34.494%
#  -- 1000 Games WIN : 327 DRAW : 52 LOSS : 621
# Total win rate : 34.710%
#  -- TOTAL Games WIN : 2614 DRAW : 469 LOSS : 4917
# ========== Training : Episode  9000  ===========
# Recent 1000 games win rate :34.599%
#  -- 1000 Games WIN : 328 DRAW : 52 LOSS : 620
# Total win rate : 34.697%
#  -- TOTAL Games WIN : 2942 DRAW : 521 LOSS : 5537
# ========== Training : Episode  10000  ===========
# Recent 1000 games win rate :34.783%
#  -- 1000 Games WIN : 328 DRAW : 57 LOSS : 615
# Total win rate : 34.706%
#  -- TOTAL Games WIN : 3270 DRAW : 578 LOSS : 6152
# ========== Training : Episode  11000  ===========
# Recent 1000 games win rate :33.442%
#  -- 1000 Games WIN : 309 DRAW : 76 LOSS : 615
# Total win rate : 34.593%
#  -- TOTAL Games WIN : 3579 DRAW : 654 LOSS : 6767
# ========== Training : Episode  12000  ===========
# Recent 1000 games win rate :35.338%
#  -- 1000 Games WIN : 329 DRAW : 69 LOSS : 602
# Total win rate : 34.655%
#  -- TOTAL Games WIN : 3908 DRAW : 723 LOSS : 7369
# ========== Training : Episode  13000  ===========
# Recent 1000 games win rate :36.316%
#  -- 1000 Games WIN : 345 DRAW : 50 LOSS : 605
# Total win rate : 34.784%
#  -- TOTAL Games WIN : 4253 DRAW : 773 LOSS : 7974
# ========== Training : Episode  14000  ===========
# Recent 1000 games win rate :33.228%
#  -- 1000 Games WIN : 315 DRAW : 52 LOSS : 633
# Total win rate : 34.672%
#  -- TOTAL Games WIN : 4568 DRAW : 825 LOSS : 8607
# ========== Training : Episode  15000  ===========
# Recent 1000 games win rate :35.213%
#  -- 1000 Games WIN : 331 DRAW : 60 LOSS : 609
# Total win rate : 34.708%
#  -- TOTAL Games WIN : 4899 DRAW : 885 LOSS : 9216
# ========== Training : Episode  16000  ===========
# Recent 1000 games win rate :38.170%
#  -- 1000 Games WIN : 363 DRAW : 49 LOSS : 588
# Total win rate : 34.926%
#  -- TOTAL Games WIN : 5262 DRAW : 934 LOSS : 9804
# ========== Training : Episode  17000  ===========
# Recent 1000 games win rate :35.213%
#  -- 1000 Games WIN : 331 DRAW : 60 LOSS : 609
# Total win rate : 34.943%
#  -- TOTAL Games WIN : 5593 DRAW : 994 LOSS : 10413
# ========== Training : Episode  18000  ===========
# Recent 1000 games win rate :31.953%
#  -- 1000 Games WIN : 301 DRAW : 58 LOSS : 641
# Total win rate : 34.777%
#  -- TOTAL Games WIN : 5894 DRAW : 1052 LOSS : 11054
# ========== Training : Episode  19000  ===========
# Recent 1000 games win rate :36.518%
#  -- 1000 Games WIN : 344 DRAW : 58 LOSS : 598
# Total win rate : 34.869%
#  -- TOTAL Games WIN : 6238 DRAW : 1110 LOSS : 11652
# ========== Training : Episode  20000  ===========
# Recent 1000 games win rate :34.110%
#  -- 1000 Games WIN : 322 DRAW : 56 LOSS : 622
# Total win rate : 34.831%
#  -- TOTAL Games WIN : 6560 DRAW : 1166 LOSS : 12274
# ========== Training : Episode  21000  ===========
# Recent 1000 games win rate :37.080%
#  -- 1000 Games WIN : 353 DRAW : 48 LOSS : 599
# Total win rate : 34.939%
#  -- TOTAL Games WIN : 6913 DRAW : 1214 LOSS : 12873
# ========== Training : Episode  22000  ===========
# Recent 1000 games win rate :33.653%
#  -- 1000 Games WIN : 316 DRAW : 61 LOSS : 623
# Total win rate : 34.881%
#  -- TOTAL Games WIN : 7229 DRAW : 1275 LOSS : 13496
# ========== Training : Episode  23000  ===========
# Recent 1000 games win rate :35.141%
#  -- 1000 Games WIN : 337 DRAW : 41 LOSS : 622
# Total win rate : 34.892%
#  -- TOTAL Games WIN : 7566 DRAW : 1316 LOSS : 14118
# ========== Training : Episode  24000  ===========
# Recent 1000 games win rate :37.740%
#  -- 1000 Games WIN : 354 DRAW : 62 LOSS : 584
# Total win rate : 35.010%
#  -- TOTAL Games WIN : 7920 DRAW : 1378 LOSS : 14702
# ========== Training : Episode  25000  ===========
# Recent 1000 games win rate :35.300%
#  -- 1000 Games WIN : 335 DRAW : 51 LOSS : 614
# Total win rate : 35.022%
#  -- TOTAL Games WIN : 8255 DRAW : 1429 LOSS : 15316
# ========== Training : Episode  26000  ===========
# Recent 1000 games win rate :35.075%
#  -- 1000 Games WIN : 329 DRAW : 62 LOSS : 609
# Total win rate : 35.024%
#  -- TOTAL Games WIN : 8584 DRAW : 1491 LOSS : 15925
# ========== Training : Episode  27000  ===========
# Recent 1000 games win rate :36.181%
#  -- 1000 Games WIN : 343 DRAW : 52 LOSS : 605
# Total win rate : 35.067%
#  -- TOTAL Games WIN : 8927 DRAW : 1543 LOSS : 16530
# ========== Training : Episode  28000  ===========
# Recent 1000 games win rate :35.889%
#  -- 1000 Games WIN : 337 DRAW : 61 LOSS : 602
# Total win rate : 35.096%
#  -- TOTAL Games WIN : 9264 DRAW : 1604 LOSS : 17132
# ========== Training : Episode  29000  ===========
# Recent 1000 games win rate :36.209%
#  -- 1000 Games WIN : 340 DRAW : 61 LOSS : 599
# Total win rate : 35.134%
#  -- TOTAL Games WIN : 9604 DRAW : 1665 LOSS : 17731
# ========== Training : Episode  30000  ===========
# Recent 1000 games win rate :36.069%
#  -- 1000 Games WIN : 334 DRAW : 74 LOSS : 592
# Total win rate : 35.165%
#  -- TOTAL Games WIN : 9938 DRAW : 1739 LOSS : 18323
# ========== Training : Episode  31000  ===========
# Recent 1000 games win rate :33.757%
#  -- 1000 Games WIN : 319 DRAW : 55 LOSS : 626
# Total win rate : 35.119%
#  -- TOTAL Games WIN : 10257 DRAW : 1794 LOSS : 18949
# ========== Training : Episode  32000  ===========
# Recent 1000 games win rate :34.006%
#  -- 1000 Games WIN : 320 DRAW : 59 LOSS : 621
# Total win rate : 35.085%
#  -- TOTAL Games WIN : 10577 DRAW : 1853 LOSS : 19570
# ========== Training : Episode  33000  ===========
# Recent 1000 games win rate :33.120%
#  -- 1000 Games WIN : 311 DRAW : 61 LOSS : 628
# Total win rate : 35.025%
#  -- TOTAL Games WIN : 10888 DRAW : 1914 LOSS : 20198
# ========== Training : Episode  34000  ===========
# Recent 1000 games win rate :37.182%
#  -- 1000 Games WIN : 351 DRAW : 56 LOSS : 593
# Total win rate : 35.089%
#  -- TOTAL Games WIN : 11239 DRAW : 1970 LOSS : 20791
# ========== Training : Episode  35000  ===========
# Recent 1000 games win rate :38.356%
#  -- 1000 Games WIN : 364 DRAW : 51 LOSS : 585
# Total win rate : 35.183%
#  -- TOTAL Games WIN : 11603 DRAW : 2021 LOSS : 21376
# ========== Training : Episode  36000  ===========
# Recent 1000 games win rate :34.213%
#  -- 1000 Games WIN : 324 DRAW : 53 LOSS : 623
# Total win rate : 35.156%
#  -- TOTAL Games WIN : 11927 DRAW : 2074 LOSS : 21999
# ========== Training : Episode  37000  ===========
# Recent 1000 games win rate :38.291%
#  -- 1000 Games WIN : 363 DRAW : 52 LOSS : 585
# Total win rate : 35.241%
#  -- TOTAL Games WIN : 12290 DRAW : 2126 LOSS : 22584
# ========== Training : Episode  38000  ===========
# Recent 1000 games win rate :35.892%
#  -- 1000 Games WIN : 332 DRAW : 75 LOSS : 593
# Total win rate : 35.258%
#  -- TOTAL Games WIN : 12622 DRAW : 2201 LOSS : 23177
# ========== Training : Episode  39000  ===========
# Recent 1000 games win rate :34.603%
#  -- 1000 Games WIN : 327 DRAW : 55 LOSS : 618
# Total win rate : 35.241%
#  -- TOTAL Games WIN : 12949 DRAW : 2256 LOSS : 23795
# ========== Training : Episode  40000  ===========
# Recent 1000 games win rate :35.783%
#  -- 1000 Games WIN : 336 DRAW : 61 LOSS : 603
# Total win rate : 35.255%
#  -- TOTAL Games WIN : 13285 DRAW : 2317 LOSS : 24398
# ========== Training : Episode  41000  ===========
# Recent 1000 games win rate :36.132%
#  -- 1000 Games WIN : 340 DRAW : 59 LOSS : 601
# Total win rate : 35.276%
#  -- TOTAL Games WIN : 13625 DRAW : 2376 LOSS : 24999
# ========== Training : Episode  42000  ===========
# Recent 1000 games win rate :37.049%
#  -- 1000 Games WIN : 349 DRAW : 58 LOSS : 593
# Total win rate : 35.318%
#  -- TOTAL Games WIN : 13974 DRAW : 2434 LOSS : 25592
# ========== Training : Episode  43000  ===========
# Recent 1000 games win rate :35.881%
#  -- 1000 Games WIN : 338 DRAW : 58 LOSS : 604
# Total win rate : 35.331%
#  -- TOTAL Games WIN : 14312 DRAW : 2492 LOSS : 26196
# ========== Training : Episode  44000  ===========
# Recent 1000 games win rate :36.954%
#  -- 1000 Games WIN : 347 DRAW : 61 LOSS : 592
# Total win rate : 35.368%
#  -- TOTAL Games WIN : 14659 DRAW : 2553 LOSS : 26788
# ========== Training : Episode  45000  ===========
# Recent 1000 games win rate :35.300%
#  -- 1000 Games WIN : 335 DRAW : 51 LOSS : 614
# Total win rate : 35.367%
#  -- TOTAL Games WIN : 14994 DRAW : 2604 LOSS : 27402
# ========== Training : Episode  46000  ===========
# Recent 1000 games win rate :34.553%
#  -- 1000 Games WIN : 321 DRAW : 71 LOSS : 608
# Total win rate : 35.349%
#  -- TOTAL Games WIN : 15315 DRAW : 2675 LOSS : 28010
# ========== Training : Episode  47000  ===========
# Recent 1000 games win rate :34.958%
#  -- 1000 Games WIN : 330 DRAW : 56 LOSS : 614
# Total win rate : 35.341%
#  -- TOTAL Games WIN : 15645 DRAW : 2731 LOSS : 28624
# ========== Training : Episode  48000  ===========
# Recent 1000 games win rate :33.439%
#  -- 1000 Games WIN : 315 DRAW : 58 LOSS : 627
# Total win rate : 35.301%
#  -- TOTAL Games WIN : 15960 DRAW : 2789 LOSS : 29251
# ========== Training : Episode  49000  ===========
# Recent 1000 games win rate :35.563%
#  -- 1000 Games WIN : 335 DRAW : 58 LOSS : 607
# Total win rate : 35.306%
#  -- TOTAL Games WIN : 16295 DRAW : 2847 LOSS : 29858
# ========== Training : Episode  50000  ===========
# Recent 1000 games win rate :37.726%
#  -- 1000 Games WIN : 355 DRAW : 59 LOSS : 586
# Total win rate : 35.355%
#  -- TOTAL Games WIN : 16650 DRAW : 2906 LOSS : 30444
# ========== Training : Episode  51000  ===========
# Recent 1000 games win rate :34.995%
#  -- 1000 Games WIN : 330 DRAW : 57 LOSS : 613
# Total win rate : 35.348%
#  -- TOTAL Games WIN : 16980 DRAW : 2963 LOSS : 31057
# ========== Training : Episode  52000  ===========
# Recent 1000 games win rate :33.507%
#  -- 1000 Games WIN : 321 DRAW : 42 LOSS : 637
# Total win rate : 35.312%
#  -- TOTAL Games WIN : 17301 DRAW : 3005 LOSS : 31694
# ========== Training : Episode  53000  ===========
# Recent 1000 games win rate :35.394%
#  -- 1000 Games WIN : 332 DRAW : 62 LOSS : 606
# Total win rate : 35.313%
#  -- TOTAL Games WIN : 17633 DRAW : 3067 LOSS : 32300
# ========== Training : Episode  54000  ===========
# Recent 1000 games win rate :34.874%
#  -- 1000 Games WIN : 332 DRAW : 48 LOSS : 620
# Total win rate : 35.305%
#  -- TOTAL Games WIN : 17965 DRAW : 3115 LOSS : 32920
# ========== Training : Episode  55000  ===========
# Recent 1000 games win rate :34.820%
#  -- 1000 Games WIN : 328 DRAW : 58 LOSS : 614
# Total win rate : 35.296%
#  -- TOTAL Games WIN : 18293 DRAW : 3173 LOSS : 33534
# ========== Training : Episode  56000  ===========
# Recent 1000 games win rate :34.304%
#  -- 1000 Games WIN : 318 DRAW : 73 LOSS : 609
# Total win rate : 35.279%
#  -- TOTAL Games WIN : 18611 DRAW : 3246 LOSS : 34143
# ========== Training : Episode  57000  ===========
# Recent 1000 games win rate :36.737%
#  -- 1000 Games WIN : 349 DRAW : 50 LOSS : 601
# Total win rate : 35.305%
#  -- TOTAL Games WIN : 18960 DRAW : 3296 LOSS : 34744
# ========== Training : Episode  58000  ===========
# Recent 1000 games win rate :35.331%
#  -- 1000 Games WIN : 336 DRAW : 49 LOSS : 615
# Total win rate : 35.305%
#  -- TOTAL Games WIN : 19296 DRAW : 3345 LOSS : 35359
# ========== Training : Episode  59000  ===========
# Recent 1000 games win rate :35.410%
#  -- 1000 Games WIN : 341 DRAW : 37 LOSS : 622
# Total win rate : 35.307%
#  -- TOTAL Games WIN : 19637 DRAW : 3382 LOSS : 35981
# ========== Training : Episode  60000  ===========
# Recent 1000 games win rate :34.677%
#  -- 1000 Games WIN : 327 DRAW : 57 LOSS : 616
# Total win rate : 35.296%
#  -- TOTAL Games WIN : 19964 DRAW : 3439 LOSS : 36597
# ========== Training : Episode  61000  ===========
# Recent 1000 games win rate :33.546%
#  -- 1000 Games WIN : 316 DRAW : 58 LOSS : 626
# Total win rate : 35.268%
#  -- TOTAL Games WIN : 20280 DRAW : 3497 LOSS : 37223
# ========== Training : Episode  62000  ===========
# Recent 1000 games win rate :34.750%
#  -- 1000 Games WIN : 327 DRAW : 59 LOSS : 614
# Total win rate : 35.259%
#  -- TOTAL Games WIN : 20607 DRAW : 3556 LOSS : 37837
# ========== Training : Episode  63000  ===========
# Recent 1000 games win rate :33.474%
#  -- 1000 Games WIN : 317 DRAW : 53 LOSS : 630
# Total win rate : 35.231%
#  -- TOTAL Games WIN : 20924 DRAW : 3609 LOSS : 38467
# ========== Training : Episode  64000  ===========
# Recent 1000 games win rate :36.876%
#  -- 1000 Games WIN : 347 DRAW : 59 LOSS : 594
# Total win rate : 35.257%
#  -- TOTAL Games WIN : 21271 DRAW : 3668 LOSS : 39061
# ========== Training : Episode  65000  ===========
# Recent 1000 games win rate :34.040%
#  -- 1000 Games WIN : 321 DRAW : 57 LOSS : 622
# Total win rate : 35.238%
#  -- TOTAL Games WIN : 21592 DRAW : 3725 LOSS : 39683
# ========== Training : Episode  66000  ===========
# Recent 1000 games win rate :32.625%
#  -- 1000 Games WIN : 307 DRAW : 59 LOSS : 634
# Total win rate : 35.198%
#  -- TOTAL Games WIN : 21899 DRAW : 3784 LOSS : 40317
# ========== Training : Episode  67000  ===========
# Recent 1000 games win rate :34.405%
#  -- 1000 Games WIN : 321 DRAW : 67 LOSS : 612
# Total win rate : 35.187%
#  -- TOTAL Games WIN : 22220 DRAW : 3851 LOSS : 40929
# ========== Training : Episode  68000  ===========
# Recent 1000 games win rate :35.829%
#  -- 1000 Games WIN : 335 DRAW : 65 LOSS : 600
# Total win rate : 35.196%
#  -- TOTAL Games WIN : 22555 DRAW : 3916 LOSS : 41529
# ========== Training : Episode  69000  ===========
# Recent 1000 games win rate :36.316%
#  -- 1000 Games WIN : 345 DRAW : 50 LOSS : 605
# Total win rate : 35.212%
#  -- TOTAL Games WIN : 22900 DRAW : 3966 LOSS : 42134
# ========== Training : Episode  70000  ===========
# Recent 1000 games win rate :31.710%
#  -- 1000 Games WIN : 293 DRAW : 76 LOSS : 631
# Total win rate : 35.163%
#  -- TOTAL Games WIN : 23193 DRAW : 4042 LOSS : 42765
# ========== Training : Episode  71000  ===========
# Recent 1000 games win rate :33.546%
#  -- 1000 Games WIN : 316 DRAW : 58 LOSS : 626
# Total win rate : 35.141%
#  -- TOTAL Games WIN : 23509 DRAW : 4100 LOSS : 43391
# ========== Training : Episode  72000  ===========
# Recent 1000 games win rate :34.225%
#  -- 1000 Games WIN : 320 DRAW : 65 LOSS : 615
# Total win rate : 35.128%
#  -- TOTAL Games WIN : 23829 DRAW : 4165 LOSS : 44006
# ========== Training : Episode  73000  ===========
# Recent 1000 games win rate :35.005%
#  -- 1000 Games WIN : 328 DRAW : 63 LOSS : 609
# Total win rate : 35.126%
#  -- TOTAL Games WIN : 24157 DRAW : 4228 LOSS : 44615
# ========== Training : Episode  74000  ===========
# Recent 1000 games win rate :37.527%
#  -- 1000 Games WIN : 352 DRAW : 62 LOSS : 586
# Total win rate : 35.159%
#  -- TOTAL Games WIN : 24509 DRAW : 4290 LOSS : 45201
# ========== Training : Episode  75000  ===========
# Recent 1000 games win rate :35.525%
#  -- 1000 Games WIN : 335 DRAW : 57 LOSS : 608
# Total win rate : 35.163%
#  -- TOTAL Games WIN : 24844 DRAW : 4347 LOSS : 45809
# ========== Training : Episode  76000  ===========
# Recent 1000 games win rate :37.124%
#  -- 1000 Games WIN : 346 DRAW : 68 LOSS : 586
# Total win rate : 35.189%
#  -- TOTAL Games WIN : 25190 DRAW : 4415 LOSS : 46395
# ========== Training : Episode  77000  ===========
# Recent 1000 games win rate :35.110%
#  -- 1000 Games WIN : 336 DRAW : 43 LOSS : 621
# Total win rate : 35.188%
#  -- TOTAL Games WIN : 25526 DRAW : 4458 LOSS : 47016
# ========== Training : Episode  78000  ===========
# Recent 1000 games win rate :37.167%
#  -- 1000 Games WIN : 349 DRAW : 61 LOSS : 590
# Total win rate : 35.213%
#  -- TOTAL Games WIN : 25875 DRAW : 4519 LOSS : 47606
# ========== Training : Episode  79000  ===========
# Recent 1000 games win rate :30.606%
#  -- 1000 Games WIN : 288 DRAW : 59 LOSS : 653
# Total win rate : 35.155%
#  -- TOTAL Games WIN : 26163 DRAW : 4578 LOSS : 48259
# ========== Training : Episode  80000  ===========
# Recent 1000 games win rate :36.859%
#  -- 1000 Games WIN : 345 DRAW : 64 LOSS : 591
# Total win rate : 35.176%
#  -- TOTAL Games WIN : 26508 DRAW : 4642 LOSS : 48850
# ========== Training : Episode  81000  ===========
# Recent 1000 games win rate :35.556%
#  -- 1000 Games WIN : 336 DRAW : 55 LOSS : 609
# Total win rate : 35.181%
#  -- TOTAL Games WIN : 26844 DRAW : 4697 LOSS : 49459
# ========== Training : Episode  82000  ===========
# Recent 1000 games win rate :34.261%
#  -- 1000 Games WIN : 320 DRAW : 66 LOSS : 614
# Total win rate : 35.170%
#  -- TOTAL Games WIN : 27164 DRAW : 4763 LOSS : 50073
# ========== Training : Episode  83000  ===========
# Recent 1000 games win rate :36.073%
#  -- 1000 Games WIN : 338 DRAW : 63 LOSS : 599
# Total win rate : 35.180%
#  -- TOTAL Games WIN : 27502 DRAW : 4826 LOSS : 50672
# ========== Training : Episode  84000  ===========
# Recent 1000 games win rate :34.002%
#  -- 1000 Games WIN : 322 DRAW : 53 LOSS : 625
# Total win rate : 35.166%
#  -- TOTAL Games WIN : 27824 DRAW : 4879 LOSS : 51297
# ========== Training : Episode  85000  ===========
# Recent 1000 games win rate :33.929%
#  -- 1000 Games WIN : 323 DRAW : 48 LOSS : 629
# Total win rate : 35.152%
#  -- TOTAL Games WIN : 28147 DRAW : 4927 LOSS : 51926
# ========== Training : Episode  86000  ===========
# Recent 1000 games win rate :34.439%
#  -- 1000 Games WIN : 322 DRAW : 65 LOSS : 613
# Total win rate : 35.143%
#  -- TOTAL Games WIN : 28469 DRAW : 4992 LOSS : 52539
# ========== Training : Episode  87000  ===========
# Recent 1000 games win rate :35.484%
#  -- 1000 Games WIN : 330 DRAW : 70 LOSS : 600
# Total win rate : 35.147%
#  -- TOTAL Games WIN : 28799 DRAW : 5062 LOSS : 53139
# ========== Training : Episode  88000  ===========
# Recent 1000 games win rate :36.897%
#  -- 1000 Games WIN : 352 DRAW : 46 LOSS : 602
# Total win rate : 35.167%
#  -- TOTAL Games WIN : 29151 DRAW : 5108 LOSS : 53741
# ========== Training : Episode  89000  ===========
# Recent 1000 games win rate :37.173%
#  -- 1000 Games WIN : 355 DRAW : 45 LOSS : 600
# Total win rate : 35.190%
#  -- TOTAL Games WIN : 29506 DRAW : 5153 LOSS : 54341
# ========== Training : Episode  90000  ===========
# Recent 1000 games win rate :36.950%
#  -- 1000 Games WIN : 344 DRAW : 69 LOSS : 587
# Total win rate : 35.210%
#  -- TOTAL Games WIN : 29850 DRAW : 5222 LOSS : 54928
# ========== Training : Episode  91000  ===========
# Recent 1000 games win rate :33.618%
#  -- 1000 Games WIN : 315 DRAW : 63 LOSS : 622
# Total win rate : 35.192%
#  -- TOTAL Games WIN : 30165 DRAW : 5285 LOSS : 55550
# ========== Training : Episode  92000  ===========
# Recent 1000 games win rate :36.257%
#  -- 1000 Games WIN : 339 DRAW : 65 LOSS : 596
# Total win rate : 35.204%
#  -- TOTAL Games WIN : 30504 DRAW : 5350 LOSS : 56146
# ========== Training : Episode  93000  ===========
# Recent 1000 games win rate :38.116%
#  -- 1000 Games WIN : 356 DRAW : 66 LOSS : 578
# Total win rate : 35.235%
#  -- TOTAL Games WIN : 30860 DRAW : 5416 LOSS : 56724
# ========== Training : Episode  94000  ===========
# Recent 1000 games win rate :35.737%
#  -- 1000 Games WIN : 337 DRAW : 57 LOSS : 606
# Total win rate : 35.240%
#  -- TOTAL Games WIN : 31197 DRAW : 5473 LOSS : 57330
# ========== Training : Episode  95000  ===========
# Recent 1000 games win rate :34.620%
#  -- 1000 Games WIN : 323 DRAW : 67 LOSS : 610
# Total win rate : 35.234%
#  -- TOTAL Games WIN : 31520 DRAW : 5540 LOSS : 57940
# ========== Training : Episode  96000  ===========
# Recent 1000 games win rate :35.375%
#  -- 1000 Games WIN : 335 DRAW : 53 LOSS : 612
# Total win rate : 35.235%
#  -- TOTAL Games WIN : 31855 DRAW : 5593 LOSS : 58552
# ========== Training : Episode  97000  ===========
# Recent 1000 games win rate :34.526%
#  -- 1000 Games WIN : 328 DRAW : 50 LOSS : 622
# Total win rate : 35.228%
#  -- TOTAL Games WIN : 32183 DRAW : 5643 LOSS : 59174
# ========== Training : Episode  98000  ===========
# Recent 1000 games win rate :34.225%
#  -- 1000 Games WIN : 320 DRAW : 65 LOSS : 615
# Total win rate : 35.218%
#  -- TOTAL Games WIN : 32503 DRAW : 5708 LOSS : 59789
# ========== Training : Episode  99000  ===========
# Recent 1000 games win rate :36.853%
#  -- 1000 Games WIN : 342 DRAW : 72 LOSS : 586
# Total win rate : 35.234%
#  -- TOTAL Games WIN : 32845 DRAW : 5780 LOSS : 60375
# ========== Training : Episode  100000  ===========
# Recent 1000 games win rate :35.054%
#  -- 1000 Games WIN : 326 DRAW : 70 LOSS : 604
# Total win rate : 35.232%
#  -- TOTAL Games WIN : 33171 DRAW : 5850 LOSS : 60979
# ========== Training : Episode  101000  ===========
# Recent 1000 games win rate :36.393%
#  -- 1000 Games WIN : 341 DRAW : 63 LOSS : 596
# Total win rate : 35.244%
#  -- TOTAL Games WIN : 33512 DRAW : 5913 LOSS : 61575
# ========== Training : Episode  102000  ===========
# Recent 1000 games win rate :33.298%
#  -- 1000 Games WIN : 316 DRAW : 51 LOSS : 633
# Total win rate : 35.224%
#  -- TOTAL Games WIN : 33828 DRAW : 5964 LOSS : 62208
# ========== Training : Episode  103000  ===========
# Recent 1000 games win rate :34.038%
#  -- 1000 Games WIN : 322 DRAW : 54 LOSS : 624
# Total win rate : 35.213%
#  -- TOTAL Games WIN : 34150 DRAW : 6018 LOSS : 62832
# ========== Training : Episode  104000  ===========
# Recent 1000 games win rate :37.353%
#  -- 1000 Games WIN : 350 DRAW : 63 LOSS : 587
# Total win rate : 35.233%
#  -- TOTAL Games WIN : 34500 DRAW : 6081 LOSS : 63419
# ========== Training : Episode  105000  ===========
# Recent 1000 games win rate :35.263%
#  -- 1000 Games WIN : 335 DRAW : 50 LOSS : 615
# Total win rate : 35.233%
#  -- TOTAL Games WIN : 34835 DRAW : 6131 LOSS : 64034
# ========== Training : Episode  106000  ===========
# Recent 1000 games win rate :31.523%
#  -- 1000 Games WIN : 296 DRAW : 61 LOSS : 643
# Total win rate : 35.199%
#  -- TOTAL Games WIN : 35131 DRAW : 6192 LOSS : 64677
# ========== Training : Episode  107000  ===========
# Recent 1000 games win rate :36.029%
#  -- 1000 Games WIN : 343 DRAW : 48 LOSS : 609
# Total win rate : 35.206%
#  -- TOTAL Games WIN : 35474 DRAW : 6240 LOSS : 65286
# ========== Training : Episode  108000  ===========
# Recent 1000 games win rate :36.959%
#  -- 1000 Games WIN : 350 DRAW : 53 LOSS : 597
# Total win rate : 35.223%
#  -- TOTAL Games WIN : 35824 DRAW : 6293 LOSS : 65883
# ========== Training : Episode  109000  ===========
# Recent 1000 games win rate :39.297%
#  -- 1000 Games WIN : 369 DRAW : 61 LOSS : 570
# Total win rate : 35.260%
#  -- TOTAL Games WIN : 36193 DRAW : 6354 LOSS : 66453
# ========== Training : Episode  110000  ===========
# Recent 1000 games win rate :31.770%
#  -- 1000 Games WIN : 298 DRAW : 62 LOSS : 640
# Total win rate : 35.228%
#  -- TOTAL Games WIN : 36491 DRAW : 6416 LOSS : 67093
# ========== Training : Episode  111000  ===========
# Recent 1000 games win rate :36.782%
#  -- 1000 Games WIN : 352 DRAW : 43 LOSS : 605
# Total win rate : 35.243%
#  -- TOTAL Games WIN : 36843 DRAW : 6459 LOSS : 67698
# ========== Training : Episode  112000  ===========
# Recent 1000 games win rate :36.004%
#  -- 1000 Games WIN : 346 DRAW : 39 LOSS : 615
# Total win rate : 35.250%
#  -- TOTAL Games WIN : 37189 DRAW : 6498 LOSS : 68313
# ========== Training : Episode  113000  ===========
# Recent 1000 games win rate :37.393%
#  -- 1000 Games WIN : 350 DRAW : 64 LOSS : 586
# Total win rate : 35.268%
#  -- TOTAL Games WIN : 37539 DRAW : 6562 LOSS : 68899
# ========== Training : Episode  114000  ===========
# Recent 1000 games win rate :35.661%
#  -- 1000 Games WIN : 332 DRAW : 69 LOSS : 599
# Total win rate : 35.272%
#  -- TOTAL Games WIN : 37871 DRAW : 6631 LOSS : 69498
# ========== Training : Episode  115000  ===========
# Recent 1000 games win rate :34.889%
#  -- 1000 Games WIN : 329 DRAW : 57 LOSS : 614
# Total win rate : 35.268%
#  -- TOTAL Games WIN : 38200 DRAW : 6688 LOSS : 70112
# ========== Training : Episode  116000  ===========
# Recent 1000 games win rate :37.104%
#  -- 1000 Games WIN : 351 DRAW : 54 LOSS : 595
# Total win rate : 35.284%
#  -- TOTAL Games WIN : 38551 DRAW : 6742 LOSS : 70707
# ========== Training : Episode  117000  ===========
# Recent 1000 games win rate :34.829%
#  -- 1000 Games WIN : 326 DRAW : 64 LOSS : 610
# Total win rate : 35.281%
#  -- TOTAL Games WIN : 38877 DRAW : 6806 LOSS : 71317
# ========== Training : Episode  118000  ===========
# Recent 1000 games win rate :37.367%
#  -- 1000 Games WIN : 352 DRAW : 58 LOSS : 590
# Total win rate : 35.298%
#  -- TOTAL Games WIN : 39229 DRAW : 6864 LOSS : 71907
# ========== Training : Episode  119000  ===========
# Recent 1000 games win rate :35.370%
#  -- 1000 Games WIN : 330 DRAW : 67 LOSS : 603
# Total win rate : 35.299%
#  -- TOTAL Games WIN : 39559 DRAW : 6931 LOSS : 72510
# ========== Training : Episode  120000  ===========
# Recent 1000 games win rate :35.584%
#  -- 1000 Games WIN : 332 DRAW : 67 LOSS : 601
# Total win rate : 35.301%
#  -- TOTAL Games WIN : 39891 DRAW : 6998 LOSS : 73111
# ========== Training : Episode  121000  ===========
# Recent 1000 games win rate :37.049%
#  -- 1000 Games WIN : 349 DRAW : 58 LOSS : 593
# Total win rate : 35.316%
#  -- TOTAL Games WIN : 40240 DRAW : 7056 LOSS : 73704
# ========== Training : Episode  122000  ===========
# Recent 1000 games win rate :31.277%
#  -- 1000 Games WIN : 294 DRAW : 60 LOSS : 646
# Total win rate : 35.283%
#  -- TOTAL Games WIN : 40534 DRAW : 7116 LOSS : 74350
# ========== Training : Episode  123000  ===========
# Recent 1000 games win rate :33.862%
#  -- 1000 Games WIN : 320 DRAW : 55 LOSS : 625
# Total win rate : 35.271%
#  -- TOTAL Games WIN : 40854 DRAW : 7171 LOSS : 74975
# ========== Training : Episode  124000  ===========
# Recent 1000 games win rate :38.576%
#  -- 1000 Games WIN : 363 DRAW : 59 LOSS : 578
# Total win rate : 35.298%
#  -- TOTAL Games WIN : 41217 DRAW : 7230 LOSS : 75553
# ========== Training : Episode  125000  ===========
# Recent 1000 games win rate :37.061%
#  -- 1000 Games WIN : 348 DRAW : 61 LOSS : 591
# Total win rate : 35.312%
#  -- TOTAL Games WIN : 41565 DRAW : 7291 LOSS : 76144
# ========== Training : Episode  126000  ===========
# Recent 1000 games win rate :37.407%
#  -- 1000 Games WIN : 352 DRAW : 59 LOSS : 589
# Total win rate : 35.328%
#  -- TOTAL Games WIN : 41917 DRAW : 7350 LOSS : 76733
# ========== Training : Episode  127000  ===========
# Recent 1000 games win rate :33.583%
#  -- 1000 Games WIN : 314 DRAW : 65 LOSS : 621
# Total win rate : 35.315%
#  -- TOTAL Games WIN : 42231 DRAW : 7415 LOSS : 77354
# ========== Training : Episode  128000  ===========
# Recent 1000 games win rate :36.596%
#  -- 1000 Games WIN : 344 DRAW : 60 LOSS : 596
# Total win rate : 35.325%
#  -- TOTAL Games WIN : 42575 DRAW : 7475 LOSS : 77950
# ========== Training : Episode  129000  ===========
# Recent 1000 games win rate :35.463%
#  -- 1000 Games WIN : 333 DRAW : 61 LOSS : 606
# Total win rate : 35.326%
#  -- TOTAL Games WIN : 42908 DRAW : 7536 LOSS : 78556
# ========== Training : Episode  130000  ===========
# Recent 1000 games win rate :34.574%
#  -- 1000 Games WIN : 325 DRAW : 60 LOSS : 615
# Total win rate : 35.320%
#  -- TOTAL Games WIN : 43233 DRAW : 7596 LOSS : 79171
# ========== Training : Episode  131000  ===========
# Recent 1000 games win rate :35.257%
#  -- 1000 Games WIN : 336 DRAW : 47 LOSS : 617
# Total win rate : 35.319%
#  -- TOTAL Games WIN : 43569 DRAW : 7643 LOSS : 79788
# ========== Training : Episode  132000  ===========
# Recent 1000 games win rate :32.771%
#  -- 1000 Games WIN : 311 DRAW : 51 LOSS : 638
# Total win rate : 35.300%
#  -- TOTAL Games WIN : 43880 DRAW : 7694 LOSS : 80426
# ========== Training : Episode  133000  ===========
# Recent 1000 games win rate :33.689%
#  -- 1000 Games WIN : 316 DRAW : 62 LOSS : 622
# Total win rate : 35.288%
#  -- TOTAL Games WIN : 44196 DRAW : 7756 LOSS : 81048
# ========== Training : Episode  134000  ===========
# Recent 1000 games win rate :35.775%
#  -- 1000 Games WIN : 337 DRAW : 58 LOSS : 605
# Total win rate : 35.292%
#  -- TOTAL Games WIN : 44533 DRAW : 7814 LOSS : 81653
# ========== Training : Episode  135000  ===========
# Recent 1000 games win rate :33.835%
#  -- 1000 Games WIN : 315 DRAW : 69 LOSS : 616
# Total win rate : 35.281%
#  -- TOTAL Games WIN : 44848 DRAW : 7883 LOSS : 82269
# ========== Training : Episode  136000  ===========
# Recent 1000 games win rate :36.730%
#  -- 1000 Games WIN : 346 DRAW : 58 LOSS : 596
# Total win rate : 35.292%
#  -- TOTAL Games WIN : 45194 DRAW : 7941 LOSS : 82865
# ========== Training : Episode  137000  ===========
# Recent 1000 games win rate :34.002%
#  -- 1000 Games WIN : 322 DRAW : 53 LOSS : 625
# Total win rate : 35.282%
#  -- TOTAL Games WIN : 45516 DRAW : 7994 LOSS : 83490
# ========== Training : Episode  138000  ===========
# Recent 1000 games win rate :34.045%
#  -- 1000 Games WIN : 319 DRAW : 63 LOSS : 618
# Total win rate : 35.273%
#  -- TOTAL Games WIN : 45835 DRAW : 8057 LOSS : 84108
# ========== Training : Episode  139000  ===========
# Recent 1000 games win rate :36.892%
#  -- 1000 Games WIN : 349 DRAW : 54 LOSS : 597
# Total win rate : 35.285%
#  -- TOTAL Games WIN : 46184 DRAW : 8111 LOSS : 84705
# ========== Training : Episode  140000  ===========
# Recent 1000 games win rate :35.294%
#  -- 1000 Games WIN : 330 DRAW : 65 LOSS : 605
# Total win rate : 35.285%
#  -- TOTAL Games WIN : 46514 DRAW : 8176 LOSS : 85310
# ========== Training : Episode  141000  ===========
# Recent 1000 games win rate :34.036%
#  -- 1000 Games WIN : 323 DRAW : 51 LOSS : 626
# Total win rate : 35.276%
#  -- TOTAL Games WIN : 46837 DRAW : 8227 LOSS : 85936
# ========== Training : Episode  142000  ===========
# Recent 1000 games win rate :33.836%
#  -- 1000 Games WIN : 314 DRAW : 72 LOSS : 614
# Total win rate : 35.266%
#  -- TOTAL Games WIN : 47151 DRAW : 8299 LOSS : 86550
# ========== Training : Episode  143000  ===========
# Recent 1000 games win rate :33.190%
#  -- 1000 Games WIN : 309 DRAW : 69 LOSS : 622
# Total win rate : 35.252%
#  -- TOTAL Games WIN : 47460 DRAW : 8368 LOSS : 87172
# ========== Training : Episode  144000  ===========
# Recent 1000 games win rate :37.726%
#  -- 1000 Games WIN : 355 DRAW : 59 LOSS : 586
# Total win rate : 35.269%
#  -- TOTAL Games WIN : 47815 DRAW : 8427 LOSS : 87758
# ========== Training : Episode  145000  ===========
# Recent 1000 games win rate :37.526%
#  -- 1000 Games WIN : 355 DRAW : 54 LOSS : 591
# Total win rate : 35.284%
#  -- TOTAL Games WIN : 48170 DRAW : 8481 LOSS : 88349
# ========== Training : Episode  146000  ===========
# Recent 1000 games win rate :35.069%
#  -- 1000 Games WIN : 330 DRAW : 59 LOSS : 611
# Total win rate : 35.283%
#  -- TOTAL Games WIN : 48500 DRAW : 8540 LOSS : 88960
# ========== Training : Episode  147000  ===========
# Recent 1000 games win rate :32.909%
#  -- 1000 Games WIN : 310 DRAW : 58 LOSS : 632
# Total win rate : 35.267%
#  -- TOTAL Games WIN : 48810 DRAW : 8598 LOSS : 89592
# ========== Training : Episode  148000  ===========
# Recent 1000 games win rate :36.583%
#  -- 1000 Games WIN : 349 DRAW : 46 LOSS : 605
# Total win rate : 35.276%
#  -- TOTAL Games WIN : 49159 DRAW : 8644 LOSS : 90197
# ========== Training : Episode  149000  ===========
# Recent 1000 games win rate :38.405%
#  -- 1000 Games WIN : 366 DRAW : 47 LOSS : 587
# Total win rate : 35.297%
#  -- TOTAL Games WIN : 49525 DRAW : 8691 LOSS : 90784
# ========== Training : Episode  150000  ===========
# Recent 1000 games win rate :36.114%
#  -- 1000 Games WIN : 342 DRAW : 53 LOSS : 605
# Total win rate : 35.303%
#  -- TOTAL Games WIN : 49867 DRAW : 8744 LOSS : 91389
# ========== Training : Episode  151000  ===========
# Recent 1000 games win rate :38.275%
#  -- 1000 Games WIN : 364 DRAW : 49 LOSS : 587
# Total win rate : 35.322%
#  -- TOTAL Games WIN : 50231 DRAW : 8793 LOSS : 91976
# ========== Training : Episode  152000  ===========
# Recent 1000 games win rate :33.193%
#  -- 1000 Games WIN : 316 DRAW : 48 LOSS : 636
# Total win rate : 35.308%
#  -- TOTAL Games WIN : 50547 DRAW : 8841 LOSS : 92612
# ========== Training : Episode  153000  ===========
# Recent 1000 games win rate :38.675%
#  -- 1000 Games WIN : 362 DRAW : 64 LOSS : 574
# Total win rate : 35.330%
#  -- TOTAL Games WIN : 50909 DRAW : 8905 LOSS : 93186
# ========== Training : Episode  154000  ===========
# Recent 1000 games win rate :35.775%
#  -- 1000 Games WIN : 337 DRAW : 58 LOSS : 605
# Total win rate : 35.333%
#  -- TOTAL Games WIN : 51246 DRAW : 8963 LOSS : 93791
# ========== Training : Episode  155000  ===========
# Recent 1000 games win rate :36.306%
#  -- 1000 Games WIN : 342 DRAW : 58 LOSS : 600
# Total win rate : 35.339%
#  -- TOTAL Games WIN : 51588 DRAW : 9021 LOSS : 94391
# ========== Training : Episode  156000  ===========
# Recent 1000 games win rate :32.801%
#  -- 1000 Games WIN : 308 DRAW : 61 LOSS : 631
# Total win rate : 35.323%
#  -- TOTAL Games WIN : 51896 DRAW : 9082 LOSS : 95022
# ========== Training : Episode  157000  ===========
# Recent 1000 games win rate :34.871%
#  -- 1000 Games WIN : 325 DRAW : 68 LOSS : 607
# Total win rate : 35.320%
#  -- TOTAL Games WIN : 52221 DRAW : 9150 LOSS : 95629
# ========== Training : Episode  158000  ===========
# Recent 1000 games win rate :34.009%
#  -- 1000 Games WIN : 319 DRAW : 62 LOSS : 619
# Total win rate : 35.312%
#  -- TOTAL Games WIN : 52540 DRAW : 9212 LOSS : 96248
# ========== Training : Episode  159000  ===========
# Recent 1000 games win rate :34.805%
#  -- 1000 Games WIN : 331 DRAW : 49 LOSS : 620
# Total win rate : 35.309%
#  -- TOTAL Games WIN : 52871 DRAW : 9261 LOSS : 96868
# ========== Training : Episode  160000  ===========
# Recent 1000 games win rate :33.648%
#  -- 1000 Games WIN : 321 DRAW : 46 LOSS : 633
# Total win rate : 35.298%
#  -- TOTAL Games WIN : 53192 DRAW : 9307 LOSS : 97501
# ========== Training : Episode  161000  ===========
# Recent 1000 games win rate :35.193%
#  -- 1000 Games WIN : 328 DRAW : 68 LOSS : 604
# Total win rate : 35.298%
#  -- TOTAL Games WIN : 53520 DRAW : 9375 LOSS : 98105
# ========== Training : Episode  162000  ===========
# Recent 1000 games win rate :32.974%
#  -- 1000 Games WIN : 306 DRAW : 72 LOSS : 622
# Total win rate : 35.283%
#  -- TOTAL Games WIN : 53826 DRAW : 9447 LOSS : 98727
# ========== Training : Episode  163000  ===========
# Recent 1000 games win rate :36.266%
#  -- 1000 Games WIN : 338 DRAW : 68 LOSS : 594
# Total win rate : 35.289%
#  -- TOTAL Games WIN : 54164 DRAW : 9515 LOSS : 99321
# ========== Training : Episode  164000  ===========
# Recent 1000 games win rate :34.926%
#  -- 1000 Games WIN : 329 DRAW : 58 LOSS : 613
# Total win rate : 35.287%
#  -- TOTAL Games WIN : 54493 DRAW : 9573 LOSS : 99934
# ========== Training : Episode  165000  ===========
# Recent 1000 games win rate :36.970%
#  -- 1000 Games WIN : 349 DRAW : 56 LOSS : 595
# Total win rate : 35.297%
#  -- TOTAL Games WIN : 54842 DRAW : 9629 LOSS : 100529
# ========== Training : Episode  166000  ===========
# Recent 1000 games win rate :37.631%
#  -- 1000 Games WIN : 359 DRAW : 46 LOSS : 595
# Total win rate : 35.312%
#  -- TOTAL Games WIN : 55201 DRAW : 9675 LOSS : 101124
# ========== Training : Episode  167000  ===========
# Recent 1000 games win rate :37.500%
#  -- 1000 Games WIN : 351 DRAW : 64 LOSS : 585
# Total win rate : 35.325%
#  -- TOTAL Games WIN : 55552 DRAW : 9739 LOSS : 101709
# ========== Training : Episode  168000  ===========
# Recent 1000 games win rate :35.928%
#  -- 1000 Games WIN : 337 DRAW : 62 LOSS : 601
# Total win rate : 35.328%
#  -- TOTAL Games WIN : 55889 DRAW : 9801 LOSS : 102310
# ========== Training : Episode  169000  ===========
# Recent 1000 games win rate :34.395%
#  -- 1000 Games WIN : 324 DRAW : 58 LOSS : 618
# Total win rate : 35.323%
#  -- TOTAL Games WIN : 56213 DRAW : 9859 LOSS : 102928
# ========== Training : Episode  170000  ===========
# Recent 1000 games win rate :38.004%
#  -- 1000 Games WIN : 358 DRAW : 58 LOSS : 584
# Total win rate : 35.339%
#  -- TOTAL Games WIN : 56571 DRAW : 9917 LOSS : 103512
# ========== Training : Episode  171000  ===========
# Recent 1000 games win rate :35.129%
#  -- 1000 Games WIN : 326 DRAW : 72 LOSS : 602
# Total win rate : 35.337%
#  -- TOTAL Games WIN : 56897 DRAW : 9989 LOSS : 104114
# ========== Training : Episode  172000  ===========
# Recent 1000 games win rate :35.237%
#  -- 1000 Games WIN : 327 DRAW : 72 LOSS : 601
# Total win rate : 35.337%
#  -- TOTAL Games WIN : 57224 DRAW : 10061 LOSS : 104715
# ========== Training : Episode  173000  ===========
# Recent 1000 games win rate :33.830%
#  -- 1000 Games WIN : 318 DRAW : 60 LOSS : 622
# Total win rate : 35.328%
#  -- TOTAL Games WIN : 57542 DRAW : 10121 LOSS : 105337
# ========== Training : Episode  174000  ===========
# Recent 1000 games win rate :33.262%
#  -- 1000 Games WIN : 312 DRAW : 62 LOSS : 626
# Total win rate : 35.316%
#  -- TOTAL Games WIN : 57854 DRAW : 10183 LOSS : 105963
# ========== Training : Episode  175000  ===========
# Recent 1000 games win rate :35.426%
#  -- 1000 Games WIN : 333 DRAW : 60 LOSS : 607
# Total win rate : 35.317%
#  -- TOTAL Games WIN : 58187 DRAW : 10243 LOSS : 106570
# ========== Training : Episode  176000  ===========
# Recent 1000 games win rate :38.307%
#  -- 1000 Games WIN : 362 DRAW : 55 LOSS : 583
# Total win rate : 35.334%
#  -- TOTAL Games WIN : 58549 DRAW : 10298 LOSS : 107153
# ========== Training : Episode  177000  ===========
# Recent 1000 games win rate :39.024%
#  -- 1000 Games WIN : 368 DRAW : 57 LOSS : 575
# Total win rate : 35.355%
#  -- TOTAL Games WIN : 58917 DRAW : 10355 LOSS : 107728
# ========== Training : Episode  178000  ===========
# Recent 1000 games win rate :35.338%
#  -- 1000 Games WIN : 335 DRAW : 52 LOSS : 613
# Total win rate : 35.355%
#  -- TOTAL Games WIN : 59252 DRAW : 10407 LOSS : 108341
# ========== Training : Episode  179000  ===========
# Recent 1000 games win rate :34.884%
#  -- 1000 Games WIN : 330 DRAW : 54 LOSS : 616
# Total win rate : 35.352%
#  -- TOTAL Games WIN : 59582 DRAW : 10461 LOSS : 108957
# ========== Training : Episode  180000  ===========
# Recent 1000 games win rate :33.052%
#  -- 1000 Games WIN : 313 DRAW : 53 LOSS : 634
# Total win rate : 35.339%
#  -- TOTAL Games WIN : 59895 DRAW : 10514 LOSS : 109591
# ========== Training : Episode  181000  ===========
# Recent 1000 games win rate :37.460%
#  -- 1000 Games WIN : 354 DRAW : 55 LOSS : 591
# Total win rate : 35.351%
#  -- TOTAL Games WIN : 60249 DRAW : 10569 LOSS : 110182
# ========== Training : Episode  182000  ===========
# Recent 1000 games win rate :32.764%
#  -- 1000 Games WIN : 307 DRAW : 63 LOSS : 630
# Total win rate : 35.337%
#  -- TOTAL Games WIN : 60556 DRAW : 10632 LOSS : 110812
# ========== Training : Episode  183000  ===========
# Recent 1000 games win rate :35.132%
#  -- 1000 Games WIN : 332 DRAW : 55 LOSS : 613
# Total win rate : 35.336%
#  -- TOTAL Games WIN : 60888 DRAW : 10687 LOSS : 111425
# ========== Training : Episode  184000  ===========
# Recent 1000 games win rate :38.627%
#  -- 1000 Games WIN : 360 DRAW : 68 LOSS : 572
# Total win rate : 35.353%
#  -- TOTAL Games WIN : 61248 DRAW : 10755 LOSS : 111997
# ========== Training : Episode  185000  ===========
# Recent 1000 games win rate :32.799%
#  -- 1000 Games WIN : 307 DRAW : 64 LOSS : 629
# Total win rate : 35.340%
#  -- TOTAL Games WIN : 61555 DRAW : 10819 LOSS : 112626
# ========== Training : Episode  186000  ===========
# Recent 1000 games win rate :34.411%
#  -- 1000 Games WIN : 330 DRAW : 41 LOSS : 629
# Total win rate : 35.335%
#  -- TOTAL Games WIN : 61885 DRAW : 10860 LOSS : 113255
# ========== Training : Episode  187000  ===========
# Recent 1000 games win rate :32.381%
#  -- 1000 Games WIN : 306 DRAW : 55 LOSS : 639
# Total win rate : 35.319%
#  -- TOTAL Games WIN : 62191 DRAW : 10915 LOSS : 113894
# ========== Training : Episode  188000  ===========
# Recent 1000 games win rate :35.677%
#  -- 1000 Games WIN : 340 DRAW : 47 LOSS : 613
# Total win rate : 35.321%
#  -- TOTAL Games WIN : 62531 DRAW : 10962 LOSS : 114507
# ========== Training : Episode  189000  ===========
# Recent 1000 games win rate :34.129%
#  -- 1000 Games WIN : 329 DRAW : 36 LOSS : 635
# Total win rate : 35.314%
#  -- TOTAL Games WIN : 62860 DRAW : 10998 LOSS : 115142
# ========== Training : Episode  190000  ===========
# Recent 1000 games win rate :36.200%
#  -- 1000 Games WIN : 341 DRAW : 58 LOSS : 601
# Total win rate : 35.319%
#  -- TOTAL Games WIN : 63201 DRAW : 11056 LOSS : 115743
# ========== Training : Episode  191000  ===========
# Recent 1000 games win rate :37.170%
#  -- 1000 Games WIN : 352 DRAW : 53 LOSS : 595
# Total win rate : 35.329%
#  -- TOTAL Games WIN : 63553 DRAW : 11109 LOSS : 116338
# ========== Training : Episode  192000  ===========
# Recent 1000 games win rate :35.871%
#  -- 1000 Games WIN : 344 DRAW : 41 LOSS : 615
# Total win rate : 35.331%
#  -- TOTAL Games WIN : 63897 DRAW : 11150 LOSS : 116953
# ========== Training : Episode  193000  ===========
# Recent 1000 games win rate :34.623%
#  -- 1000 Games WIN : 331 DRAW : 44 LOSS : 625
# Total win rate : 35.328%
#  -- TOTAL Games WIN : 64228 DRAW : 11194 LOSS : 117578
# ========== Training : Episode  194000  ===========
# Recent 1000 games win rate :35.456%
#  -- 1000 Games WIN : 334 DRAW : 58 LOSS : 608
# Total win rate : 35.328%
#  -- TOTAL Games WIN : 64562 DRAW : 11252 LOSS : 118186
# ========== Training : Episode  195000  ===========
# Recent 1000 games win rate :31.013%
#  -- 1000 Games WIN : 294 DRAW : 52 LOSS : 654
# Total win rate : 35.306%
#  -- TOTAL Games WIN : 64856 DRAW : 11304 LOSS : 118840
# ========== Training : Episode  196000  ===========
# Recent 1000 games win rate :34.076%
#  -- 1000 Games WIN : 321 DRAW : 58 LOSS : 621
# Total win rate : 35.300%
#  -- TOTAL Games WIN : 65177 DRAW : 11362 LOSS : 119461
# ========== Training : Episode  197000  ===========
# Recent 1000 games win rate :34.783%
#  -- 1000 Games WIN : 328 DRAW : 57 LOSS : 615
# Total win rate : 35.297%
#  -- TOTAL Games WIN : 65505 DRAW : 11419 LOSS : 120076
# ========== Training : Episode  198000  ===========
# Recent 1000 games win rate :35.979%
#  -- 1000 Games WIN : 340 DRAW : 55 LOSS : 605
# Total win rate : 35.301%
#  -- TOTAL Games WIN : 65845 DRAW : 11474 LOSS : 120681
# ========== Training : Episode  199000  ===========
# Recent 1000 games win rate :30.860%
#  -- 1000 Games WIN : 287 DRAW : 70 LOSS : 643
# Total win rate : 35.279%
#  -- TOTAL Games WIN : 66132 DRAW : 11544 LOSS : 121324
# ========== Training : Episode  200000  ===========
# Recent 1000 games win rate :33.791%
#  -- 1000 Games WIN : 320 DRAW : 53 LOSS : 627
# Total win rate : 35.271%
#  -- TOTAL Games WIN : 66452 DRAW : 11597 LOSS : 121951
# ========== Training : Episode  201000  ===========
# Recent 1000 games win rate :35.518%
#  -- 1000 Games WIN : 336 DRAW : 54 LOSS : 610
# Total win rate : 35.272%
#  -- TOTAL Games WIN : 66788 DRAW : 11651 LOSS : 122561
# ========== Training : Episode  202000  ===========
# Recent 1000 games win rate :36.702%
#  -- 1000 Games WIN : 345 DRAW : 60 LOSS : 595
# Total win rate : 35.279%
#  -- TOTAL Games WIN : 67133 DRAW : 11711 LOSS : 123156
# ========== Training : Episode  203000  ===========
# Recent 1000 games win rate :35.518%
#  -- 1000 Games WIN : 336 DRAW : 54 LOSS : 610
# Total win rate : 35.281%
#  -- TOTAL Games WIN : 67469 DRAW : 11765 LOSS : 123766
# ========== Training : Episode  204000  ===========
# Recent 1000 games win rate :36.831%
#  -- 1000 Games WIN : 344 DRAW : 66 LOSS : 590
# Total win rate : 35.288%
#  -- TOTAL Games WIN : 67813 DRAW : 11831 LOSS : 124356
# ========== Training : Episode  205000  ===========
# Recent 1000 games win rate :37.738%
#  -- 1000 Games WIN : 357 DRAW : 54 LOSS : 589
# Total win rate : 35.300%
#  -- TOTAL Games WIN : 68170 DRAW : 11885 LOSS : 124945
# ========== Training : Episode  206000  ===========
# Recent 1000 games win rate :36.489%
#  -- 1000 Games WIN : 343 DRAW : 60 LOSS : 597
# Total win rate : 35.306%
#  -- TOTAL Games WIN : 68513 DRAW : 11945 LOSS : 125542
# ========== Training : Episode  207000  ===========
# Recent 1000 games win rate :37.339%
#  -- 1000 Games WIN : 348 DRAW : 68 LOSS : 584
# Total win rate : 35.316%
#  -- TOTAL Games WIN : 68861 DRAW : 12013 LOSS : 126126
# ========== Training : Episode  208000  ===========
# Recent 1000 games win rate :36.518%
#  -- 1000 Games WIN : 344 DRAW : 58 LOSS : 598
# Total win rate : 35.321%
#  -- TOTAL Games WIN : 69205 DRAW : 12071 LOSS : 126724
# ========== Training : Episode  209000  ===========
# Recent 1000 games win rate :34.778%
#  -- 1000 Games WIN : 329 DRAW : 54 LOSS : 617
# Total win rate : 35.319%
#  -- TOTAL Games WIN : 69534 DRAW : 12125 LOSS : 127341
# ========== Training : Episode  210000  ===========
# Recent 1000 games win rate :37.329%
#  -- 1000 Games WIN : 355 DRAW : 49 LOSS : 596
# Total win rate : 35.329%
#  -- TOTAL Games WIN : 69889 DRAW : 12174 LOSS : 127937
# ========== Training : Episode  211000  ===========
# Recent 1000 games win rate :34.904%
#  -- 1000 Games WIN : 326 DRAW : 66 LOSS : 608
# Total win rate : 35.327%
#  -- TOTAL Games WIN : 70215 DRAW : 12240 LOSS : 128545
# ========== Training : Episode  212000  ===========
# Recent 1000 games win rate :35.646%
#  -- 1000 Games WIN : 334 DRAW : 63 LOSS : 603
# Total win rate : 35.328%
#  -- TOTAL Games WIN : 70549 DRAW : 12303 LOSS : 129148
# ========== Training : Episode  213000  ===========
# Recent 1000 games win rate :35.631%
#  -- 1000 Games WIN : 336 DRAW : 57 LOSS : 607
# Total win rate : 35.329%
#  -- TOTAL Games WIN : 70885 DRAW : 12360 LOSS : 129755
# ========== Training : Episode  214000  ===========
# Recent 1000 games win rate :36.392%
#  -- 1000 Games WIN : 345 DRAW : 52 LOSS : 603
# Total win rate : 35.334%
#  -- TOTAL Games WIN : 71230 DRAW : 12412 LOSS : 130358
# ========== Training : Episode  215000  ===========
# Recent 1000 games win rate :34.571%
#  -- 1000 Games WIN : 326 DRAW : 57 LOSS : 617
# Total win rate : 35.331%
#  -- TOTAL Games WIN : 71556 DRAW : 12469 LOSS : 130975
# ========== Training : Episode  216000  ===========
# Recent 1000 games win rate :36.421%
#  -- 1000 Games WIN : 346 DRAW : 50 LOSS : 604
# Total win rate : 35.336%
#  -- TOTAL Games WIN : 71902 DRAW : 12519 LOSS : 131579
# ========== Training : Episode  217000  ===========
# Recent 1000 games win rate :35.150%
#  -- 1000 Games WIN : 329 DRAW : 64 LOSS : 607
# Total win rate : 35.335%
#  -- TOTAL Games WIN : 72231 DRAW : 12583 LOSS : 132186
# ========== Training : Episode  218000  ===========
# Recent 1000 games win rate :32.629%
#  -- 1000 Games WIN : 309 DRAW : 53 LOSS : 638
# Total win rate : 35.323%
#  -- TOTAL Games WIN : 72540 DRAW : 12636 LOSS : 132824
# ========== Training : Episode  219000  ===========
# Recent 1000 games win rate :34.595%
#  -- 1000 Games WIN : 329 DRAW : 49 LOSS : 622
# Total win rate : 35.319%
#  -- TOTAL Games WIN : 72869 DRAW : 12685 LOSS : 133446
# ========== Training : Episode  220000  ===========
# Recent 1000 games win rate :32.524%
#  -- 1000 Games WIN : 308 DRAW : 53 LOSS : 639
# Total win rate : 35.307%
#  -- TOTAL Games WIN : 73177 DRAW : 12738 LOSS : 134085
# ========== Training : Episode  221000  ===========
# Recent 1000 games win rate :30.671%
#  -- 1000 Games WIN : 288 DRAW : 61 LOSS : 651
# Total win rate : 35.286%
#  -- TOTAL Games WIN : 73465 DRAW : 12799 LOSS : 134736
# ========== Training : Episode  222000  ===========
# Recent 1000 games win rate :35.692%
#  -- 1000 Games WIN : 338 DRAW : 53 LOSS : 609
# Total win rate : 35.287%
#  -- TOTAL Games WIN : 73803 DRAW : 12852 LOSS : 135345
# ========== Training : Episode  223000  ===========
# Recent 1000 games win rate :34.563%
#  -- 1000 Games WIN : 328 DRAW : 51 LOSS : 621
# Total win rate : 35.284%
#  -- TOTAL Games WIN : 74131 DRAW : 12903 LOSS : 135966
# ========== Training : Episode  224000  ===========
# Recent 1000 games win rate :35.919%
#  -- 1000 Games WIN : 338 DRAW : 59 LOSS : 603
# Total win rate : 35.287%
#  -- TOTAL Games WIN : 74469 DRAW : 12962 LOSS : 136569
# ========== Training : Episode  225000  ===========
# Recent 1000 games win rate :35.436%
#  -- 1000 Games WIN : 337 DRAW : 49 LOSS : 614
# Total win rate : 35.288%
#  -- TOTAL Games WIN : 74806 DRAW : 13011 LOSS : 137183
# ========== Training : Episode  226000  ===========
# Recent 1000 games win rate :35.338%
#  -- 1000 Games WIN : 329 DRAW : 69 LOSS : 602
# Total win rate : 35.288%
#  -- TOTAL Games WIN : 75135 DRAW : 13080 LOSS : 137785
# ========== Training : Episode  227000  ===========
# Recent 1000 games win rate :34.352%
#  -- 1000 Games WIN : 326 DRAW : 51 LOSS : 623
# Total win rate : 35.284%
#  -- TOTAL Games WIN : 75461 DRAW : 13131 LOSS : 138408
# ========== Training : Episode  228000  ===========
# Recent 1000 games win rate :34.815%
#  -- 1000 Games WIN : 329 DRAW : 55 LOSS : 616
# Total win rate : 35.282%
# ...
# Recent 1000 games win rate :33.934%
#  -- 1000 Games WIN : 320 DRAW : 57 LOSS : 623
# Total win rate : 35.280%
#  -- TOTAL Games WIN : 307967 DRAW : 53088 LOSS : 564945
# ========== Training : Episode  927000  ===========
# Recent 1000 games win rate :37.407%
#  -- 1000 Games WIN : 352 DRAW : 59 LOSS : 589
# Total win rate : 35.283%
#  -- TOTAL Games WIN : 308319 DRAW : 53147 LOSS : 565534
# ========== Training : Episode  928000  ===========
# Recent 1000 games win rate :35.494%
#  -- 1000 Games WIN : 334 DRAW : 59 LOSS : 607
# Total win rate : 35.283%
#  -- TOTAL Games WIN : 308653 DRAW : 53206 LOSS : 566141
# ========== Training : Episode  929000  ===========
# Recent 1000 games win rate :34.110%
#  -- 1000 Games WIN : 322 DRAW : 56 LOSS : 622
# Total win rate : 35.282%
#  -- TOTAL Games WIN : 308975 DRAW : 53262 LOSS : 566763
# ========== Training : Episode  930000  ===========
# Recent 1000 games win rate :34.741%
#  -- 1000 Games WIN : 329 DRAW : 53 LOSS : 618
# Total win rate : 35.281%
#  -- TOTAL Games WIN : 309304 DRAW : 53315 LOSS : 567381
# ========== Training : Episode  931000  ===========
# Recent 1000 games win rate :32.945%
#  -- 1000 Games WIN : 311 DRAW : 56 LOSS : 633
# Total win rate : 35.279%
#  -- TOTAL Games WIN : 309615 DRAW : 53371 LOSS : 568014
# ========== Training : Episode  932000  ===========
# Recent 1000 games win rate :35.979%
#  -- 1000 Games WIN : 340 DRAW : 55 LOSS : 605
# Total win rate : 35.279%
#  -- TOTAL Games WIN : 309955 DRAW : 53426 LOSS : 568619
# ========== Training : Episode  933000  ===========
# Recent 1000 games win rate :34.402%
#  -- 1000 Games WIN : 322 DRAW : 64 LOSS : 614
# Total win rate : 35.278%
#  -- TOTAL Games WIN : 310277 DRAW : 53490 LOSS : 569233
# ========== Training : Episode  934000  ===========
# Recent 1000 games win rate :36.614%
#  -- 1000 Games WIN : 346 DRAW : 55 LOSS : 599
# Total win rate : 35.280%
#  -- TOTAL Games WIN : 310623 DRAW : 53545 LOSS : 569832
# ========== Training : Episode  935000  ===========
# Recent 1000 games win rate :34.681%
#  -- 1000 Games WIN : 326 DRAW : 60 LOSS : 614
# Total win rate : 35.279%
#  -- TOTAL Games WIN : 310949 DRAW : 53605 LOSS : 570446
# ========== Training : Episode  936000  ===========
# Recent 1000 games win rate :33.086%
#  -- 1000 Games WIN : 312 DRAW : 57 LOSS : 631
# Total win rate : 35.277%
#  -- TOTAL Games WIN : 311261 DRAW : 53662 LOSS : 571077
# ========== Training : Episode  937000  ===========
# Recent 1000 games win rate :34.395%
#  -- 1000 Games WIN : 324 DRAW : 58 LOSS : 618
# Total win rate : 35.276%
#  -- TOTAL Games WIN : 311585 DRAW : 53720 LOSS : 571695
# ========== Training : Episode  938000  ===========
# Recent 1000 games win rate :34.640%
#  -- 1000 Games WIN : 327 DRAW : 56 LOSS : 617
# Total win rate : 35.275%
#  -- TOTAL Games WIN : 311912 DRAW : 53776 LOSS : 572312
# ========== Training : Episode  939000  ===========
# Recent 1000 games win rate :35.288%
#  -- 1000 Games WIN : 331 DRAW : 62 LOSS : 607
# Total win rate : 35.275%
#  -- TOTAL Games WIN : 312243 DRAW : 53838 LOSS : 572919
# ========== Training : Episode  940000  ===========
# Recent 1000 games win rate :33.615%
#  -- 1000 Games WIN : 318 DRAW : 54 LOSS : 628
# Total win rate : 35.273%
#  -- TOTAL Games WIN : 312561 DRAW : 53892 LOSS : 573547
# ========== Training : Episode  941000  ===========
# Recent 1000 games win rate :32.804%
#  -- 1000 Games WIN : 310 DRAW : 55 LOSS : 635
# Total win rate : 35.271%
#  -- TOTAL Games WIN : 312871 DRAW : 53947 LOSS : 574182
# ========== Training : Episode  942000  ===========
# Recent 1000 games win rate :35.406%
#  -- 1000 Games WIN : 336 DRAW : 51 LOSS : 613
# Total win rate : 35.271%
#  -- TOTAL Games WIN : 313207 DRAW : 53998 LOSS : 574795
# ========== Training : Episode  943000  ===========
# Recent 1000 games win rate :35.783%
#  -- 1000 Games WIN : 336 DRAW : 61 LOSS : 603
# Total win rate : 35.272%
#  -- TOTAL Games WIN : 313543 DRAW : 54059 LOSS : 575398
# ========== Training : Episode  944000  ===========
# Recent 1000 games win rate :34.405%
#  -- 1000 Games WIN : 321 DRAW : 67 LOSS : 612
# Total win rate : 35.271%
#  -- TOTAL Games WIN : 313864 DRAW : 54126 LOSS : 576010
# ========== Training : Episode  945000  ===========
# Recent 1000 games win rate :34.741%
#  -- 1000 Games WIN : 329 DRAW : 53 LOSS : 618
# Total win rate : 35.270%
#  -- TOTAL Games WIN : 314193 DRAW : 54179 LOSS : 576628
# ========== Training : Episode  946000  ===========
# Recent 1000 games win rate :33.050%
#  -- 1000 Games WIN : 311 DRAW : 59 LOSS : 630
# Total win rate : 35.268%
#  -- TOTAL Games WIN : 314504 DRAW : 54238 LOSS : 577258
# ========== Training : Episode  947000  ===========
# Recent 1000 games win rate :33.298%
#  -- 1000 Games WIN : 313 DRAW : 60 LOSS : 627
# Total win rate : 35.266%
#  -- TOTAL Games WIN : 314817 DRAW : 54298 LOSS : 577885
# ========== Training : Episode  948000  ===========
# Recent 1000 games win rate :37.994%
#  -- 1000 Games WIN : 356 DRAW : 63 LOSS : 581
# Total win rate : 35.268%
#  -- TOTAL Games WIN : 315173 DRAW : 54361 LOSS : 578466
# ========== Training : Episode  949000  ===========
# Recent 1000 games win rate :34.909%
#  -- 1000 Games WIN : 325 DRAW : 69 LOSS : 606
# Total win rate : 35.268%
#  -- TOTAL Games WIN : 315498 DRAW : 54430 LOSS : 579072
# ========== Training : Episode  950000  ===========
# Recent 1000 games win rate :34.713%
#  -- 1000 Games WIN : 327 DRAW : 58 LOSS : 615
# Total win rate : 35.268%
#  -- TOTAL Games WIN : 315825 DRAW : 54488 LOSS : 579687
# ========== Training : Episode  951000  ===========
# Recent 1000 games win rate :34.319%
#  -- 1000 Games WIN : 325 DRAW : 53 LOSS : 622
# Total win rate : 35.267%
#  -- TOTAL Games WIN : 316150 DRAW : 54541 LOSS : 580309
# ========== Training : Episode  952000  ===========
# Recent 1000 games win rate :34.783%
#  -- 1000 Games WIN : 328 DRAW : 57 LOSS : 615
# Total win rate : 35.266%
#  -- TOTAL Games WIN : 316478 DRAW : 54598 LOSS : 580924
# ========== Training : Episode  953000  ===========
# Recent 1000 games win rate :31.250%
#  -- 1000 Games WIN : 290 DRAW : 72 LOSS : 638
# Total win rate : 35.262%
#  -- TOTAL Games WIN : 316768 DRAW : 54670 LOSS : 581562
# ========== Training : Episode  954000  ===========
# Recent 1000 games win rate :35.849%
#  -- 1000 Games WIN : 342 DRAW : 46 LOSS : 612
# Total win rate : 35.262%
#  -- TOTAL Games WIN : 317110 DRAW : 54716 LOSS : 582174
# ========== Training : Episode  955000  ===========
# Recent 1000 games win rate :35.737%
#  -- 1000 Games WIN : 337 DRAW : 57 LOSS : 606
# Total win rate : 35.263%
#  -- TOTAL Games WIN : 317447 DRAW : 54773 LOSS : 582780
# ========== Training : Episode  956000  ===========
# Recent 1000 games win rate :34.395%
#  -- 1000 Games WIN : 324 DRAW : 58 LOSS : 618
# Total win rate : 35.262%
#  -- TOTAL Games WIN : 317771 DRAW : 54831 LOSS : 583398
# ========== Training : Episode  957000  ===========
# Recent 1000 games win rate :34.516%
#  -- 1000 Games WIN : 321 DRAW : 70 LOSS : 609
# Total win rate : 35.261%
#  -- TOTAL Games WIN : 318092 DRAW : 54901 LOSS : 584007
# ========== Training : Episode  958000  ===========
# Recent 1000 games win rate :34.072%
#  -- 1000 Games WIN : 323 DRAW : 52 LOSS : 625
# Total win rate : 35.260%
#  -- TOTAL Games WIN : 318415 DRAW : 54953 LOSS : 584632
# ========== Training : Episode  959000  ===========
# Recent 1000 games win rate :35.979%
#  -- 1000 Games WIN : 340 DRAW : 55 LOSS : 605
# Total win rate : 35.261%
#  -- TOTAL Games WIN : 318755 DRAW : 55008 LOSS : 585237
# ========== Training : Episode  960000  ===========
# Recent 1000 games win rate :35.859%
#  -- 1000 Games WIN : 336 DRAW : 63 LOSS : 601
# Total win rate : 35.261%
#  -- TOTAL Games WIN : 319091 DRAW : 55071 LOSS : 585838
# ========== Training : Episode  961000  ===========
# Recent 1000 games win rate :34.113%
#  -- 1000 Games WIN : 321 DRAW : 59 LOSS : 620
# Total win rate : 35.260%
#  -- TOTAL Games WIN : 319412 DRAW : 55130 LOSS : 586458
# ========== Training : Episode  962000  ===========
# Recent 1000 games win rate :36.373%
#  -- 1000 Games WIN : 347 DRAW : 46 LOSS : 607
# Total win rate : 35.261%
#  -- TOTAL Games WIN : 319759 DRAW : 55176 LOSS : 587065
# ========== Training : Episode  963000  ===========
# Recent 1000 games win rate :32.945%
#  -- 1000 Games WIN : 311 DRAW : 56 LOSS : 633
# Total win rate : 35.259%
#  -- TOTAL Games WIN : 320070 DRAW : 55232 LOSS : 587698
# ========== Training : Episode  964000  ===========
# Recent 1000 games win rate :32.025%
#  -- 1000 Games WIN : 302 DRAW : 57 LOSS : 641
# Total win rate : 35.256%
#  -- TOTAL Games WIN : 320372 DRAW : 55289 LOSS : 588339
# ========== Training : Episode  965000  ===========
# Recent 1000 games win rate :33.510%
#  -- 1000 Games WIN : 316 DRAW : 57 LOSS : 627
# Total win rate : 35.254%
#  -- TOTAL Games WIN : 320688 DRAW : 55346 LOSS : 588966
# ========== Training : Episode  966000  ===========
# Recent 1000 games win rate :32.154%
#  -- 1000 Games WIN : 300 DRAW : 67 LOSS : 633
# Total win rate : 35.251%
#  -- TOTAL Games WIN : 320988 DRAW : 55413 LOSS : 589599
# ========== Training : Episode  967000  ===========
# Recent 1000 games win rate :33.053%
#  -- 1000 Games WIN : 314 DRAW : 50 LOSS : 636
# Total win rate : 35.248%
#  -- TOTAL Games WIN : 321302 DRAW : 55463 LOSS : 590235
# ========== Training : Episode  968000  ===========
# Recent 1000 games win rate :35.412%
#  -- 1000 Games WIN : 335 DRAW : 54 LOSS : 611
# Total win rate : 35.249%
#  -- TOTAL Games WIN : 321637 DRAW : 55517 LOSS : 590846
# ========== Training : Episode  969000  ===========
# Recent 1000 games win rate :33.721%
#  -- 1000 Games WIN : 319 DRAW : 54 LOSS : 627
# Total win rate : 35.247%
#  -- TOTAL Games WIN : 321956 DRAW : 55571 LOSS : 591473
# ========== Training : Episode  970000  ===========
# Recent 1000 games win rate :34.034%
#  -- 1000 Games WIN : 324 DRAW : 48 LOSS : 628
# Total win rate : 35.246%
#  -- TOTAL Games WIN : 322280 DRAW : 55619 LOSS : 592101
# ========== Training : Episode  971000  ===========
# Recent 1000 games win rate :31.813%
#  -- 1000 Games WIN : 300 DRAW : 57 LOSS : 643
# Total win rate : 35.242%
#  -- TOTAL Games WIN : 322580 DRAW : 55676 LOSS : 592744
# ========== Training : Episode  972000  ===========
# Recent 1000 games win rate :34.069%
#  -- 1000 Games WIN : 324 DRAW : 49 LOSS : 627
# Total win rate : 35.241%
#  -- TOTAL Games WIN : 322904 DRAW : 55725 LOSS : 593371
# ========== Training : Episode  973000  ===========
# Recent 1000 games win rate :34.615%
#  -- 1000 Games WIN : 324 DRAW : 64 LOSS : 612
# Total win rate : 35.240%
#  -- TOTAL Games WIN : 323228 DRAW : 55789 LOSS : 593983
# ========== Training : Episode  974000  ===========
# Recent 1000 games win rate :33.620%
#  -- 1000 Games WIN : 313 DRAW : 69 LOSS : 618
# Total win rate : 35.239%
#  -- TOTAL Games WIN : 323541 DRAW : 55858 LOSS : 594601
# ========== Training : Episode  975000  ===========
# Recent 1000 games win rate :35.789%
#  -- 1000 Games WIN : 340 DRAW : 50 LOSS : 610
# Total win rate : 35.239%
#  -- TOTAL Games WIN : 323881 DRAW : 55908 LOSS : 595211
# ========== Training : Episode  976000  ===========
# Recent 1000 games win rate :34.472%
#  -- 1000 Games WIN : 323 DRAW : 63 LOSS : 614
# Total win rate : 35.238%
#  -- TOTAL Games WIN : 324204 DRAW : 55971 LOSS : 595825
# ========== Training : Episode  977000  ===========
# Recent 1000 games win rate :33.620%
#  -- 1000 Games WIN : 313 DRAW : 69 LOSS : 618
# Total win rate : 35.237%
#  -- TOTAL Games WIN : 324517 DRAW : 56040 LOSS : 596443
# ========== Training : Episode  978000  ===========
# Recent 1000 games win rate :34.172%
#  -- 1000 Games WIN : 326 DRAW : 46 LOSS : 628
# Total win rate : 35.236%
#  -- TOTAL Games WIN : 324843 DRAW : 56086 LOSS : 597071
# ========== Training : Episode  979000  ===========
# Recent 1000 games win rate :36.296%
#  -- 1000 Games WIN : 343 DRAW : 55 LOSS : 602
# Total win rate : 35.237%
#  -- TOTAL Games WIN : 325186 DRAW : 56141 LOSS : 597673
# ========== Training : Episode  980000  ===========
# Recent 1000 games win rate :33.755%
#  -- 1000 Games WIN : 320 DRAW : 52 LOSS : 628
# Total win rate : 35.235%
#  -- TOTAL Games WIN : 325506 DRAW : 56193 LOSS : 598301
# ========== Training : Episode  981000  ===========
# Recent 1000 games win rate :37.726%
#  -- 1000 Games WIN : 355 DRAW : 59 LOSS : 586
# Total win rate : 35.238%
#  -- TOTAL Games WIN : 325861 DRAW : 56252 LOSS : 598887
# ========== Training : Episode  982000  ===========
# Recent 1000 games win rate :35.319%
#  -- 1000 Games WIN : 332 DRAW : 60 LOSS : 608
# Total win rate : 35.238%
#  -- TOTAL Games WIN : 326193 DRAW : 56312 LOSS : 599495
# ========== Training : Episode  983000  ===========
# Recent 1000 games win rate :34.120%
#  -- 1000 Games WIN : 318 DRAW : 68 LOSS : 614
# Total win rate : 35.237%
#  -- TOTAL Games WIN : 326511 DRAW : 56380 LOSS : 600109
# ========== Training : Episode  984000  ===========
# Recent 1000 games win rate :35.112%
#  -- 1000 Games WIN : 329 DRAW : 63 LOSS : 608
# Total win rate : 35.237%
#  -- TOTAL Games WIN : 326840 DRAW : 56443 LOSS : 600717
# ========== Training : Episode  985000  ===========
# Recent 1000 games win rate :35.684%
#  -- 1000 Games WIN : 334 DRAW : 64 LOSS : 602
# Total win rate : 35.237%
#  -- TOTAL Games WIN : 327174 DRAW : 56507 LOSS : 601319
# ========== Training : Episode  986000  ===========
# Recent 1000 games win rate :36.555%
#  -- 1000 Games WIN : 348 DRAW : 48 LOSS : 604
# Total win rate : 35.238%
#  -- TOTAL Games WIN : 327522 DRAW : 56555 LOSS : 601923
# ========== Training : Episode  987000  ===========
# Recent 1000 games win rate :33.889%
#  -- 1000 Games WIN : 325 DRAW : 41 LOSS : 634
# Total win rate : 35.237%
#  -- TOTAL Games WIN : 327847 DRAW : 56596 LOSS : 602557
# ========== Training : Episode  988000  ===========
# Recent 1000 games win rate :35.941%
#  -- 1000 Games WIN : 340 DRAW : 54 LOSS : 606
# Total win rate : 35.238%
#  -- TOTAL Games WIN : 328187 DRAW : 56650 LOSS : 603163
# ========== Training : Episode  989000  ===========
# Recent 1000 games win rate :35.124%
#  -- 1000 Games WIN : 327 DRAW : 69 LOSS : 604
# Total win rate : 35.238%
#  -- TOTAL Games WIN : 328514 DRAW : 56719 LOSS : 603767
# ========== Training : Episode  990000  ===========
# Recent 1000 games win rate :35.957%
#  -- 1000 Games WIN : 338 DRAW : 60 LOSS : 602
# Total win rate : 35.238%
#  -- TOTAL Games WIN : 328852 DRAW : 56779 LOSS : 604369
# ========== Training : Episode  991000  ===========
# Recent 1000 games win rate :37.146%
#  -- 1000 Games WIN : 354 DRAW : 47 LOSS : 599
# Total win rate : 35.240%
#  -- TOTAL Games WIN : 329206 DRAW : 56826 LOSS : 604968
# ========== Training : Episode  992000  ===========
# Recent 1000 games win rate :36.809%
#  -- 1000 Games WIN : 353 DRAW : 41 LOSS : 606
# Total win rate : 35.242%
#  -- TOTAL Games WIN : 329559 DRAW : 56867 LOSS : 605574
# ========== Training : Episode  993000  ===========
# Recent 1000 games win rate :34.113%
#  -- 1000 Games WIN : 321 DRAW : 59 LOSS : 620
# Total win rate : 35.241%
#  -- TOTAL Games WIN : 329880 DRAW : 56926 LOSS : 606194
# ========== Training : Episode  994000  ===========
# Recent 1000 games win rate :36.286%
#  -- 1000 Games WIN : 340 DRAW : 63 LOSS : 597
# Total win rate : 35.242%
#  -- TOTAL Games WIN : 330220 DRAW : 56989 LOSS : 606791
# ========== Training : Episode  995000  ===========
# Recent 1000 games win rate :35.095%
#  -- 1000 Games WIN : 332 DRAW : 54 LOSS : 614
# Total win rate : 35.242%
#  -- TOTAL Games WIN : 330552 DRAW : 57043 LOSS : 607405
# ========== Training : Episode  996000  ===========
# Recent 1000 games win rate :33.936%
#  -- 1000 Games WIN : 319 DRAW : 60 LOSS : 621
# Total win rate : 35.240%
#  -- TOTAL Games WIN : 330871 DRAW : 57103 LOSS : 608026
# ========== Training : Episode  997000  ===========
# Recent 1000 games win rate :34.685%
#  -- 1000 Games WIN : 325 DRAW : 63 LOSS : 612
# Total win rate : 35.240%
#  -- TOTAL Games WIN : 331196 DRAW : 57166 LOSS : 608638
# ========== Training : Episode  998000  ===========
# Recent 1000 games win rate :36.479%
#  -- 1000 Games WIN : 344 DRAW : 57 LOSS : 599
# Total win rate : 35.241%
#  -- TOTAL Games WIN : 331540 DRAW : 57223 LOSS : 609237
# ========== Training : Episode  999000  ===========
# Recent 1000 games win rate :34.211%
#  -- 1000 Games WIN : 325 DRAW : 50 LOSS : 625
# Total win rate : 35.240%
#  -- TOTAL Games WIN : 331865 DRAW : 57273 LOSS : 609862
# ========== Training : Episode  1000000  ===========
# Recent 1000 games win rate :32.558%
#  -- 1000 Games WIN : 308 DRAW : 54 LOSS : 638
# Total win rate : 35.237%
#  -- TOTAL Games WIN : 332173 DRAW : 57327 LOSS : 610500

# %%
current_money = 10000
win_count = 0
lose_count = 0

money_list = []
count_list = []
#episode = list()    # 에피소드

for i in range (1000):
            current_money -= 10
          #  episode = mc_es.generate_episode(dealer, agent, deck)
         # agent.update_qval(episode)
            
            deck.reset()
            dealer.reset()
            agent.reset()

            # 딜러와 에이전트가 카드를 두장씩 뽑음
            dealer.hit(deck)
            dealer.hit(deck)
            agent.hit(deck)
            agent.hit(deck)
            
            dealer_one = dealer.show()
            
            done = False 
            money = 0
            
            while not done:
            # 에피소드가 끝날 때까지 State, Action, Reward를 생성
                sums = agent.calculate_sum()
                if sums < 12:
                    agent.hit(deck)
                    continue

                state = (sums, bool(agent.usable_ace), dealer.show())

                       
                action = agent.policy(state)
                done, reward = dealer.observation(action, agent, deck)  
                
            dealer.action(deck)
            
            done, reward = dealer.observation(action, agent, deck)# 에피소드 종료 여부, Reward 계산
            
            if (reward == 1):
                current_money += 20
                win_count += 1
            elif (reward == 0):
                current_money += 10
            elif (reward == -1):
                current_money  += 0
                lose_count += 1

            count_list.insert(i,i)
            money_list.insert(i,current_money)
            
           # print("========== Training : Episode ", i, " ===========")

# %%
winRate = win_count/(win_count+lose_count)

winRate
# Out:
# 0.4718004338394794

# %%
plt.plot(count_list,money_list)
plt.show()

# %% [markdown]
# ---
# ### 참고자료
# [1] Reinforcement Learning - An Introduction (Richard S. Sutton, Andreow G. Barto), 2nd edition, p.120-124 https://web.stanford.edu/class/psych209/Readings/SuttonBartoIPRLBook2ndEd.pdf <br>
# [2] matplotlib.pyplot.plot Documentation, https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html <br>
# [3] matplotlib.pyplot.plot Examples https://matplotlib.org/tutorials/introductory/pyplot.html
